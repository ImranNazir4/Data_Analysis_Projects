# %%
import pandas as pd
import numpy as np
import seaborn as ns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
df=pd.read_csv("customer_churn.csv")

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(25,50))

# Create a grid of subplots with custom widths and heights
gs = gridspec.GridSpec(8, 8,figure=fig)

# Adding text
text = """The    dashboard    explores the relationships between different features and survival 
rate on the Titanic, and includes visualizations such as histograms, count plots, and 
violin plots. Key findings include that children and young adults were more likely to 
survive than older passengers, passengers who paid higher fares were more likely to 
survive, and female passengers were more likely to survive than male passengers."""
fig.suptitle(f'Titanic Dashboard\nAsim Muhammad Salim (21031789)\n\n {text}\n\n', fontsize=18)


# Create the subplots
ax1 = plt.subplot(gs[0, 0:8])
#ax2 = plt.subplot(gs[0, 1])
#ax3 = plt.subplot(gs[1, :])
