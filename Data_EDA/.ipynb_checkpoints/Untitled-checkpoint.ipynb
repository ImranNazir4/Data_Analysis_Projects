# %% [markdown]
# # Necessary Packages

# %%
#data analysis
import pandas as pd
import numpy as np
#ata visualization
import seaborn as sns
import matplotlib.pyplot as plt
#to match text patterns
import re

# %% [markdown]
# # Reading the Data

# %%
df=pd.read_csv('isilon_joint_soft_hard_500.csv',low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24019 entries, 0 to 24018
# Columns: 291 entries, Unnamed: 0 to FlshDrv
# dtypes: float64(151), object(140)
# memory usage: 53.3+ MB

# %% [markdown]
# # Columns in Data

# %%
for i in df.columns:
    print(i)
# Out:
# Unnamed: 0
# Cluster Health
# Size HDD
# Size  SSD Storage
# VHS Size HDD
# VHS Size  SSD Storage
# Used HDD
# Used  SSD Storage
# Avail HDD
# Avail  SSD Storage
# OK_Count
# Down_Count
# Atten Count
# SmartFail_Count
# Read_Only
# NA_Count
# Unique_Event_Count
# LNN_Info
# Critical_Event_List
# Running Jobs
# Waiting Jobs
# Failed Jobs
# Failed_Desc
# Total Unsuccessful
# Recent Failed
# Unretrieveable
# case_id
# cluster_x
# node_x
# Storage Efficiency
# cluster_y
# node_y
# SerNo
# Config
# FamCode
# ChsCode
# GenCode
# Product
# HWGen
# Chassis
# CPU
# PROC
# RAM
# Mobo
# NVRam
# DskCtl
# DskExp
# PwrSupl
# CPU_Model
# CPU Operation
# FAN TAC SENSOR 1
# FAN TAC SENSOR 2
# FAN TAC SENSOR 3
# PS FAN SPEED 1
# PS FAN SPEED 2
# BB +12.0V
# BB +5.0V
# BB +3.3V
# BB +5.0V STBY
# BB +3.3V AUX
# BB +1.05V P1Vccp
# BB +1.05V P2Vccp
# BB +1.5 P1DDR AB
# BB +1.5 P1DDR CD
# BB +1.5 P2DDR AB
# BB +1.5 P2DDR CD
# BB +1.8V AUX
# BB +1.1V STBY
# BB VBAT
# BB +1.35 P1LV AB
# BB +1.35 P1LV CD
# BB +1.35 P2LV AB
# BB +1.35 P2LV CD
# VCC_12V0
# VCC_5V0
# VCC_3V3
# VCC_1V8
# VCC_5V0_SB
# VCC_1V0
# VCC_5V0_CBL
# VCC_SW
# VBATT_1
# VBATT_2
# PS IN VOLT 1
# PS IN VOLT 2
# PS OUT VOLT 1
# PS OUT VOLT 2
# Temp Front Panel
# BB EDGE Temp
# BB BMC Temp
# BB P2 VR Temp
# BB MEM VR Temp
# LAN NIC Temp
# P1 Therm Margin
# P2 Therm Margin
# P1 DTS Therm Mgn
# P2 DTS Therm Mgn
# DIMM Thrm Mrgn 1
# DIMM Thrm Mrgn 2
# DIMM Thrm Mrgn 3
# DIMM Thrm Mrgn 4
# TEMP SENSOR 1
# PS TEMP 1
# PS TEMP 2
# Battery1:
# Battery2:
# Battery 1 Voltage (now)
# Battery 1 Charge  (now)
# Battery 2 Voltage (now)
# Battery 2 Charge  (now)
# Battery 1 Status
# Battery 2 Status
# Ambient_Temp
# Battery0_Temp
# CMOS_Voltage
# CPU Speed Limit
# CPU0_Temp
# ChsSerN
# ChsSlot
# DIMM_Bank0
# DIMM_Bank1
# Fan0_Speed
# Fan1_Speed
# Hottest_HDD_Temp
# MP_Temp0
# PrfCode
# SP_CMD_Vin
# SP_Temp0
# Slot3-PS0_In_Voltage
# Slot3-PS0_Temp0
# Slot3-PS0_Temp1
# Slot4-PS1_In_Voltage
# Slot4-PS1_Temp0
# Slot4-PS1_Temp1
# Slot1-PS0_In_Voltage
# Slot1-PS0_Temp0
# Slot1-PS0_Temp1
# Slot2-PS1_In_Voltage
# Slot2-PS1_Temp0
# Slot2-PS1_Temp1
# Class
# DEBUG
# Exhaust Temp
# Fan1A
# Fan1B
# Fan2A
# Fan2B
# Fan3A
# Fan3B
# Fan4A
# Fan4B
# Fan5A
# Fan5B
# Fan6A
# Fan6B
# Fan7A
# Fan7B
# Fan8A
# Fan8B
# GPU1 Temp
# GPU2 Temp
# GPU3 Temp
# Inlet Temp
# MEM012 VR
# MEM345 VR
# Series
# Temp
# Tier
# VCORE VR
# Voltage 1
# Voltage 2
# Drive_IO0_Temp
# Embed_IO_Temp0
# Hottest_SAS_Drv
# MP_Temp1
# SLIC0_Temp
# SLIC1_Temp
# BB +1.2V VCCP1
# BB +3.0V Vbat
# BB -12.0V
# BB 1.5V P1 MEM
# BB P1 VR Temp
# P1 DIMM Thrm Mgn
# P1 DTS Thrm Mgn
# SSB Temp
# Fan1
# Fan2
# Fan3
# Fan4
# Fan5
# Fan6
# GPU4 Temp
# GPU5 Temp
# GPU6 Temp
# GPU7 Temp
# GPU8 Temp
# Chassis Fan1 (ISI F1)
# Chassis Fan2 (ISI F2)
# Chassis Fan3 (ISI F3)
# Front Panel Temp
# Power Supply 1 Fan1
# Power Supply 1 Input Voltage
# Power Supply 1 Output Voltage
# Power Supply 2 Fan1
# Power Supply 2 Input Voltage
# Power Supply 2 Output Voltage
# Temp Chassis 1 (ISI T1)
# Temp Power Supply 1
# Temp Power Supply 2
# Temp System
# Temp Until CPU Throttle (CPU 0)
# Voltage 1.5v
# Voltage 12v
# Voltage 3.3v
# Voltage 3.3v Standby
# Voltage 5v
# Voltage 5v Standby
# Voltage CPU Core (CPU 0)
# Voltage Chassis 1.0v
# Voltage Chassis 1.8v
# Voltage Chassis 12v
# Voltage Chassis 3.3v
# Voltage Chassis 5v
# Voltage Dimm (CPU 0)
# Voltage Front Panel Fused 5v
# LSI CORE TEMP
# TEMP SENSOR 2
# V1.0
# V1.8
# V12.0
# V12.0_BB_A
# V12.0_FAN1
# V12.0_FAN2
# V12.0_FAN3
# V12.0_MB0
# V12.0_MB1
# V3.3
# V3.3_CMD
# V3.3_STBY
# V5.0
# V5.0_FP_X
# V5.0_NVRAM
# V5.0_STBY
# FAN TAC SENSOR 4
# FAN TAC SENSOR 5
# FAN TAC SENSOR 6
# HOTTEST DRVTEMP
# INLET TEMP
# PMC CORE TEMP
# V0.92_A
# V0.92_DC
# V12.0_BB_B
# V12.0_BB_C
# V12.0_BB_D
# V12.0_FOR_D2D
# Agg Therm Mgn 1
# BB +1.05Vccp P1
# BB +1.05Vccp P2
# BB +1.5 P1MEM AB
# BB +1.5 P1MEM CD
# BB +1.5 P2MEM AB
# BB +1.5 P2MEM CD
# BB +3.3V Vbat
# BB Vtt 1 Temp
# BB Vtt 2 Temp
# Exit Air Temp
# HSBP 1 Temp
# MIC 1 Margin
# MIC 2 Margin
# P1 Mem01 VRD Hot
# P1 Mem23 VRD Hot
# P1 VRD Hot
# P2 Mem01 VRD Hot
# P2 Mem23 VRD Hot
# P2 VRD Hot
# PS1 Temperature
# PS2 Temperature
# SAS Mod Temp
# System Fan 1A
# System Fan 1B
# System Fan 2A
# System Fan 2B
# System Fan 3A
# System Fan 3B
# System Fan 4A
# System Fan 4B
# System Fan 5A
# System Fan 5B
# System Fan 6A
# System Fan 6B
# FlshDrv

# %%
# removing trailing and leading [] brackets
df['Cluster Health']=df['Cluster Health'].apply(lambda x:re.sub('[\[\]]','',x))

# %%
plt.figure(figsize=(8,8))
df['Cluster Health'].value_counts().plot.pie(autopct='%.1f%%')
plt.title('Cluster Health Distribution')
# Out:
# Text(0.5, 1.0, 'Cluster Health Distribution')

# %% [markdown]
# ### Storages Analysis

# %%
#this function converts peta bytes to tera bytes and also remove trailing data units
def pb_to_tb(petabytes):
    if petabytes[-1]=='P':
        petabytes=petabytes[0:-1]
        petabytes=float(petabytes)
        terabytes=petabytes * 1024
        return terabytes
    else: 
        return petabytes[1:-1]

# %%
df['Used HDD']=df['Used HDD'].apply(lambda x:str(x).split()[0])

# %%
df['Used HDD']=df['Used HDD'].apply(lambda x:pb_to_tb(str(x)))

# %%
df['Used  SSD Storage']=df['Used  SSD Storage'].apply(lambda x:str(x).split()[0])

# %%
df['Used  SSD Storage']=df['Used  SSD Storage'].apply(lambda x:pb_to_tb(str(x)))

# %%
df['Avail HDD']=df['Avail HDD'].apply(lambda x:str(x).split()[0])
df['Avail HDD']=df['Avail HDD'].apply(lambda x:pb_to_tb(str(x)))

# %%
df['Avail  SSD Storage']=df['Avail  SSD Storage'].apply(lambda x:str(x).split()[0])
df['Avail  SSD Storage']=df['Avail  SSD Storage'].apply(lambda x:pb_to_tb(str(x)))

# %%
df['VHS Size HDD']=df['VHS Size HDD'].apply(lambda x:pb_to_tb(str(x)))

# %%
#cnverting string data to numerical data
for i in ['Used HDD','Used  SSD Storage', 'Avail HDD', 'Avail  SSD Storage','VHS Size HDD']:
    df[df[i]=='']=np.nan
    df[df[i]=='/a']=np.nan
    df[i]=df[i].astype(float)

# %%
for i in ['Used HDD','Used  SSD Storage', 'Avail HDD', 'Avail  SSD Storage','VHS Size HDD']:
    sns.displot(df[i])

# %%
def pb_to_tb(petabytes):
    if petabytes[-1]=='P':
        petabytes=petabytes[1:-1]
        petabytes=float(petabytes)
        terabytes=petabytes * 1024
    else: 
        return petabytes[1:-1]

# %% [markdown]
# ### Jobs Analysis

# %%
for i in ['Running Jobs','Waiting Jobs','Failed Jobs','Critical_Event_List']:
    sns.displot(df[i])
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)

# %%
### Procs Analysis

# %%
def get_procs_info(cpu_data):
    cpu_data=cpu_data.split()
    try:
        res=cpu_data[0]
        return res
    except:
        pass

# %%
df['PROC Type']=df['PROC'].apply(lambda x:get_procs_info(str(x)))

# %%
plt.figure(figsize=(8,8))
df['PROC Type'].value_counts().plot.pie(autopct='%.1f%%')
plt.title('Procs Type')
# Out:
# Text(0.5, 1.0, 'Procs Type')

# %%
def get_cores_info(cpu_data):
    cpu_data=cpu_data.split()
    try:
        res=cpu_data[1]
        return res
    except:
        pass

# %%
df['PROC Core']=df['PROC'].apply(lambda x:get_cores_info(str(x)))

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['PROC Core'])
plt.title('Procs Cores Distributions')
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Procs Cores Distributions')

# %% [markdown]
# ### Performance Counts Anlysis

# %%
for i in ['OK_Count','Down_Count','Atten Count','SmartFail_Count']:
    sns.displot(df[i])

# %%
def get_cpu_series(cpu_data):
    cpu_data=cpu_data.split()
    try:
        res=cpu_data[1]
        return res
    except:
        pass

# %%
df['CPU_Series']=df['CPU_Model'].apply(lambda x:get_cpu_series(str(x)))

# %%
plt.figure(figsize=(8,8))
df['CPU_Series'].value_counts().plot.pie(autopct='%.1f%%')
plt.title('CPU Series')
# Out:
# Text(0.5, 1.0, 'CPU Series')

# %% [markdown]
# ### Ram Analysis

# %%
df['RAM']=df['RAM'].apply(lambda x:str(x).split()[0])

# %%
df['RAM']=df['RAM'].astype(float)

# %%
#converting bytes to gb
def bytes_to_gb(byte):
    gb = byte / (1024 ** 3)
    return gb

# %%
df['RAM In Gb Approx']=df['RAM'].apply(lambda x:bytes_to_gb(x))

# %%
sns.displot(df['RAM In Gb Approx'])

# %%
plt.figure(figsize=(22,7))
sorted_data = df['RAM In Gb Approx'].sort_values(ascending=False)
top_10 = sorted_data.head(50)
sns.countplot(top_10)
plt.title('Top 10 RAM Sizes')
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Top 10 RAM Sizes')

# %% [markdown]
# ### CPU Analysis

# %%
df['CPU Company']=df['CPU'].apply(lambda x:str(x).split()[0])

# %%
df['CPU Company'].value_counts()
# Out:
# GenuineIntel    12447
# nan             11572
# Name: CPU Company, dtype: int64

# %%
def get_cpu_speed(cpu_data):
    cpu_data=cpu_data.split()
    try:
        res=cpu_data[1][1:-1]
        return res
    except:
        pass

# %%
df['CPU Speed']=df['CPU'].apply(lambda x:get_cpu_speed(str(x)))

# %%
plt.figure(figsize=(20,7))
sns.countplot(df['CPU Speed'])
plt.title('CPU Speeds')
plt.show()
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Permissions Analysis

# %%
plt.figure(figsize=(8,8))
df[['Read_Only']].value_counts().plot.pie(autopct='%.1f%%')
plt.title('Read Only Permissions')
# Out:
# Text(0.5, 1.0, 'Read Only Permissions')
