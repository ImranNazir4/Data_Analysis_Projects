# %% [markdown]
# # **Required Packages**

# %%
import pandas as pd             #package for data analysis
import numpy as np              #package for handling numpy arrays
import seaborn as sns           #package for data visualization
import matplotlib.pyplot as plt #packae for data visualization
import re                       #package for handling regular expression

# %% [markdown]
# # **Reading the Data**

# %%
data=pd.read_csv('DataET0.csv',delimiter=';')

# %% [markdown]
# ### **Data Display**

# %%
data.head()
# Out:
#          Date/heure moy_Temp[°C] max_Temp[°C] min_Temp[°C] moy_DewPoint[°C]  \
# 0  05/08/2022 00:00        24,73        35,08        15,11             12,4
# 1  04/08/2022 00:00        25,26        35,79         16,4             14,6
# 2  03/08/2022 00:00        28,37        36,71         19,8             12,3
# 3  02/08/2022 00:00        32,17        43,43        19,68              0,9
# 4  01/08/2022 00:00         32,3         41,9        21,26              8,7
#
#   min_DewPoint[°C]  moy_SolarRadiation[W/m2] moy_VPD[kPa] min_VPD[kPa]  \
# 0              8,8                       361          1,9          0,3
# 1                8                       288         1,73            0
# 2              7,4                       285         2,56         0,95
# 3             -4,7                       296         4,55          1,7
# 4              1,5                       290         3,97         1,39
#
#   moy_RelativeHumidity[%] max_RelativeHumidity[%] min_RelativeHumidity[%]  \
# 0                   51,87                    83,3                      22
# 1                   59,06                   99,54                   19,84
# 2                   38,43                   65,76                    23,6
# 3                   16,44                   38,56                    5,23
# 4                   26,68                   47,56                    9,52
#
#   Somme_Precipitation[mm] moy_WindSpeed[m/s] max_WindSpeed[m/s]  \
# 0                       0                0,5                2,1
# 1                       0                0,6                1,7
# 2                       0                0,7                2,6
# 3                       0                0,6                2,3
# 4                       0                0,6                2,7
#
#   max_WindSpeedMax[m/s]  moy_WindDirection[deg]  dernier_WindDirection[deg]  \
# 0                   4,4                     NaN                         NaN
# 1                   5,3                     NaN                         NaN
# 2                   5,3                     NaN                         NaN
# 3                   6,6                     NaN                         NaN
# 4                   6,7                     NaN                         NaN
#
#   ETP quotidien [mm]
# 0                NaN
# 1                  5
# 2                5,3
# 3                5,3
# 4                5,5

# %% [markdown]
# ### **Data Structure**

# %%
data.shape
# Out:
# (1781, 19)

# %%
#no. of rows --> 1781 and no. of columns-->19

# %% [markdown]
# ### **Features in the Data**

# %%
data.columns
# Out:
# Index(['Date/heure', 'moy_Temp[°C]', 'max_Temp[°C]', 'min_Temp[°C]',
#        'moy_DewPoint[°C]', 'min_DewPoint[°C]', 'moy_SolarRadiation[W/m2]',
#        'moy_VPD[kPa]', 'min_VPD[kPa]', 'moy_RelativeHumidity[%]',
#        'max_RelativeHumidity[%]', 'min_RelativeHumidity[%]',
#        'Somme_Precipitation[mm]', 'moy_WindSpeed[m/s]', 'max_WindSpeed[m/s]',
#        'max_WindSpeedMax[m/s]', 'moy_WindDirection[deg]',
#        'dernier_WindDirection[deg]', 'ETP quotidien [mm]'],
#       dtype='object')

# %% [markdown]
# ### **Categorical Data Feature**

# %%
data.select_dtypes(object).columns
# Out:
# Index(['Date/heure', 'moy_Temp[°C]', 'max_Temp[°C]', 'min_Temp[°C]',
#        'moy_DewPoint[°C]', 'min_DewPoint[°C]', 'moy_VPD[kPa]', 'min_VPD[kPa]',
#        'moy_RelativeHumidity[%]', 'max_RelativeHumidity[%]',
#        'min_RelativeHumidity[%]', 'Somme_Precipitation[mm]',
#        'moy_WindSpeed[m/s]', 'max_WindSpeed[m/s]', 'max_WindSpeedMax[m/s]',
#        'ETP quotidien [mm]'],
#       dtype='object')

# %% [markdown]
# ### **Datatype  Anomaly Alert!**
# Here we can see that data is misclassified, the data that should be of type interger or float is preseent in object data type. We will figure out this data type anomly problem later in this code. This is the main intuition to select this data because some single vlaue features contain huge strigs even in target feature.

# %% [markdown]
# ### **Numerical Data Feature**

# %%
data.select_dtypes(np.number).columns
# Out:
# Index(['moy_SolarRadiation[W/m2]', 'moy_WindDirection[deg]',
#        'dernier_WindDirection[deg]'],
#       dtype='object')

# %% [markdown]
# # **Data Preprocessing**
# - Exploring Features Data Values and Data Types
# - Finding Null Values
# - Fill Missing Values
# - Data Normalization

# %% [markdown]
# ### **Exploring Features Data Values and Data Types**

# %%
data.dtypes
# Out:
# Date/heure                     object
# moy_Temp[°C]                   object
# max_Temp[°C]                   object
# min_Temp[°C]                   object
# moy_DewPoint[°C]               object
# min_DewPoint[°C]               object
# moy_SolarRadiation[W/m2]        int64
# moy_VPD[kPa]                   object
# min_VPD[kPa]                   object
# moy_RelativeHumidity[%]        object
# max_RelativeHumidity[%]        object
# min_RelativeHumidity[%]        object
# Somme_Precipitation[mm]        object
# moy_WindSpeed[m/s]             object
# max_WindSpeed[m/s]             object
# max_WindSpeedMax[m/s]          object
# moy_WindDirection[deg]        float64
# dernier_WindDirection[deg]    float64
# ETP quotidien [mm]             object
# dtype: object

# %% [markdown]
# It is strange is to see our feature are numerical and should have numeric data type either int or float. But these features has object as ata type which refers to text type of data. We need to convert them into numerical data types.

# %% [markdown]
# ### **Checking Unique Values in the Data Feature**

# %%
feat_with_object_dtype=data.select_dtypes(np.object).columns
for feature in feat_with_object_dtype:
    print(f'{feature} : {data[feature].unique()}')
# Out:
# Date/heure : ['05/08/2022 00:00' '04/08/2022 00:00' '03/08/2022 00:00' ...
#  '05/06/2017 00:00' '10/04/2017 00:00' '10/11/2016 00:00']
# moy_Temp[°C] : ['24,73' '25,26' '28,37' ... '29,31' '26,83' '26,19']
# max_Temp[°C] : ['35,08' '35,79' '36,71' ... '47,34' '26,47' '22,6']
# min_Temp[°C] : ['15,11' '16,4' '19,8' ... '26,1' '22,89' '20,94']
# moy_DewPoint[°C] : ['12,4' '14,6' '12,3' '0,9' '8,7' '9,5' '16,5' '12,6' '13,6' '7,9' '4,9'
#  '7,2' '5,1' '6,6' '7,3' '9,7' '12,7' '16,9' '18,8' '11,6' '9,4' '2,1'
#  '9,2' '4,7' '5,8' '13,1' '15,6' '16,6' '15,9' '12,5' '11,8' '12' '9,6'
#  '10,8' '13,5' '12,1' '11,4' '11,3' '15' '14' '15,7' '18,1' '11,2' '8,9'
#  '7,1' '7,8' '12,8' '11,1' '11,7' '13,2' '13' '10,7' '15,3' '10,3' '5,9'
#  '8,6' '13,8' '15,4' '0,1' '8,1' '12,9' '14,2' '7,7' '6,7' '5,4' '5,7'
#  '5,2' '7,4' '8,8' '10' '9,3' '6,9' '10,4' '11,5' '9,9' '5,3' '4,4' '6,3'
#  '3,2' '8,4' '10,9' '6,4' '11' '10,1' '6,1' '10,2' '10,6' '11,9' '7,5' '8'
#  '6,2' '3,6' '4,2' '5' '13,3' '9,8' '8,2' '0,7' '4' '-1,8' '-0,6' '4,6'
#  '-1' '1,2' '5,6' '1,8' '7' '1,7' '-2,5' '-0,8' '0,3' '-0,3' '1,9' '0,4'
#  '2' '5,5' '2,4' '-0,4' '-0,7' '1,1' '1,3' '0,6' '2,3' '2,6' '7,6' '3'
#  '4,8' '2,9' '4,1' '6,5' '6' '8,5' '9' '1,4' '3,4' '1,5' '-0,1' '4,5'
#  '13,9' '4,3' '8,3' '6,8' '14,8' '3,1' '14,9' '14,5' '15,1' '16,1' '15,2'
#  '16,4' '16,2' '14,3' '16,3' '19' '16' '16,8' '18,9' '3,7' '17,9' '15,5'
#  '14,1' '16,7' '14,7' '13,4' '13,7' '12,2' '14,4' '10,5' '9,1' '3,3' '2,7'
#  '0' '3,5' '3,9' '17,1' '15,8' '18,2' '19,3' '17,5' '19,1' '17,6' '0,5'
#  '17' '3,8' '-0,2' '-2,1' '-1,5' '2,8' '17,2' '17,7' '17,8' '1' '0,8'
#  '-0,5' '-3,4' '-1,6' '-1,4' '-1,1' '17,3' '-2,3' '-0,9' '-2,8' '-4,1'
#  '-5,7' '-4,8' '-4,9' '-4,3' '-3,6' '-2,7' '2,2' '20,7' '20,8' '18,7'
#  '17,4']
# min_DewPoint[°C] : ['8,8' '8' '7,4' '-4,7' '1,5' '3,6' '13,7' '6,3' '10,6' '-2,5' '0' '4,5'
#  '-1,8' '-0,9' '4' '5,2' '4,3' '13,6' '17' '6' '4,9' '-4,5' '2,3' '-6,1'
#  '-1,6' '-10,7' '0,8' '7' '13' '15,4' '15,2' '14,9' '9,7' '10,8' '9,1'
#  '7,9' '6,6' '11,4' '10,1' '8,7' '9,4' '11' '12,3' '10,9' '12' '2,6' '6,4'
#  '2,8' '2' '1,2' '9,6' '5' '8,9' '10,7' '12,5' '11,2' '6,7' '1,4' '-2,9'
#  '2,9' '-5,1' '9,2' '9,5' '7,6' '1,9' '2,1' '-2,7' '2,2' '5,6' '8,4' '5,8'
#  '-0,5' '-1,2' '6,5' '7,1' '5,3' '0,5' '1,7' '-0,8' '4,4' '7,3' '5,9'
#  '-2,8' '7,7' '3,7' '2,7' '6,2' '5,5' '3,4' '8,5' '7,2' '4,2' '4,8' '5,7'
#  '6,8' '5,1' '6,1' '10' '-0,6' '4,7' '1' '1,8' '11,1' '10,4' '5,4' '3,2'
#  '-1,5' '-7,9' '-0,4' '4,1' '-1,4' '-9,8' '-12,7' '-8,3' '-3,9' '1,6'
#  '-4,2' '-0,7' '-5,6' '-5,8' '-3,7' '-0,3' '-1' '-2,4' '3,1' '-0,2' '-4,1'
#  '-5,2' '-5,7' '-2,2' '-2,3' '-2,1' '-7,3' '-9,1' '0,3' '0,4' '1,3' '3'
#  '0,6' '9,3' '-1,3' '0,1' '2,4' '-1,1' '6,9' '-1,7' '-6,3' '-7' '7,8'
#  '11,8' '12,2' '4,6' '-3' '0,9' '11,7' '3,8' '-0,1' '12,1' '14,2' '11,3'
#  '12,4' '12,6' '13,3' '7,5' '11,5' '13,9' '14,7' '13,4' '14,5' '16,3'
#  '17,5' '17,1' '8,1' '-14,7' '-5' '-6,5' '16,2' '16,1' '12,8' '9,8' '13,1'
#  '9,9' '-8,2' '10,5' '10,3' '12,7' '8,6' '11,9' '10,2' '3,3' '9' '3,9'
#  '8,3' '12,9' '2,5' '1,1' '8,2' '0,7' '-1,9' '-2,6' '15,9' '15,6' '13,5'
#  '-5,9' '11,6' '3,5' '15,5' '18,2' '-5,3' '14,3' '16' '-11,5' '0,2' '15,7'
#  '14,1' '-4,6' '-3,1' '-3,2' '-6,6' '-3,6' '15,8' '15' '13,8' '-3,4'
#  '-3,8' '-3,5' '-4,3' '-4,8' '-7,2' '-9,4' '-4,9' '-4' '14,8' '15,3'
#  '14,4' '13,2' '-6' '-2' '-9,6' '-9,5' '-6,7' '-7,7' '-6,2' '-5,5' '-8,1'
#  '19,9' '19,8' '17,3' '17,9' '17,2']
# moy_VPD[kPa] : ['1,9' '1,73' '2,56' '4,55' '3,97' '3,99' '2,41' '2,13' '1,65' '2,35'
#  '3,7' '4,44' '4,92' '4,46' '4,26' '3,39' '2,85' '1,66' '1,45' '2,3'
#  '2,91' '3,29' '4,16' '4,33' '3,72' '4,22' '3,63' '3,77' '3,55' '2,52'
#  '1,42' '0,92' '1,04' '1' '1,41' '1,11' '1,22' '1,35' '0,95' '0,74' '0,87'
#  '1,03' '0,9' '0,77' '1,29' '2,99' '3,27' '4,36' '3,49' '2,75' '1,81'
#  '1,62' '1,67' '1,36' '1,07' '0,82' '0,8' '0,6' '1,4' '1,54' '0,93' '0,49'
#  '2,19' '2,57' '1,94' '1,13' '0,65' '0,46' '4,41' '2,93' '1,68' '1,46'
#  '1,12' '1,19' '2,21' '2,02' '2,03' '1,52' '1,23' '1,01' '0,09' '0,08'
#  '1,27' '0,63' '0,54' '0,31' '0,18' '0,47' '0,33' '0,29' '0,7' '0,36'
#  '0,38' '0,91' '1,39' '1,31' '0,73' '0,42' '0,22' '0,35' '1,51' '0,5'
#  '0,34' '0,05' '0,37' '0,04' '0,41' '0,39' '0,3' '0,21' '0,07' '0,2'
#  '0,48' '0,27' '0,19' '0,13' '0,01' '0,02' '0,12' '0,32' '0,45' '0,24'
#  '0,28' '0,25' '0,62' '0,55' '0,11' '0,71' '1,57' '1,28' '0,57' '0,81'
#  '0,69' '0,4' '0,59' '0,88' '0,86' '0,61' '1,15' '0,98' '1,06' '0,67'
#  '0,26' '0,68' '0,56' '0,44' '0,14' '0,03' '0,64' '0,85' '0,76' '0,84'
#  '0,15' '0,17' '0,1' '0,06' '0,83' '0,53' '0,43' '0,23' '0,97' '0,78'
#  '1,25' '1,1' '1,7' '1,97' '1,49' '1,34' '1,63' '1,3' '1,93' '1,76' '1,5'
#  '2,25' '1,33' '1,44' '1,8' '1,98' '1,08' '0,72' '1,2' '1,18' '0,96'
#  '0,89' '0,66' '1,85' '2,86' '2,17' '1,91' '3,18' '3,14' '0,99' '0,79'
#  '1,05' '2,1' '1,96' '3,09' '3,32' '4,77' '4,98' '4,03' '1,38' '1,14'
#  '1,72' '1,21' '1,99' '2,73' '1,59' '1,24' '2,15' '2,14' '3,17' '2,82'
#  '2,09' '2,43' '2,48' '2,8' '2,64' '1,95' '2,37' '4,58' '5,12' '3,26'
#  '1,69' '1,6' '2,23' '1,61' '1,47' '0,75' '1,88' '2,65' '2,33' '1,71'
#  '1,16' '1,55' '0,51' '0' '0,16' '0,94' '1,17' '0,52' '1,74' '1,26' '1,87'
#  '1,84' '2,67' '1,37' '1,83' '1,92' '2,18' '2,31' '2,28' '2,88' '2,92'
#  '2,5' '4,02' '4,42' '2,49' '2,45' '1,58' '1,32' '2,08' '3,11' '3,28'
#  '2,63' '2,29' '2,24' '3,07' '3,8' '2,94' '2,36' '2,66' '3,21' '2,16'
#  '3,08' '4,81' '3,59' '1,89' '2,34' '1,78' '1,43' '1,75' '2,95' '2,38'
#  '2,01' '0,58' '2,07' '2,12' '3,1' '1,79' '1,02' '1,77' '2,68' '2,42'
#  '3,42' '3,48' '2,44' '2,4' '2,06' '1,64' '1,53' '1,56' '2,84' '2,54'
#  '2,32' '2,62' '1,09' '2' '1,48' '1,82' '2,26' '2,83' '3,23' '2,81' '2,71'
#  '3,13' '3,65' '3,56' '3,43' '3,38' '4,17' '2,59' '2,79' '2,74' '2,51'
#  '3,06']
# min_VPD[kPa] : ['0,3' '0' '0,95' '1,7' '1,39' '1,17' '0,24' '0,48' '0,06' '0,84' '1,52'
#  '1,9' '1,88' '1,5' '1,73' '1,08' '0,56' '0,15' '0,01' '0,21' '0,91'
#  '1,19' '1,54' '1,86' '1,29' '1,11' '1,18' '0,94' '0,38' '0,11' '0,19'
#  '0,04' '0,28' '0,76' '1,51' '2,13' '1,06' '0,13' '0,12' '0,02' '0,31'
#  '0,08' '0,69' '0,62' '1,49' '0,05' '0,18' '0,49' '0,67' '0,6' '0,39'
#  '0,14' '0,09' '0,43' '0,65' '0,33' '0,27' '0,29' '0,25' '0,34' '0,03'
#  '0,1' '0,07' '0,26' '0,23' '0,42' '0,66' '0,74' '0,55' '0,44' '0,51'
#  '0,85' '0,41' '0,78' '0,58' '0,59' '0,2' '0,17' '0,64' '0,83' '1,23'
#  '0,5' '0,47' '1,25' '1,28' '2,04' '0,37' '0,61' '0,57' '1,07' '0,75'
#  '0,16' '2,48' '0,53' '0,22' '0,52' '0,4' '0,45' '0,63' '0,54' '0,36'
#  '0,8' '0,98' '0,68' '0,96' '0,87' '1,68' '0,93' '0,92' '0,89' '0,71'
#  '1,24' '1,05' '0,79' '1,09' '0,72' '1,1' '1,27' '0,35' '0,81' '1,16'
#  '0,73' '1,22' '0,32' '0,88' '1' '0,46' '0,97' '0,7' '0,86' '1,2' '0,99'
#  '1,97' '1,26' '1,36' '1,01' '1,04' '1,48' '1,13' '1,66']
# moy_RelativeHumidity[%] : ['51,87' '59,06' '38,43' ... '58,5' '53,43' '30,93']
# max_RelativeHumidity[%] : ['83,3' '99,54' '65,76' '38,56' '47,56' '59,15' '89,44' '75,35' '96,16'
#  '66,26' '40,44' '35,32' '37,49' '39,73' '40,65' '52,04' '72,94' '92,49'
#  '99,39' '90,74' '65,97' '59,88' '44,39' '39,26' '48,36' '37,37' '46,77'
#  '50,53' '58,42' '80,37' '99,37' '99,45' '99,26' '99,35' '81,51' '99,2'
#  '99,3' '99,32' '91,33' '88,21' '99,23' '99,38' '99,41' '96,83' '83,51'
#  '90,49' '99,31' '99,56' '99,22' '71,9' '57,37' '33,9' '56,28' '92,64'
#  '91,98' '98,7' '81,01' '99,58' '99,43' '99,28' '95,03' '94,36' '98,63'
#  '69,77' '59,48' '90,63' '99,6' '99,77' '93,57' '42,74' '99,21' '96,3'
#  '99,51' '90,81' '68,26' '62,47' '59,24' '74,58' '87,22' '99,72' '99,71'
#  '99,24' '96,28' '99,42' '99,62' '99,49' '99,66' '99,27' '91,3' '66,95'
#  '99,47' '99,61' '99,68' '99,7' '99,64' '99,75' '99,74' '99,55' '99,57'
#  '99,78' '99,5' '99,36' '99,44' '99,73' '99,69' '99,65' '99,33' '99,4'
#  '99,76' '99,48' '54,27' '69,04' '95,01' '99,34' '78,57' '98,94' '91,41'
#  '82,71' '94,87' '85,36' '99,67' '71,22' '65,74' '63,3' '75,39' '68,92'
#  '65,58' '79,89' '71,59' '87,57' '96,42' '70,91' '84,55' '86,87' '98,54'
#  '95,48' '98,69' '96,49' '99,46' '90,36' '98,45' '99,63' '89,74' '95,83'
#  '77,16' '98,52' '90,19' '87,94' '99,29' '99,59' '99,52' '82,65' '78,68'
#  '96,29' '91,02' '71,67' '87,44' '86,45' '90,61' '95,22' '98,12' '99,15'
#  '98,61' '76,7' '88,05' '92,28' '80,1' '80,26' '86,92' '63,6' '78,43'
#  '67,4' '52,15' '55,68' '70,17' '80,86' '68,32' '97,57' '93,18' '53,45'
#  '74,9' '86,41' '78,52' '55,86' '58,48' '84,9' '84,54' '63,69' '72,17'
#  '89,36' '96,09' '85,35' '88,66' '91,5' '88,99' '99,25' '74,71' '70,08'
#  '88,95' '98,03' '68,65' '57,54' '70,1' '95,9' '98,62' '89,38' '97,98'
#  '98,73' '74,14' '70,89' '71,52' '51,6' '54,39' '44,47' '39,71' '79,04'
#  '94,23' '82,43' '84,42' '74,28' '84,75' '93,95' '95,88' '86,06' '79,58'
#  '82,23' '72,07' '99,13' '70,04' '75,6' '64,98' '71,77' '75,8' '77,67'
#  '68,74' '71,53' '73,74' '65,29' '63,77' '87,9' '59,79' '34,85' '55,21'
#  '75,55' '94,13' '96,64' '90,54' '69,29' '97,85' '87,45' '74,39' '90,28'
#  '99,12' '94,75' '93,01' '90,06' '89,59' '88,03' '68,66' '70,19' '94,74'
#  '86,68' '98,43' '97,09' '75,67' '73,31' '89,99' '99,53' '98,17' '96,8'
#  '87,2' '71,95' '85,85' '75,43' '88,88' '87,38' '67,58' '67,45' '68,83'
#  '77,07' '98,66' '79,88' '93,9' '80,87' '85,51' '61,88' '61,56' '92,02'
#  '97,7' '96,52' '81,56' '96,95' '83,68' '74,75' '66,31' '61,89' '82,07'
#  '98,67' '96,94' '81,91' '78,07' '93,36' '84,16' '60,32' '50,18' '75,11'
#  '88,18' '91,66' '89,69' '86,7' '93,38' '90,07' '80,21' '70,72' '58,89'
#  '68,39' '64,72' '63,17' '54,83' '69,96' '72,77' '82,04' '96,92' '84,06'
#  '46,8' '46' '58,47' '53,8' '71,41' '57,44' '66,46' '82,62' '84,67' '94,3'
#  '88,36' '95,71' '91,39' '96,18' '93,4' '86,39' '88,98' '84,03' '68,3'
#  '70,47' '52,42' '56,22' '69,25' '93,71' '86,75' '82,16' '82' '84,44'
#  '91,35' '97,51' '94,8' '83,06' '67,84' '81,48' '63,43' '56,05' '65,25'
#  '68,98' '95,15' '61,8' '72,37' '94,7' '69,35' '38,43' '51,91' '74,43'
#  '75,13' '93,47' '86,65' '82,45' '86,71' '95,68' '92,86' '96,4' '73,57'
#  '78,15' '93,8' '95,25' '93,82' '87,69' '92,68' '90,08' '97,41' '95,82'
#  '75,85' '83' '52,22' '39,95' '84,72' '76,16' '79,16' '66,6' '65,81'
#  '66,21' '82,96' '96,68' '98,08' '98,77' '79,97' '71,01' '77,81' '95,85'
#  '97,53' '99,02' '92,03' '98,97' '75,19' '58,72' '94,08' '99,11' '92,44'
#  '93,43' '97' '85,81' '89,1' '71,88' '70,12' '77,09' '64,11' '78,67'
#  '84,96' '82,53' '93,55' '75,36' '58,16' '60,15' '64,2' '85,14' '82,64'
#  '80,67' '98,15' '87,93' '92,8' '91,94' '93,21' '94,68' '79,84' '94,38'
#  '74,94' '88,84' '85,21' '89,2' '93,2' '88,26' '79,98' '95,79' '83,01'
#  '80,91' '78,26' '71,36' '67,91' '66,85' '55,57' '77,08' '97,59' '97,37'
#  '69,54' '53,42' '79,18' '76,9' '86,66' '94,79' '72,82' '78,03' '71,1'
#  '71,5' '66,56' '78,79' '86,3' '83,42' '73,15' '63,7' '74,98' '84,83'
#  '81,94' '74,55' '95,84' '92,71' '69,62' '89,4' '90,8' '92,93' '91,83'
#  '92,65' '86,89' '85,56' '90,45' '91,37' '89,41' '97,3' '98,78' '98,34'
#  '97,47' '95,62' '83,52' '91,47' '96,55' '97,21' '93,56' '90,9' '93,3'
#  '90,69' '89,33' '96,74' '98,18' '96,87' '92,62' '96,99' '98,48' '88,72'
#  '87,68' '92' '91,52' '82,22' '88,1' '88,15' '88,34' '89,23' '90,21'
#  '90,29' '91,53' '97,25' '90,78' '89,55' '95,6' '90,97' '87,49' '87,33'
#  '58,25' '55,4' '47,51' '59,02' '53,57' '78,8' '65,86' '66,65' '97,27'
#  '79,37' '59,82' '59,98' '65,22' '81,98' '84,77' '88,09' '94,57' '93,6'
#  '91,14' '82,5' '82,41' '89,01' '76,52' '75,7' '93,31' '89,87' '84,26'
#  '87,19' '75,33' '75,06' '96,25' '92,73' '98,72' '95,55' '93,88' '96,89'
#  '87,18' '88,8' '86,05' '91,2' '93,37' '90,66' '93,78' '98,2' '99,16'
#  '91,58' '92,2' '92,67' '97,45' '97,13' '98,44' '98,81' '97,99' '77,49'
#  '72,11' '61,9' '80,43' '92,84' '82,61' '77,65' '74,25' '76,94' '68,91'
#  '93,44' '90,82' '79,66' '88,89' '91,72' '92,85' '85,23' '91,22' '84,17'
#  '93,96' '98,11' '96,37' '96,2' '95,89' '93,68' '96,35' '68,56' '75,66'
#  '89,15' '92,43' '83,77' '73,34' '78,28' '79,81' '75,09' '87,04' '78,06'
#  '79,76' '66,41' '88,11' '91,87' '87,97' '89' '99,03' '80,47' '68,12'
#  '92,46' '77,31' '66,51' '45,16' '61,5' '66,91' '62,27' '37,61' '88,25'
#  '85,91' '89,43' '93,48' '95,97' '98,25' '98,01' '92,6' '91,05' '83,27'
#  '91,64' '77,34' '74,73' '92,78' '93,85' '98,46' '97,43' '97,86' '91,81'
#  '96,19' '87,1' '93,13' '84,11' '94,62' '98,57' '94,41' '98,92' '97,58'
#  '93,61' '96,66' '99,05' '97,06' '96,9' '97,42' '95,43' '95,67' '93,7'
#  '92,22' '91,57' '98,33' '98,35' '97,35' '94,95' '96,93' '99,09' '96,73'
#  '98,82' '98,23' '98,3' '97,74' '98,24' '98,05' '97,49' '96,43' '98,58'
#  '98,96' '97,5' '89,62' '97,89' '95,96' '97,23' '98,49' '94,64' '96,84'
#  '94,26' '89,73' '98,84' '98,98' '97,29' '99,14' '98,5' '99,17' '98,41'
#  '90' '90,7' '96,11' '88,04' '96,75' '85,58' '98,4' '97,62' '89,66'
#  '88,08' '78,96' '84,51' '91,93' '91,86' '98,36' '95,11' '51,33' '56,46'
#  '45,06' '34,47' '32,85' '39,8' '42,2' '48,27' '48,58' '54,1' '54,53'
#  '59,11' '68,97' '85,63' '87,46' '79,08' '95,93' '92,97' '75,99' '71,56'
#  '95,78' '85,02' '84,34' '81,73' '80,59' '58,12' '59,55' '53,37' '60,76'
#  '68,72' '80,23' '97,92' '94,53' '67,95' '47,31' '33,77' '36,49' '44,64'
#  '39,36' '43,41' '54,38' '53,4' '63,16' '57,34' '73,5' '74,85' '66,45'
#  '74,56' '90,24' '93,17' '85,99' '81,03' '75,92' '84,53' '84,95' '87,62'
#  '86,85' '96,47' '96,85' '79,9' '69' '56,73' '63,92' '55,44' '77,15'
#  '74,99' '69,31' '68,01' '60,93' '56,89' '61,86' '32,73']
# min_RelativeHumidity[%] : ['22' '19,84' '23,6' ... '57,18' '51,64' '56,71']
# Somme_Precipitation[mm] : ['0' '0,2' '1,4' '9,8' '4,2' '0,6' '1,8' '1' '0,8' '17,8' '5,4' '6,2'
#  '3,8' '7' '12,4' '3,6' '10,4' '11,4' '2,8' '10,2' '2,2' '0,4' '7,4' '1,2'
#  '2,4' '8,2' '10,8' '20,6' '2' '5,6' '3,2' '6' '7,8' '7,2' '2,6' '1,6'
#  '3,4' '5' '11,2' '13,6' '20,2' '9,4' '7,6' '10' '8,4' '5,2' '4,4' '14,8'
#  '6,6' '19,2' '9,2' '17' '8' '3' '6,8' '25,6' '13,4' '4,6' '4' '26,2'
#  '4,8' '14,4' '15,4' '16' '20' '9,6' '6,4' '12,2' '14' '13,2' '16,4'
#  '40,2' '25' '8,8' '9' '15,2' '22,4' '18,4' '12,8' '29,8' '15,6' '8,6'
#  '18,8' '14,2' '15,8' '19,6' '21,2' '28' '5,8']
# moy_WindSpeed[m/s] : ['0,5' '0,6' '0,7' '0,9' '0,8' '1,1' '1,2' '1' '1,4' '1,7' '1,6' '2' '1,5'
#  '1,3' '0,3' '0,4' '0,2' '0,1' '1,9' '1,8' '2,6' '2,2' '2,3' '3' '2,4'
#  '2,1' '2,9' '3,2' '3,6' '2,8' '0' nan]
# max_WindSpeed[m/s] : ['2,1' '1,7' '2,6' '2,3' '2,7' '2,4' '1,8' '2,2' '2,9' '3,1' '4,3' '3'
#  '2,8' '3,7' '2,5' '1,6' '1,9' '3,4' '4,8' '3,5' '4,2' '5,1' '2' '4,4' '4'
#  '3,3' '4,6' '3,2' '3,9' '4,1' '1,4' '5,9' '1,5' '1,3' '1,2' '4,7' '3,8'
#  '3,6' '0,8' '1,1' '1' '0,9' '5,3' '5,7' '5,2' '7,1' '4,5' '6,2' '4,9'
#  '7,7' '5,6' '0' '0,5' nan]
# max_WindSpeedMax[m/s] : ['4,4' '5,3' '6,6' '6,7' '5' '3,8' '5,6' '6,5' '9,4' '7,8' '4,5' '5,4' '8'
#  '6' '5,5' '4,7' '5,7' '4,3' '7,4' '4,2' '4,8' '5,1' '21' '5,9' '6,1'
#  '8,4' '22,1' '4,9' '6,2' '16,1' '9,8' '11,9' '9,6' '4,6' '9,1' '3,9'
#  '8,7' '5,2' '7,1' '8,1' '6,8' '7,5' '9,5' '8,2' '5,8' '7,3' '7' '3,4'
#  '10,3' '11,4' '7,9' '9,3' '6,9' '4' '3,3' '8,5' '4,1' '10,5' '11,3' '8,8'
#  '3,1' '3,6' '3,5' '3,2' '3,7' '2,4' '2,6' '2,5' '2,9' '3' '6,4' '9,2'
#  '15' '14,3' '6,3' '7,2' '2,8' '1,4' '9,7' '2,3' '8,3' '7,6' '12,7' '10,2'
#  '2,7' '7,7' '16,8' '8,9' '9' '9,9' '8,6' '10' '11,2' '10,8' '14' '12,6'
#  '1,9' '10,4' '13,3' '16,3' '14,2' '11,8' '15,3' '12,8' '17,1' '10,9' nan]
# ETP quotidien [mm] : [nan '5' '5,3' '5,5' '5,4' '5,1' '5,9' '6,3' '5,8' '5,7' '4,4' '5,2' '6'
#  '6,7' '5,6' '4,7' '4,8' '4,6' '4,9' '4,5' '4,3' '6,1' '4,1' '2,7' '2,9'
#  '6,6' '3,7' '6,5' '4,2' '2' '1,9' '4' '2,5' '2,1' '3,9' '2,8' '3,4' '3,5'
#  '3,3' '3,1' '1,7' '1,1' '3' '1,6' '1,4' '2,6' '1' '1,2' '2,4' '1,8' '2,2'
#  '2,3' '1,5' '1,3' '0,9' '0,7' '0,6' '0,8' '3,2' '3,6' '3,8' '6,4' '6,2'
#  '7' '6,9' '7,9' '7,3' '8' '0,5']
# <ipython-input-111-11c93a301c25>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   feat_with_object_dtype=data.select_dtypes(np.object).columns

# %% [markdown]
# When we checked unique values in our data feature we find some feature with some irregular values.So we need to normalize them. This is the ['max_WindSpeedMax[m/s]','max_WindSpeed[m/s]','ETP quotidien [mm]','moy_WindSpeed[m/s]'] list of feature with irregular values

# %% [markdown]
# ### **Removing Irregular Data Values in the Features**

# %%
feat_with_wrong_inputs=['max_WindSpeedMax[m/s]','max_WindSpeed[m/s]','ETP quotidien [mm]','moy_WindSpeed[m/s]']
for feature in feat_with_wrong_inputs:
    #data[feature]=data[feature].apply(lambda x:str(x))
    data[feature]=data[feature].apply(lambda x: 0 if len(str(x))>3 else x)

# %%
data.isnull().sum()/data.shape[0]
# Out:
# Date/heure                    0.000000
# moy_Temp[°C]                  0.000000
# max_Temp[°C]                  0.000000
# min_Temp[°C]                  0.000000
# moy_DewPoint[°C]              0.000000
# min_DewPoint[°C]              0.000000
# moy_SolarRadiation[W/m2]      0.000000
# moy_VPD[kPa]                  0.000000
# min_VPD[kPa]                  0.000000
# moy_RelativeHumidity[%]       0.000000
# max_RelativeHumidity[%]       0.000000
# min_RelativeHumidity[%]       0.000000
# Somme_Precipitation[mm]       0.000000
# moy_WindSpeed[m/s]            0.001123
# max_WindSpeed[m/s]            0.001123
# max_WindSpeedMax[m/s]         0.057833
# moy_WindDirection[deg]        0.998877
# dernier_WindDirection[deg]    0.998877
# ETP quotidien [mm]            0.003369
# dtype: float64

# %% [markdown]
# ### **Missing Values Imputation**

# %%
feat_with_miss_val=['moy_WindSpeed[m/s]','max_WindSpeed[m/s]','max_WindSpeedMax[m/s]','ETP quotidien [mm]']
for feature in feat_with_miss_val:
    data[feature].fillna(0,inplace=True)

# %% [markdown]
# ### **Dropping Data Features**

# %% [markdown]
# If a data feature contains null values more than 30 percent then it is good to drop that feature otherwise that feature can alter final output. So we are going to drop two data feature.
#
# - moy_WindDirection[deg]
# - dernier_WindDirection[deg]

# %%
data.drop(['moy_WindDirection[deg]','dernier_WindDirection[deg]'],axis=1,inplace=True)

# %% [markdown]
# Becaue our data feature contain numerical values in form of string so we need to convert them in numerical form.

# %%
for feature in data.select_dtypes(np.object).columns[1:]:
    data[feature]=data[feature].apply(lambda x:re.sub(',','.',str(x)))
    data[feature]=pd.to_numeric(data[feature])
# Out:
# <ipython-input-116-1bf18c0e0077>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   for feature in data.select_dtypes(np.object).columns[1:]:

# %% [markdown]
# # **Regularized Data Types**

# %%
data.dtypes
# Out:
# Date/heure                   object
# moy_Temp[°C]                float64
# max_Temp[°C]                float64
# min_Temp[°C]                float64
# moy_DewPoint[°C]            float64
# min_DewPoint[°C]            float64
# moy_SolarRadiation[W/m2]      int64
# moy_VPD[kPa]                float64
# min_VPD[kPa]                float64
# moy_RelativeHumidity[%]     float64
# max_RelativeHumidity[%]     float64
# min_RelativeHumidity[%]     float64
# Somme_Precipitation[mm]     float64
# moy_WindSpeed[m/s]          float64
# max_WindSpeed[m/s]          float64
# max_WindSpeedMax[m/s]       float64
# ETP quotidien [mm]          float64
# dtype: object

# %% [markdown]
# ### **Extracting Day,Month,Year From Date Feature**

# %%
data['Date/heure']=data['Date/heure'].apply(lambda x:str(x).split()[0])
data['Date/heure']=pd.to_datetime(data['Date/heure'])
data['year']=data['Date/heure'].dt.year
data['month']=data['Date/heure'].dt.month
data['day']=data['Date/heure'].dt.day
data.drop(['Date/heure'],axis=1,inplace=True)

# %% [markdown]
# ### **Feature Correlation**

# %%
plt.figure(figsize=(20,10))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Correlation: It is measurement of effect of one feature upon other feature. Its value lies between -1,1. 1 or positive values for more correlated(light boxes) and -1 or negative values for not correlated(dark boxes) feature

# %% [markdown]
# ### **Normalized Data**

# %%
data
# Out:
#       moy_Temp[°C]  max_Temp[°C]  min_Temp[°C]  moy_DewPoint[°C]  \
# 0            24.73         35.08         15.11              12.4
# 1            25.26         35.79         16.40              14.6
# 2            28.37         36.71         19.80              12.3
# 3            32.17         43.43         19.68               0.9
# 4            32.30         41.90         21.26               8.7
# ...            ...           ...           ...               ...
# 1776         26.19         27.22         25.43              19.0
# 1777         26.21         26.42         25.51              17.4
# 1778         26.31         26.47         26.10              16.0
# 1779         23.58         23.92         22.89              14.9
# 1780         21.87         22.60         20.94               3.8
#
#       min_DewPoint[°C]  moy_SolarRadiation[W/m2]  moy_VPD[kPa]  min_VPD[kPa]  \
# 0                  8.8                       361          1.90          0.30
# 1                  8.0                       288          1.73          0.00
# 2                  7.4                       285          2.56          0.95
# 3                 -4.7                       296          4.55          1.70
# 4                  1.5                       290          3.97          1.39
# ...                ...                       ...           ...           ...
# 1776              17.9                         0          1.18          1.04
# 1777              17.2                         0          1.40          1.28
# 1778              15.3                         0          1.58          1.48
# 1779              14.1                         2          1.20          1.13
# 1780               3.4                        93          1.81          1.66
#
#       moy_RelativeHumidity[%]  max_RelativeHumidity[%]  \
# 0                       51.87                    83.30
# 1                       59.06                    99.54
# 2                       38.43                    65.76
# 3                       16.44                    38.56
# 4                       26.68                    47.56
# ...                       ...                      ...
# 1776                    65.12                    68.01
# 1777                    58.50                    60.93
# 1778                    53.43                    56.89
# 1779                    58.56                    61.86
# 1780                    30.93                    32.73
#
#       min_RelativeHumidity[%]  Somme_Precipitation[mm]  moy_WindSpeed[m/s]  \
# 0                       22.00                      0.0                 0.5
# 1                       19.84                      0.0                 0.6
# 2                       23.60                      0.0                 0.7
# 3                        5.23                      0.0                 0.6
# 4                        9.52                      0.0                 0.6
# ...                       ...                      ...                 ...
# 1776                    57.11                      5.4                 0.0
# 1777                    57.18                      0.0                 0.0
# 1778                    51.64                      0.0                 0.0
# 1779                    56.71                      0.0                 0.0
# 1780                    29.15                      0.0                 0.0
#
#       max_WindSpeed[m/s]  max_WindSpeedMax[m/s]  ETP quotidien [mm]  year  \
# 0                    2.1                    4.4                 0.0  2022
# 1                    1.7                    5.3                 5.0  2022
# 2                    2.6                    5.3                 5.3  2022
# 3                    2.3                    6.6                 5.3  2022
# 4                    2.7                    6.7                 5.5  2022
# ...                  ...                    ...                 ...   ...
# 1776                 0.5                    0.0                 0.6  2017
# 1777                 0.0                    0.0                 0.0  2017
# 1778                 0.0                    0.0                 0.0  2017
# 1779                 0.0                    0.0                 0.0  2017
# 1780                 0.0                    0.0                 0.0  2016
#
#       month  day
# 0         5    8
# 1         4    8
# 2         3    8
# 3         2    8
# 4         1    8
# ...     ...  ...
# 1776      4    9
# 1777      6    6
# 1778      5    6
# 1779     10    4
# 1780     10   11
#
# [1781 rows x 19 columns]

# %% [markdown]
# # **Data Visualization**

# %%
avg_temps=data.groupby(['year']).mean()

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['moy_Temp[°C]'],color='blue')
plt.title('Average moy_Temp[°C] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_Temp[°C] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['max_Temp[°C]'])
plt.title('Average moy_Temp[°C] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_Temp[°C] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['min_Temp[°C]'],color='green')
plt.title('Average min_Temp[°C] over the years')
# Out:
# Text(0.5, 1.0, 'Average min_Temp[°C] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['moy_DewPoint[°C]'],color='purple')
plt.title('Average moy_DewPoint[°C] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_DewPoint[°C] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['min_DewPoint[°C]'])
plt.title('Average min_DewPoint[°C] over the years')
# Out:
# Text(0.5, 1.0, 'Average min_DewPoint[°C] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['moy_SolarRadiation[W/m2]'],color='red')
plt.title('Average moy_SolarRadiation[W/m2] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_SolarRadiation[W/m2] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['moy_VPD[kPa]'],color='purple')
plt.title('Average moy_VPD[kPa] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_VPD[kPa] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['min_VPD[kPa]'])
plt.title('Average min_VPD[kPa] over the years')
# Out:
# Text(0.5, 1.0, 'Average min_VPD[kPa] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['moy_RelativeHumidity[%]'],color='violet')
plt.title('Average moy_RelativeHumidity[%] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_RelativeHumidity[%] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['max_RelativeHumidity[%]'],color='green')
plt.title('Average max_RelativeHumidity[%] over the years')
# Out:
# Text(0.5, 1.0, 'Average max_RelativeHumidity[%] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['min_RelativeHumidity[%]'],color='black')
plt.title('Average min_RelativeHumidity[%] over the years')
# Out:
# Text(0.5, 1.0, 'Average min_RelativeHumidity[%] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['Somme_Precipitation[mm]'])
plt.title('Average Somme_Precipitation[mm] over the years')
# Out:
# Text(0.5, 1.0, 'Average Somme_Precipitation[mm] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['moy_WindSpeed[m/s]'],color='blue')
plt.title('Average moy_WindSpeed[m/s] over the years')
# Out:
# Text(0.5, 1.0, 'Average moy_WindSpeed[m/s] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['max_WindSpeed[m/s]'],color='green')
plt.title('Average max_WindSpeed[m/s] over the years')
# Out:
# Text(0.5, 1.0, 'Average max_WindSpeed[m/s] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['max_WindSpeedMax[m/s]'])
plt.title('Average max_WindSpeedMax[m/s] over the years')
# Out:
# Text(0.5, 1.0, 'Average max_WindSpeedMax[m/s] over the years')

# %%
sns.lineplot(x=avg_temps.index,y=avg_temps['ETP quotidien [mm]'],color='purple')
plt.title('Average ETP quotidien [mm] over the years')
# Out:
# Text(0.5, 1.0, 'Average ETP quotidien [mm] over the years')

# %% [markdown]
# # **Hypothesis Testing**

# %% [markdown]
# ---
# ### lets try to find out impact of idependent features(X) on target feature y(ETP quotidien [mm]).
# ---

# %% [markdown]
# # **Null Hypothesis:**
# There is no significant impact of independent features (X) on target feature ('ETP quotidien [mm]')

# %% [markdown]
# # **Alternate Hypothesis:**
# There is significant impact of independent features (X) on target feature ('ETP quotidien [mm]')

# %% [markdown]
# # **ETP quotidien [mm]** stands for "Evapotranspiration Potentielle quotidienne in millimeters" in French.
# It is a measure of the amount of water that could potentially be evaporated and transpired by a crop or vegetation in a day, assuming there is sufficient water available. ETP is an important factor in determining crop water requirements and irrigation scheduling. It is typically estimated using empirical equations that take into account factors such as temperature, humidity, wind speed, and solar radiation.

# %%
y=data['ETP quotidien [mm]']

# %%
columns=data.drop(['ETP quotidien [mm]'],axis=1).columns

# %%
in_significant_feat=[]

# %% [markdown]
# ### **Applying T-Test**

# %%
import scipy.stats as stats

for col in columns:
    t_stat, p_value = stats.ttest_ind(data[col],y)
    if p_value < 0.05:
        print("Reject null hypothesis. There is a significant impact of "+col+" on "+"ETP quotidien [mm]")
    else:
        print("Fail to reject null hypothesis. There is no significant impact of "+col+" on "+"ETP quotidien [mm]")
        in_significant_feat.append(col)
# Out:
# Reject null hypothesis. There is a significant impact of moy_Temp[°C] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of max_Temp[°C] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of min_Temp[°C] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of moy_DewPoint[°C] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of min_DewPoint[°C] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of moy_SolarRadiation[W/m2] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of moy_VPD[kPa] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of min_VPD[kPa] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of moy_RelativeHumidity[%] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of max_RelativeHumidity[%] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of min_RelativeHumidity[%] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of Somme_Precipitation[mm] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of moy_WindSpeed[m/s] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of max_WindSpeed[m/s] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of max_WindSpeedMax[m/s] on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of year on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of month on ETP quotidien [mm]
# Reject null hypothesis. There is a significant impact of day on ETP quotidien [mm]

# %% [markdown]
# # **Drop Insignificant Feautures**

# %%
in_significant_feat
# there is no insignificant input feature to drop
# Out:
# []

# %% [markdown]
# # **Separating Dependent and Independent Feature**

# %%
X=data.drop(['ETP quotidien [mm]'],axis=1)
y=data['ETP quotidien [mm]']

# %% [markdown]
# # **Data Scalling by MinMax Scaler**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X= scaler.fit_transform(X)

# %% [markdown]
# # **Note!**
# Fortunately or unfortunately there is not categorical features present in our selected data.
# This data is selected because it has mis-typed data that needs sufficient problem solving
# and data handling skills.

# %% [markdown]
# # **Model Preparation**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y) #splitting data into training and testin

# %%
# Applying Multiple Models
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# Importing evaluation modules
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# check the performance on diffrent regressor
models = []
models.append(('LinearRegression', LinearRegression()))
models.append(('KNeighborsRegressor', KNeighborsRegressor()))

train_l = []
test_l = []
mae_l = []
rmse_l = []
r2_l = []

import time
i = 0
for name,model in models:
    i = i+1
    start_time = time.time()
    
    # Fitting model to the Training set
    regressor = model
    regressor.fit(X_train, y_train)
    
    # Scores of model
    train = model.score(X_train, y_train)
    test = model.score(X_test, y_test)
    
    train_l.append(train)
    test_l.append(test)
    
    # predict values
    predictions = regressor.predict(X_test)
    # RMSE
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_l.append(rmse)
    # MAE
    mae = mean_absolute_error(y_test,predictions)
    mae_l.append(mae)
    # R2 score
    r2 = r2_score(y_test,predictions)
    r2_l.append(r2)
    
    # Plot the linear regression line
    plt.scatter(predictions.reshape(-1), y_test, color='black')
    


    print("+","="*100,"+")
    print('\033[1m' + f"\t\t\t{i}-For {name} The Performance result is: " + '\033[0m')
    print("+","="*100,"+")
    print('Root mean squared error (RMSE) : ', rmse)   
    print("-"*50)
    print('Mean absolute error (MAE) : ', mae)
    print("-"*50)
    print('R2 score : ', r2)
    print("-"*50)
    print("\t\t\t\t\t\t\t-----------------------------------------------------------")
    print(f"\t\t\t\t\t\t\t Time for detection ({name}) : {round((time.time() - start_time), 3)} seconds...")
    print("\t\t\t\t\t\t\t-----------------------------------------------------------")
    print()
    
comp = pd.DataFrame({"Training Score": train_l, "Testing Score": test_l, "MAE": mae_l, "RMSE": rmse_l, "R2 Score": r2_l})
comp
# Out:
# + ==================================================================================================== +
# 			1-For LinearRegression The Performance result is:
# + ==================================================================================================== +
# Root mean squared error (RMSE) :  0.25560976127745433
# --------------------------------------------------
# Mean absolute error (MAE) :  0.1973204587247147
# --------------------------------------------------
# R2 score :  0.9773119475532944
# --------------------------------------------------
# 							-----------------------------------------------------------
# 							 Time for detection (LinearRegression) : 0.039 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			2-For KNeighborsRegressor The Performance result is:
# + ==================================================================================================== +
# Root mean squared error (RMSE) :  0.39856243919519024
# --------------------------------------------------
# Mean absolute error (MAE) :  0.2599103139013453
# --------------------------------------------------
# R2 score :  0.9448386248864916
# --------------------------------------------------
# 							-----------------------------------------------------------
# 							 Time for detection (KNeighborsRegressor) : 0.187 seconds...
# 							-----------------------------------------------------------
#    Training Score  Testing Score      MAE      RMSE  R2 Score
# 0        0.966530       0.977312  0.19732  0.255610  0.977312
# 1        0.969719       0.944839  0.25991  0.398562  0.944839
