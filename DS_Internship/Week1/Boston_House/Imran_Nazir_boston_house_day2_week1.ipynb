# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading

# %%
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

# %%
train_df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
from sklearn.ensemble import RandomForestRegresssor
from sklearn.model_selection import GridSearchCV, train_test_split

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]
}

# Create the Random Forest Classifier
rf_classifier = RandomForestRegressor()

# Perform grid search with cross-validation
grid_search = GridSearchCV(rf_classifier, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best Score: 0.850394198670342

# %%
X_train=train_df.drop(["ID","medv"],axis=1)
y_train=train_df["medv"]

# %%
X_test=test_df.drop(['ID'],axis=1)

# %%
rf_regressor = RandomForestRegressor(max_depth=10,max_features='sqrt',
                                     min_samples_leaf=1,min_samples_split=2, n_estimators=200)

# %%
rf_regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_features='sqrt', n_estimators=200)

# %%
prediction=rf_regressor.predict(X_test)

# %%
prediction
# Out:
# array([33.95357717, 27.95310332, 17.26280322, 16.73013426, 18.67390004,
#        18.90557903, 20.07937979, 16.81384126, 16.5898084 , 17.94610151,
#        18.449739  , 20.0946103 , 16.1940524 , 14.79743552, 22.61686831,
#        22.20175341, 23.01992454, 28.47415226, 18.07675486, 25.21869846,
#        21.95514518, 23.7995515 , 22.01818794, 22.14261484, 21.27142389,
#        22.0166399 , 24.31625466, 23.78142194, 23.7812938 , 26.9150076 ,
#        40.29483339, 40.11329294, 31.69323546, 19.87348377, 17.97292893,
#        20.77226228, 19.05740563, 17.95667276, 19.40582413, 19.88237884,
#        16.40033864, 18.82289133, 19.25541762, 17.11545486, 16.11334513,
#        14.44974164, 15.41918961, 16.22664688, 19.77443646, 21.06985963,
#        17.9431406 , 33.33593949, 46.309375  , 21.35148919, 25.39506889,
#        26.2207769 , 30.53973376, 44.66514583, 35.84627839, 33.14299106,
#        31.61313643, 41.4439375 , 20.37030098, 18.61888054, 20.07629701,
# ...
