# %% [markdown]
# # Installing Dependencies

# %%
# !pip install -q neattext
# !pip install -q pandas
# Out:
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import neattext as nt

# %% [markdown]
# # Reading the Dataset

# %%
df=pd.read_csv('Amz-Products-Data-2023-03-13-ProductFinder.csv')
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (46,50,51,66,67,68,91,92,93,96,100,101,104,105,106,107,108,109,141,162,166,167,172,173,184,185,242,243,249,267,268,269,271,272,273) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # View of Dataset

# %%
df.head(2)
# Out:
#   Locale                                              Image  \
# 0    com  https://images-na.ssl-images-amazon.com/images...
# 1    com  https://images-na.ssl-images-amazon.com/images...
#
#                                                Title  Sales Rank: Current  \
# 0  Mademark x Daria - Quinn - VP of the Fashion C...             113514.0
# 1  Disney Men's Cars 3 Lightning McQueen Graphic ...             113883.0
#
#    Sales Rank: 30 days avg.  Sales Rank: 90 days avg.  \
# 0                  112719.0                  109131.0
# 1                  128709.0                  126036.0
#
#    Sales Rank: 180 days avg. Sales Rank: 30 days drop %  \
# 0                   107231.0                       -1 %
# 1                   134081.0                       12 %
#
#   Sales Rank: 90 days drop %  Sales Rank: Lowest  ...  \
# 0                       -4 %               95572  ...
# 1                       10 %               20363  ...
#
#    One Time Coupon: Absolute  One Time Coupon: Percentage  \
# 0                          -                            -
# 1                          -                            -
#
#    Subscribe and Save Coupon: Percentage  Buy Box Used 🚚: Lowest  \
# 0                                      -                     NaN
# 1                                      -                     NaN
#
#   Buy Box Used 🚚: Highest Buy Box Used Seller  Buy Box Used: Is FBA  \
# 0                     NaN                 NaN                    no
# 1                     NaN                 NaN                    no
#
#    Buy Box Used: Condition  New, Prime exclusive: Lowest  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
#
#    New, Prime exclusive: Highest
# 0                            NaN
# 1                            NaN
#
# [2 rows x 274 columns]

# %%
titles=' '.join(df.Title)

# %%
titles=nt.remove_stopwords(titles)
titles=nt.remove_shortwords(titles,3)
titles=nt.remove_numbers(titles)
titles=nt.remove_special_characters(titles)

# %%
from collections import Counter
cnt=Counter()

# %%
import nltk
from nltk import word_tokenize

# tokenize your text into a list of words
text =titles
tokens = word_tokenize(text)

# generate bigrams and trigrams
bigrams = list(nltk.bigrams(tokens))

print("Bigrams:", bigrams)
# Out:
# Bigrams: [('Mademark', 'Daria'), ('Daria', 'Quinn'), ('Quinn', 'Fashion'), ('Fashion', 'Club'), ('Club', 'Shirt'), ('Shirt', 'Disney'), ('Disney', 'Cars'), ('Cars', 'Lightning'), ('Lightning', 'McQueen'), ('McQueen', 'Graphic'), ('Graphic', 'Shirt'), ('Shirt', 'Charcoal'), ('Charcoal', 'Medium'), ('Medium', 'Patricks'), ('Patricks', 'Shamrock'), ('Shamrock', 'Baseball'), ('Baseball', 'Saint'), ('Saint', 'Paddys'), ('Paddys', 'Kids'), ('Kids', 'Boys'), ('Boys', 'Shirt'), ('Shirt', 'Drop'), ('Drop', 'Women'), ('Women', 'Cora'), ('Cora', 'Shirt'), ('Shirt', 'Dress'), ('Dress', 'Black'), ('Black', 'Funny'), ('Funny', 'Merry'), ('Merry', 'Patrick'), ('Patrick', 'Biden'), ('Biden', 'Leprechaun'), ('Leprechaun', 'Shirt'), ('Shirt', 'Amateur'), ('Amateur', 'Sketch'), ('Sketch', 'Mobile'), ('Mobile', 'Alabama'), ('Alabama', 'Leprechaun'), ('Leprechaun', 'Patrick'), ('Patrick', 'Shirt'), ('Shirt', 'yr'), ('yr', 'BDay'), ('BDay', 'Funny'), ('Funny', 'Gamer'), ('Gamer', 'th'), ('th', 'Year'), ('Year', 'Birthday'), ('Birthday', 'Shirt'), ('Shirt', 'Shenanigans'), ('Shenanigans', 'Squad'), ('Squad', 'Shirt'), ('Shirt', 'Saint'), ('Saint', 'Patricks'), ('Patricks', 'Shirt'), ('Shirt', 'Life'), ('Life', 'Good'), ('Good', 'Women'), ('Women', 'Standard'), ('Standard', 'Crusher'), ('Crusher', 'Graphic'), ('Graphic', 'Shirt'), ('Shirt', 'Watercolor'), ('Watercolor', 'Daisy'), ('Daisy', 'Birds'), ('Birds', 'Darkest'), ('Darkest', 'Blue'), ('Blue', 'Large'), ('Large', 'Life'), ('Life', 'Good'), ('Good', 'Women'), ('Women', 'Standard'), ('Standard', 'Crusher'), ('Crusher', 'Graphic'), ('Graphic', 'Shirt'), ('Shirt', 'Watercolor'), ('Watercolor', 'Daisy'), ('Daisy', 'Birds'), ('Birds', 'Cloud'), ('Cloud', 'White'), ('White', 'Medium'), ('Medium', 'Level'), ('Level', 'Unlocked'), ('Unlocked', 'Awesome'), ('Awesome', 'th'), ('th', 'Birthday'), ('Birthday', 'Gaming'), ('Gaming', 'Shirt'), ('Shirt', 'Harry'), ('Harry', 'Potter'), ('Potter', 'Hufflepuff'), ('Hufflepuff', 'Symbol'), ('Symbol', 'Line'), ('Line', 'Shirt'), ('Shirt', 'Year'), ('Year', 'Gifts'), ('Gifts', 'Vintage'), ('Vintage', 'Limited'), ('Limited', 'Edition'), ('Edition', 'th'), ('th', 'Birthday'), ('Birthday', 'Shirt'), ('Shirt', 'Patricks'), ('Patricks', 'Shamrock'), ('Shamrock', 'Baseball'), ('Baseball', 'Saint'), ('Saint', 'Paddy'), ('Paddy', 'Kids'), ('Kids', 'Boys'), ('Boys', 'Shirt'), ('Shirt', 'Nintendo'), ('Nintendo', 'Yoshi'), ('Yoshi', 'Shirt'), ('Shirt', 'Medium'), ('Medium', 'Black'), ('Black', 'Liquid'), ('Liquid', 'Blue'), ('Blue', 'unisex'), ('unisex', 'adult'), ('adult', 'Creedence'), ('Creedence', 'Clearwater'), ('Clearwater', 'Revival'), ('Revival', 'Travelin'), ('Travelin', 'Band'), ('Band', 'shirt'), ('shirt', 'Shirt'), ('Shirt', 'Grey'), ('Grey', 'Medium'), ('Medium', 'Christians'), ('Christians', 'Cute'), ('Cute', 'Silly'), ('Silly', 'Rabbit'), ('Rabbit', 'Easter'), ('Easter', 'Jesus'), ('Jesus', 'Shirt'), ('Shirt', 'Calvin'), ('Calvin', 'Klein'), ('Klein', 'Relaxed'), ('Relaxed', 'Logo'), ('Logo', 'Crewneck'), ('Crewneck', 'Shirt'), ('Shirt', 'Black'), ('Black', 'Beauty'), ('Beauty', 'Brilliant'), ('Brilliant', 'White'), ('White', 'Medium'), ('Medium', 'Life'), ('Life', 'Good'), ('Good', 'Women'), ('Women', 'Crusher'), ('Crusher', 'Graphic'), ('Graphic', 'Neck'), ('Neck', 'Shirt'), ('Shirt', 'Floral'), ('Floral', 'Jars'), ('Jars', 'Darkest'), ('Darkest', 'Blue'), ('Blue', 'Small'), ('Small', 'Life'), ('Life', 'Good'), ('Good', 'Women'), ('Women', 'Crusher'), ('Crusher', 'Graphic'), ('Graphic', 'Neck'), ('Neck', 'Shirt'), ('Shirt', 'Floral'), ('Floral', 'Jars'), ('Jars', 'Darkest'), ('Darkest', 'Blue'), ('Blue', 'Large'), ('Large', 'Alternative'), ('Alternative', 'Jersey'), ('Jersey', 'Crew'), ('Crew', 'Shirt'), ('Shirt', 'Warm'), ('Warm', 'Gold'), ('Gold', 'Large'), ('Large', 'Funny'), ('Funny', 'Novelty'), ('Novelty', 'Shirt'), ('Shirt', 'Sarcasm'), ('Sarcasm', 'Intelligence'), ('Intelligence', 'Test'), ('Test', 'Ness'), ('Ness', 'funny'), ('funny', 'joke'), ('joke ...

# %%
cnt.update(bigrams)
cnt
# Out:
# Counter({('Mademark', 'Daria'): 3,
#          ('Daria', 'Quinn'): 3,
#          ('Quinn', 'Fashion'): 3,
#          ('Fashion', 'Club'): 3,
#          ('Club', 'Shirt'): 6,
#          ('Shirt', 'Disney'): 606,
#          ('Disney', 'Cars'): 3,
#          ('Cars', 'Lightning'): 12,
#          ('Lightning', 'McQueen'): 12,
#          ('McQueen', 'Graphic'): 3,
#          ('Graphic', 'Shirt'): 768,
#          ('Shirt', 'Charcoal'): 171,
#          ('Charcoal', 'Medium'): 21,
#          ('Medium', 'Patricks'): 9,
#          ('Patricks', 'Shamrock'): 42,
#          ('Shamrock', 'Baseball'): 9,
#          ('Baseball', 'Saint'): 9,
#          ('Saint', 'Paddys'): 9,
#          ('Paddys', 'Kids'): 3,
#          ('Kids', 'Boys'): 66,
#          ('Boys', 'Shirt'): 117,
#          ('Shirt', 'Drop'): 12,
#          ('Drop', 'Women'): 12,
#          ('Women', 'Cora'): 12,
#          ('Cora', 'Shirt'): 12,
#          ('Shirt', 'Dress'): 12,
#          ('Dress', 'Black'): 12,
#          ('Black', 'Funny'): 3,
#          ('Funny', 'Merry'): 3,
#          ('Merry', 'Patrick'): 9,
#          ('Patrick', 'Biden'): 6,
#          ('Biden', 'Leprechaun'): 9,
#          ('Leprechaun', 'Shirt'): 33,
#          ('Shirt', 'Amateur'): 9,
#          ('Amateur', 'Sketch'): 6,
#          ('Sketch', 'Mobile'): 9,
#          ('Mobile', 'Alabama'): 9,
#          ('Alabama', 'Leprechaun'): 3,
#          ('Leprechaun', 'Patrick'): 9,
#          ('Patrick', 'Shirt'): 336,
#          ('Shirt', 'yr'): 30,
#          ('yr', 'BDay'): 33,
#          ('BDay', 'Funny'): 48,
#          ('Funny', 'Gamer'): 57,
#          ('Gamer', 'th'): 27,
#          ('th', 'Year'): 33,
#          ('Year', 'Birthday'): 57,
#          ('Birthday', 'Shirt'): 384,
#          ('Shirt', 'Shenanigans'): 105,
#          ('Shenanigans', 'Squad'): 45,
#          ('Squad', 'Shirt'): 27,
#          ('Shirt', 'Saint'): 63,
#          ('Saint', 'Patricks'): 54,
#          ('Patricks', 'Shirt'): 267,
#          ('Shirt', 'Life'): 162,
#          ('Life', 'Good'): 312,
#          ('Good', 'Women'): 213,
#          ('Women', 'Standard'): 102,
#          ('Standard', 'Crusher'): 81,
#          ('Crusher', 'Graphic'): 300,
#          ('Shirt', 'Watercolor'): 72,
#          ('Watercolor', 'Daisy'): 72,
#          ('Daisy', 'Birds'): 36,
#          ('Birds', 'Darkest'): 18,
#          ('Darkest', 'Blue'): 75,
#          ('Blue', 'Large'): 96,
#          ('Large', 'Life'): 90,
#          ('Birds', 'Cloud'): 18,
#          ('Cloud', 'White'): 39,
#          ('White', 'Medium'): 51,
#          ('Medium', 'Level'): 12,
#          ('Level', 'Unlocked'): 84,
#          ('Unlocked', 'Awesome'): 18,
#          ('Awesome', 'th'): 18,
#          ('th', 'Birthday'): 333,
#          ('Birthday', 'Gaming'): 18,
#          ('Gaming', 'Shirt'): 21,
#          ('Shirt', 'Harry'): 51,
#          ('Harry', 'Potter'): 75,
#          ('Potter', 'Hufflepuff'): 12,
#          ('Hufflepuff', 'Symbol'): 3,
#          ('Symbol', 'Line'): 6,
#          ('Line', 'Shirt'): 6,
#          ('Shirt', 'Year'): 33,
#          ('Year', 'Gifts'): 66,
#          ('Gifts', 'Vintage'): 21,
#          ('Vintage', 'Limited'): 48,
#          ('Limited', 'Edition'): 54,
#          ('Edition', 'th'): 18,
#          ('Shirt', 'Patricks'): 153,
#          ('Saint', 'Paddy'): 15,
#          ('Paddy', 'Kids'): 9,
#          ('Shirt', 'Nintendo'): 189,
#          ('Nintendo', 'Yoshi'): 21,
#          ('Yoshi', 'Shirt'): 18,
#          ('Shirt', 'Medium'): 81,
#          ('Medium', 'Black'): 9,
#          ('Black', 'Liquid'): 18,
#          ('Liquid', 'Blue'): 567,
#          ('Blue', 'unisex'): 183,
#          ('unisex', 'adult'): 279,
#          ('adult', 'Creedence'): 21,
#          ('Creedence', 'Clearwater'): 21,
#          ('Clearwater', 'Revival'): 21,
#          ('Revival', 'Travelin'): 15,
#          ('Travelin', 'Band'): 15,
#          ('Band', 'shirt'): 15,
#          ('shirt', 'Shirt'): 447,
#          ('Shirt', 'Grey'): 39,
#          ('Grey', 'Medium'): 21,
#          ('Medium', 'Christians'): 3,
#          ('Christians', 'Cute'): 3,
#          ('Cute', 'Silly'): 3,
#          ('Silly', 'Rabbit'): 15,
#          ('Rabbit', 'Easter'): 21,
#          ('Easter', 'Jesus'): 18,
#          ('Jesus', 'Shirt'): 18,
#          ('Shirt', 'Calvin'): 9,
#          ('Calvin', 'Klein'): 45,
#          ('Klein', 'Relaxed'): 45,
#          ('Relaxed', 'Logo'): 45,
#          ('Logo', 'Crewneck'): 45,
#          ('Crewneck', 'Shirt'): 48,
#          ('Shirt', 'Black'): 747,
#          ('Black', 'Beauty'): 27,
#          ('Beauty', 'Brilliant'): 9,
#          ('Brilliant', 'White'): 24,
#          ('Medium', 'Life'): 21,
#          ('Women', 'Crusher'): 99,
#          ('Graphic', 'Neck'): 123,
#          ('Neck', 'Shirt'): 462,
#          ('Shirt', 'Floral'): 33,
#          ('Floral', 'Jars'): 30,
#          ('Jars', 'Darkest'): 15,
#          ('Blue', 'Small'): 48,
#          ('Small', 'Life'): 27,
#          ('Large', 'Alternative'): 15,
#          ('Alternative', 'Jersey'): 6,
#          ('Jersey', 'Crew'): 9,
#          ('Crew', 'Shirt'): 39,
#          ('Shirt', 'Warm'): 3,
#          ('Warm', 'Gold'): 3,
#          ('Gold', 'Large'): 18,
#          ('Large', 'Funny'): 27,
#          ('Funny', 'Novelty'): 6,
#          ('Novelty', 'Shirt'): 6,
#          ('Shirt', 'Sarcasm'): 3,
#          ('Sarcasm', 'Intelligence'): 3,
#          ('Intelligence', 'Test'): 3,
#          ('Test', 'Ness'): 3,
#          ('Ness', 'funny'): 3,
#          ('funny', 'joke'): 3,
#          ('joke', 'Shirt'): 3,
#          ('Shirt', 'Funny'): 414,
#          ('Funny', 'Chess'): 3,
#          ('Chess', 'Gift'): 3,
#          ('Gift', 'Chess'): 3,
#          ('Chess', 'Lover'): 3,
#          ('Lover', 'Kids'): 3,
#          ('Boys', 'Girls'): 135,
#          ('Girls', 'Cool'): 3,
#          ('Cool', 'Player'): 3,
#          ('Player', 'Shirt'): 33,
#          ('Shirt', 'Capybara'): 3,
#          ('Capybara', 'Mugshot'): 3,
#          ('Mugshot', 'Wanted'): 3,
#          ('Wanted', 'Felonies'): 3,
#          ('Felonies', 'Country'): 3,
#          ('Country', 'Shirt'): 6,
#          ('Shirt', 'Identify'): 6,
#          ('Identify', 'Conspiracy'): 3,
#          ('Conspiracy', 'Theorist'): 6,
#          ('Theorist', 'Pronouns'): 6,
#          ('Pronouns', 'Told'): 6,
#          ('Told', 'Shirt'): 9,
#          ('Shirt', 'Talk'): 9,
#          ('Talk', 'Chickens'): 3,
#          ('Chickens', 'Shirt'): 3,
#          ('Shirt', 'Cute'): 105,
#          ('Cute', 'Chicken'): 3,
#          ('Chicken', 'Buffs'): 3,
#          ('Buffs', 'Gift'): 3,
#          ('Gift', 'Shirt'): 417,
#          ('Shirt', 'Mens'): 159,
#          ('Mens', 'Father'): 9,
#          ('Father', 'Gift'): 12,
#          ('Gift', 'Uncle'): 3,
#          ('Uncle', 'Myth'): 3,
#          ('Myth', 'Influence'): 3,
#          ('Influence', 'Shirt'): 3,
#          ('Shirt', 'Hello'): 24,
#          ('Hello', 'Kitty'): 24,
#          ('Kitty', 'Friends'): 3,
#          ('Friends', 'Sanrio'): 3,
#          ('Sanrio', 'Rainbow'): 3,
#          ('Rainbow', 'Shirt'): 27,
#          ('Shirt', 'Cricut'): 3,
#          ('Cricut', 'unisex'): 3,
#          ('adult', 'shirt'): 3,
#          ('shirt', 'BLANK'): 3,
#          ('BLANK', 'TSHIRT'): 3,
#          ('TSHIRT', 'White'): 3,
#          ('White', 'Large'): 141,
#          ('Large', 'John'): 3,
#          ('John', 'Cena'): 3,
#          ('Cena', 'Champ'): 3,
#          ('Champ', 'Shirt'): 3,
#          ('Shirt', 'Dabbing'): 27,
#          ('Dabbing', 'Banana'): 3,
#          ('Banana', 'Wearing'): 3,
#          ('Wearing', 'Sunglasses'): 3,
#          ('Sunglasses', 'Dance'): 3,
#          ('Dance', 'Girl'): 3,
#          ('Girl', 'Mens'): 3,
#          ('Mens', 'Kids'): 3,
#          ('Kids', 'Shirt'): 219,
#          ('Mens', 'Waffle'): 3,
#          ('Waffle', 'Crewneck'): 3,
#          ('Shirt', 'Shirt'): 822,
#          ('Shirt', 'Bright'): 30,
#          ('Bright', 'Aloe'): 3,
#          ('Aloe', 'Global'): 3,
#          ('Global', 'Large'): 3,
#          ('Large', 'Grey'): 3,
#          ('Grey', 'Heather'): 18,
#          ('Heather', 'Lucky'): 3,
#          ('Lucky', 'Simple'): 9,
#          ('Simple', 'Blessed'): 9,
#          ('Blessed', 'Leopard'): 12,
#          ('Leopard', 'Glitter'): 3,
#          ('Glitter', 'Patrick'): 3,
#          ('Patrick', 'Irish'): 60,
#          ('Irish', 'Shirt'): 108,
#          ('Shirt', 'Womens'): 270,
#          ('Womens', 'Disney'): 33,
#          ('Disney', 'Minnie'): 57,
#          ('Minnie', 'Mouse'): 75,
#          ('Mouse', 'Icon'): 12,
#          ('Icon', 'Green'): 3,
#          ('Green', 'Shamrocks'): 6,
#          ('Shamrocks', 'Patrick'): 9,
#          ('Patrick', 'Neck'): 12,
#          ('Disney', 'Villains'): 18,
#          ('Villains', 'Maleficent'): 6,
#          ('Maleficent', 'Shirt'): 3,
#          ('Shirt', 'Shrek'): 12,
#          ('Shrek', 'Check'): 3,
#          ('Check', 'Shrek'): 3,
#          ('Shrek', 'Shirt'): 3,
#          ('Shirt', 'Naruto'): 18,
#          ('Naruto', 'Shippuden'): 27,
#          ('Shippuden', 'Heads'): 3,
#          ('Heads', 'Shirt'): 3,
#          ('Shirt', 'Liquid'): 342,
#          ('Blue', 'Pink'): 9,
#          ('Pink', 'Floyd'): 48,
#          ('Floyd', 'Dark'): 42,
#          ('Dark', 'Paint'): 3,
#          ('Paint', 'Short'): 3,
#          ('Short', 'Sleeve'): 705,
#          ('Sleeve', 'Shirt'): 522,
#          ('Shirt', 'Multi'): 138,
#          ('Multi', 'Large'): 81,
#          ('Large', 'Hard'): 3,
#          ('Hard', 'Fast'): 3,
#          ('Fast', 'Turn'): 3,
#          ('Turn', 'Left'): 3,
#          ('Left', 'Funny'): 3,
#          ('Funny', 'Baseball'): 12,
#          ('Baseball', 'Player'): 15,
#          ('Womens', 'Slainte'): 15,
#          ('Slainte', 'green'): 3,
#          ('green', 'shamrock'): 3,
#          ('shamrock', 'clover'): 3,
#          ('clover', 'Patricks'): 3,
#          ('Patricks', 'Neck'): 24,
#          ('Shirt', 'Problem'): 9,
#          ('Problem', 'Groovy'): 6,
#          ('Groovy', 'Retro'): 12,
#          ('Retro', 'Shirt'): 48,
#          ('Shirt', 'birthday'): 6,
#          ('birthday', 'Shirt'): 18,
#          ('Shirt', 'Play'): 6,
#          ('Play', 'Video'): 3,
#          ('Video', 'Games'): 24,
#          ('Games', 'Funny'): 6,
#          ('Gamer', 'Boys'): 24,
#          ('Boys', 'Teens'): 3,
#          ('Teens', 'Shirt'): 18,
#          ('Shirt', 'Kids'): 324,
#          ('Kids', 'Kwazii'): 3,
#          ('Kwazii', 'Cute'): 3,
#          ('Cute', 'Funny'): 6,
#          ('Funny', 'Pirate'): 3,
#          ('Pirate', 'Kids'): 3,
#          ('Shirt', 'Trump'): 9,
#          ('Trump', 'Vintage'): 3,
#          ('Vintage', 'Donald'): 6,
#          ('Donald', 'Trump'): 3,
#          ('Trump', 'July'): 3,
#          ('July', 'Shirt'): 9,
#          ('Daisy', 'Trees'): 36,
#          ('Trees', 'Black'): 15,
#          ('Black', 'Small'): 129,
#          ('Trees', 'Cloud'): 21,
#          ('Large', 'Disney'): 75,
#          ('Disney', 'Peter'): 18,
#          ('Peter', 'Skull'): 3,
#          ('Skull', 'Rock'): 3,
#          ('Rock', 'Vintage'): 3,
#          ('Vintage', 'Graphic'): 21,
#          ('Disney', 'Mickey'): 99,
#          ('Mickey', 'Friends'): 63,
#          ('Friends', 'Minnie'): 12,
#          ('Mouse', 'Classic'): 6,
#          ('Classic', 'Portrait'): 3,
#          ('Portrait', 'Neck'): 12,
#          ('Shirt', 'Courage'): 6,
#          ('Courage', 'Cowardly'): 6,
#          ('Cowardly', 'Girl'): 6,
#          ('Girl', 'Courage'): 6,
#          ('Courage', 'Logo'): 6,
#          ('Logo', 'Shirt'): 435,
#          ('Small', 'Bruce'): 3,
#          ('Bruce', 'Retro'): 6,
#          ('Retro', 'Style'): 9,
#          ('Style', 'Vintage'): 6,
#          ('Vintage', 'Distressed'): 9,
#          ('Distressed', 'Shirt'): 21,
#          ('adult', 'Rock'): 15,
#          ('Rock', 'Eruption'): 15,
#          ('Eruption', 'Short'): 15,
#          ('Sleeve', 'shirt'): 90,
#          ('Small', 'Lucky'): 6,
#          ('Lucky', 'Lepricorn'): 3,
#          ('Lepricorn', 'Unicorn'): 3,
#          ('Unicorn', 'Patricks'): 12,
#          ('Shirt', 'Totally'): 3,
#          ('Totally', 's'): 3,
#          ('s', 'Vintage'): 6,
#          ('Vintage', 'Eighties'): 3,
#          ('Eighties', 'Costume'): 3,
#          ('Costume', 'Party'): 30,
#          ('Party', 'shirt'): 6,
#          ('Shirt', 'Local'): 6,
#          ('Local', 'Dealer'): 6,
#          ('Dealer', 'Funny'): 6,
#          ('Funny', 'Bleached'): 6,
#          ('Bleached', 'Chicken'): 6,
#          ('Chicken', 'Lover'): 9,
#          ('Lover', 'Farm'): 6,
#          ('Farm', 'Farmer'): 6,
#          ('Farmer', 'Shirt'): 9,
#          ('Shirt', 'Taylor'): 12,
#          ('Taylor', 'Thing'): 3,
#          ('Thing', 'understand'): 3,
#          ('understand', 'Shirt'): 3,
#          ('Shirt', 'Father'): 12,
#          ('Father', 'Papa'): 3,
#          ('Papa', 'Grandpa'): 9,
#          ('Grandpa', 'Funny'): 3,
#          ('Funny', 'Dada'): 3,
#          ('Dada', 'Shirt'): 9,
#          ('Shenanigans', 'Coordinator'): 60,
#          ('Coordinator', 'Shirt'): 21,
#          ('Shirt', 'Teacher'): 12,
#          ('Teacher', 'Patricks'): 30,
#          ('Shirt', 'Sham'): 6,
#          ('Sham', 'Rock'): 3,
#          ('Rock', 'Funny'): 3,
#          ('Funny', 'Patricks'): 96,
#          ('Shirt', 'Shamrock'): 30,
#          ('Shamrock', 'Guitar'): 3,
#          ('Guitar', 'Shirt'): 21,
#          ('Shirt', 'Kryptek'): 24,
#          ('Kryptek', 'Standard'): 36,
#          ('Standard', 'Hyperion'): 33,
#          ('Hyperion', 'Short'): 33,
#          ('Sleeve', 'Lightweight'): 33,
#          ('Lightweight', 'Breathable'): 33,
#          ('Breathable', 'Stealthy'): 33,
#          ('Stealthy', 'Camo'): 33,
#          ('Camo', 'Hunting'): 45,
#          ('Hunting', 'Fishing'): 33,
#          ('Fishing', 'Shirt'): 54,
#          ('Shirt', 'Highlander'): 12,
#          ('Highlander', 'Large'): 18,
#          ('Large', 'Kryptek'): 21,
#          ('Large', 'Teacher'): 3,
#          ('Teacher', 'Life'): 6,
#          ('Life', 'Messy'): 12,
#          ('Messy', 'Happy'): 3,
#          ('Happy', 'School'): 3,
#          ('School', 'Teacher'): 3,
#          ('Teacher', 'Shirt'): 66,
#          ('Shirt', 'Prince'): 6,
#          ('Prince', 'unisex'): 3,
#          ('adult', 'Casual'): 9,
#          ('Casual', 'Shirt'): 15,
#          ('Black', 'Medium'): 126,
#          ('Medium', 'Mens'): 18,
#          ('Mens', 'Irish'): 3,
#          ('Irish', 'Blessing'): 6,
#          ('Blessing', 'Funny'): 3,
#          ('Shirt', 'Inch'): 3,
#          ('Inch', 'Nails'): 3,
#          ('Nails', 'Adult'): 3,
#          ('Adult', 'Short'): 3,
#          ('Charcoal', 'Logo'): 3,
#          ('Logo', 'Medium'): 3,
#          ('Medium', 'Kanagawa'): 3,
#          ('Kanagawa', 'Japanese'): 3,
#          ('Japanese', 'great'): 3,
#          ('great', 'wave'): 3,
#          ('wave', 'shirt'): 3,
#          ('shirt', 'Disney'): 6,
#          ('Disney', 'Caballeros'): 6,
#          ('Caballeros', 'Classic'): 3,
#          ('Classic', 'Shirt'): 90,
#          ('Patricks', 'Golf'): 3,
#          ('Golf', 'Golfing'): 3,
#          ('Golfing', 'Irish'): 3,
#          ('Irish', 'Golfer'): 3,
#          ('Golfer', 'Beer'): 3,
#          ('Beer', 'Humor'): 3,
#          ('Humor', 'Shirt'): 27,
#          ('Disney', 'Years'): 15,
#          ('Years', 'Wonder'): 12,
#          ('Wonder', 'Mickey'): 6,
#          ('Mickey', 'Pals'): 6,
#          ('Pals', 'Muted'): 3,
#          ('Muted', 'Cute'): 9,
#          ('Cute', 'D'): 9,
#          ('D', 'Shirt'): 18,
#          ('Shirt', 'Lucky'): 102,
#          ('Lucky', 'Patricks'): 21,
#          ('Shamrock', 'Shirt'): 132,
#          ('Shirt', 'Women'): 81,
#          ('Women', 'Girls'): 39,
#          ('Girls', 'Shirt'): 135,
#          ('Funny', 'March'): 3,
#          ('March', 'Birthday'): 15,
#          ('Birthday', 'Month'): 6,
#          ('Month', 'Birthday'): 3,
#          ('Shirt', 'Foxes'): 3,
#          ('Foxes', 'World'): 3,
#          ('World', 'Funny'): 3,
#          ('Funny', 'Animals'): 3,
#          ('Animals', 'Educational'): 3,
#          ('Educational', 'Shirt'): 3,
#          ('Funny', 'Leprechaun'): 27,
#          ('Leprechaun', 'Dibs'): 3,
#          ('Dibs', 'Redhead'): 24,
#          ('Redhead', 'Irish'): 3,
#          ('Irish', 'Patrick'): 30,
#          ('Mouse', 'Leopard'): 3,
#          ('Leopard', 'Print'): 21,
#          ('Print', 'Premium'): 3,
#          ('Premium', 'Shirt'): 84,
#          ('Shirt', 'Nightmare'): 3,
#          ('Nightmare', 'Street'): 3,
#          ('Street', 'Freddy'): 3,
#          ('Freddy', 'Follow'): 3,
#          ('Follow', 'Dreams'): 3,
#          ('Dreams', 'Shirt'): 12,
#          ('Women', 'Kids'): 99,
#          ('Kids', 'Toddler'): 18,
#          ('Toddler', 'Math'): 3,
#          ('Math', 'Teacher'): 51,
#          ('Teacher', 'Cutie'): 3,
#          ('Cutie', 'Shirt'): 6,
#          ('Shirt', 'th'): 78,
#          ('Birthday', 'Sign'): 9,
#          ('Sign', 'Shirt'): 18,
#          ('Shirt', 'Years'): 75,
#          ('Years', 'Women'): 3,
#          ('Shirt', 'Happy'): 102,
#          ('Happy', 'Patricks'): 42,
#          ('Patricks', 'Birthday'): 18,
#          ('Birthday', 'Born'): 6,
#          ('Born', 'Irish'): 3,
#          ('Irish', 'Bday'): 3,
#          ('Bday', 'Gift'): 6,
#          ('Shirt', 'Marvel'): 153,
#          ('Marvel', 'Punisher'): 21,
#          ('Punisher', 'Sweat'): 18,
#          ('Sweat', 'Shirt'): 9,
#          ('Black', 'Large'): 474,
#          ('Large', 'Marvel'): 33,
#          ('Marvel', 'mens'): 3,
#          ('mens', 'Marvel'): 3,
#          ('Sweat', 'shirt'): 9,
#          ('Medium', 'Happy'): 3,
#          ('Happy', 'Patrick'): 39,
#          ('Irish', 'Shamrock'): 84,
#          ('Shamrock', 'Matching'): 3,
#          ('Matching', 'Group'): 18,
#          ('Group', 'Cute'): 3,
#          ('Cute', 'Shirt'): 18,
#          ('Shirt', 'Hudson'): 18,
#          ('Hudson', 'Baby'): 42,
#          ('Baby', 'Unisex'): 42,
#          ('Unisex', 'Baby'): 42,
#          ('Baby', 'Premium'): 21,
#          ('Premium', 'Quilted'): 21,
#          ('Quilted', 'Coveralls'): 21,
#          ('Coveralls', 'Blush'): 3,
#          ('Blush', 'Rose'): 3,
#          ('Rose', 'Leopard'): 3,
#          ('Leopard', 'Months'): 3,
#          ('Months', 'Womens'): 6,
#          ('Womens', 'Star'): 12,
#          ('Star', 'Wars'): 522,
#          ('Wars', 'Mandalorian'): 90,
#          ('Mandalorian', 'Patrick'): 3,
#          ('Patrick', 'Gold'): 6,
#          ('Gold', 'Neck'): 3,
#          ('Disney', 'Emperor'): 3,
#          ('Emperor', 'Groove'): 3,
#          ('Groove', 'Yzma'): 3,
#          ('Yzma', 'Ahaha'): 3,
#          ('Ahaha', 'Shirt'): 3,
#          ('Blue', 'Grateful'): 81,
#          ('Grateful', 'Dead'): 186,
#          ('Dead', 'Shamrock'): 15,
#          ('Multi', 'Medium'): 33,
#          ('Patricks', 'McCrotch'): 3,
#          ('McCrotch', 'Funny'): 6,
#          ('Funny', 'Irish'): 36,
#          ('Shirt', 'Double'): 9,
#          ('Double', 'Paddy'): 9,
#          ('Paddy', 'Funny'): 3,
#          ('Funny', 'Parade'): 3,
#          ('Parade', 'Shirt'): 3,
#          ('Cute', 'Unicorn'): 9,
#          ('Unicorn', 'Leprecorn'): 3,
#          ('Leprecorn', 'Patrick'): 3,
#          ('Patrick', 'Lucky'): 42,
#          ('Lucky', 'Irish'): 12,
#          ('Irish', 'Girls'): 3,
#          ('Girls', 'Kids'): 60,
#          ('Nintendo', 'Throwback'): 15,
#          ('Throwback', 'Mario'): 15,
#          ('Mario', 'Shirt'): 33,
#          ('Shirt', 'Large'): 285,
#          ('Large', 'Light'): 12,
#          ('Light', 'Blue'): 51,
#          ('Blue', 'Nintendo'): 12,
#          ('Nintendo', 'Pixel'): 3,
#          ('Pixel', 'Cast'): 3,
#          ('Cast', 'Shirt'): 3,
#          ('Large', 'Charcoal'): 18,
#          ('Charcoal', 'Heather'): 123,
#          ('Heather', 'Harry'): 3,
#          ('Potter', 'Happiness'): 3,
#          ('Happiness', 'Quote'): 3,
#          ('Quote', 'Shirt'): 18,
#          ('Large', 'Logo'): 3,
#          ('Logo', 'Shining'): 3,
#          ('Shining', 'Print'): 3,
#          ('Print', 'Shirt'): 36,
#          ('Marvel', 'Spider'): 54,
#          ('Spider', 'Miles'): 18,
#          ('Miles', 'Morales'): 18,
#          ('Morales', 'Birthday'): 12,
#          ('Birthday', 'Graphic'): 12,
#          ('Shirt', 'Eminem'): 3,
#          ('Eminem', 'Official'): 3,
#          ('Official', 'Sprayed'): 3,
#          ('Sprayed', 'Shirt'): 3,
#          ('Shirt', 'HUMAN'): 3,
#          ('HUMAN', 'LGBT'): 3,
#          ('LGBT', 'Flag'): 3,
#          ('Flag', 'Pride'): 24,
#          ('Pride', 'Month'): 3,
#          ('Month', 'Transgender'): 3,
#          ('Transgender', 'Rainbow'): 3,
#          ('Rainbow', 'Lesbian'): 3,
#          ('Lesbian', 'Shirt'): 3,
#          ('Shirt', 'Teach'): 9,
#          ('Teach', 'Cutest'): 3,
#          ('Cutest', 'Little'): 6,
#          ('Little', 'Leprechaun'): 3,
#          ('Leprechaun', 'Patricks'): 15,
#          ('Patricks', 'Teacher'): 6,
#          ('Shirt', 'Long'): 36,
#          ('Long', 'Board'): 6,
#          ('Board', 'North'): 3,
#          ('North', 'Shore'): 6,
#          ('Shore', 'Surf'): 3,
#          ('Surf', 'Vintage'): 3,
#          ('Vintage', 'Hawaii'): 3,
#          ('Hawaii', 'Beach'): 3,
#          ('Beach', 'Shirt'): 3,
#          ('Kids', 'Comics'): 12,
#          ('Comics', 'Batman'): 21,
#          ('Batman', 'Birthday'): 12,
#          ('Birthday', 'Action'): 6,
#          ('Action', 'Shot'): 6,
#          ('Shot', 'Shirt'): 48,
#          ('Standard', 'Vintage'): 48,
#          ('Vintage', 'Crusher'): 108,
#          ('Shirt', 'Daisy'): 48,
#          ('Daisy', 'Happy'): 21,
#          ('Happy', 'Pink'): 42,
#          ('Pink', 'Small'): 21,
#          ('Pink', 'Large'): 42,
#          ('Large', 'Mens'): 57,
#          ('Mens', 'Lucky'): 9,
#          ('Lucky', 'Father'): 3,
#          ('Father', 'Funny'): 6,
#          ('Irish', 'Shamrocks'): 3,
#          ('Shirt', 'Ireland'): 6,
#          ('Ireland', 'Shirt'): 9,
#          ('Shirt', 'Vintage'): 249,
#          ('Vintage', 'Sports'): 15,
#          ('Sports', 'Design'): 24,
#          ('Design', 'Irish'): 3,
#          ('Shamrock', 'Today'): 3,
#          ('Today', 'Irish'): 9,
#          ('Irish', 'Gift'): 12,
#          ('Gift', 'Patrick'): 6,
#          ('Patrick', 'Shamrock'): 33,
#          ('Shamrock', 'Clover'): 36,
#          ('Clover', 'Funny'): 6,
#          ('Funny', 'Shirt'): 141,
#          ('Kids', 'Birthday'): 63,
#          ('Birthday', 'Years'): 45,
#          ('Years', 'Vintage'): 21,
#          ('Vintage', 'Retro'): 72,
#          ('Retro', 'Months'): 18,
#          ('Months', 'Shirt'): 15,
#          ('Shirt', 'Sarcastic'): 3,
#          ('Sarcastic', 'Shirt'): 15,
#          ('Shirt', 'Humor'): 3,
#          ('Shirt', 'Outstanding'): 3,
#          ('Outstanding', 'Shirt'): 3,
#          ('Daisy', 'Jones'): 24,
#          ('Jones', 'Vintage'): 21,
#          ('Vintage', 'Band'): 3,
#          ('Band', 'Logo'): 3,
#          ('Logo', 'Premium'): 9,
#          ('Shirt', 'Love'): 99,
#          ('Love', 'Fart'): 3,
#          ('Fart', 'Heart'): 3,
#          ('Heart', 'Shirt'): 24,
#          ('Shirt', 'Today'): 6,
#          ('Today', 'Jesus'): 3,
#          ('Jesus', 'Satan'): 3,
#          ('Satan', 'Goat'): 3,
#          ('Goat', 'Satanic'): 3,
#          ('Satanic', 'Rainbow'): 3,
#          ('Rainbow', 'Satanism'): 3,
#          ('Satanism', 'Gift'): 3,
#          ('Shirt', 'STAR'): 63,
#          ('STAR', 'WARS'): 135,
#          ('WARS', 'Junior'): 15,
#          ('Junior', 'Retro'): 15,
#          ('Retro', 'Color'): 15,
#          ('Color', 'Festival'): 15,
#          ('Festival', 'Muscle'): 15,
#          ('Muscle', 'Charcoal'): 15,
#          ('Charcoal', 'Small'): 15,
#          ('Small', 'Born'): 3,
#          ('Born', 'Fishing'): 6,
#          ('Fishing', 'Forced'): 3,
#          ('Forced', 'School'): 3,
#          ('School', 'Funny'): 3,
#          ('Funny', 'Fish'): 3,
#          ('Fish', 'Boys'): 3,
#          ('Boys', 'Kids'): 78,
#          ('Kids', 'Youth'): 15,
#          ('Youth', 'Shirt'): 18,
#          ('Womens', 'Saint'): 3,
#          ('Patricks', 'Shenanigans'): 24,
#          ('Shenanigans', 'Patricks'): 15,
#          ('Shirt', 'Bunny'): 12,
#          ('Bunny', 'Easter'): 18,
#          ('Easter', 'Leopard'): 6,
#          ('Leopard', 'Plaid'): 3,
#          ('Plaid', 'Buffalo'): 3,
#          ('Buffalo', 'Rabbit'): 3,
#          ('Easter', 'Kids'): 9,
#          ('Shirt', 'Monster'): 24,
#          ('Monster', 'truck'): 3,
#          ('truck', 'family'): 9,
#          ('family', 'matching'): 9,
#          ('matching', 'birthday'): 3,
#          ('Shirt', 'Sugar'): 9,
#          ('Sugar', 'Skull'): 15,
#          ('Skull', 'Patricks'): 12,
#          ('Patricks', 'Dead'): 6,
#          ('Dead', 'Women'): 3,
#          ('Women', 'Leprechaun'): 9,
#          ('Shirt', 'Costa'): 27,
#          ('Costa', 'Species'): 9,
#          ('Species', 'Shield'): 9,
#          ('Shield', 'Short'): 9,
#          ('Shirt', 'Gray'): 12,
#          ('Gray', 'Heather'): 21,
#          ('Heather', 'Medium'): 57,
#          ('Medium', 'Shenanigans'): 6,
#          ('Squad', 'Patricks'): 6,
#          ('Patricks', 'Gnomes'): 3,
#          ('Gnomes', 'Green'): 3,
#          ('Green', 'Proud'): 3,
#          ('Proud', 'Irish'): 3,
#          ('Blue', 'Dirt'): 6,
#          ('Dirt', 'Cheap'): 6,
#          ('Cheap', 'Shirt'): 6,
#          ('Medium', 'Liquid'): 33,
#          ('Large', 'Liquid'): 114,
#          ('adult', 'Bertha'): 3,
#          ('Bertha', 'shirt'): 3,
#          ('Shirt', 'Cream'): 12,
#          ('Cream', 'Medium'): 6,
#          ('Medium', 'Video'): 3,
#          ('Video', 'Game'): 60,
#          ('Game', 'Leprechaun'): 3,
#          ('Patricks', 'Gamer'): 9,
#          ('Gamer', 'Kids'): 3,
#          ('Boys', 'Gaming'): 3,
#          ('Shirt', 'Inspire'): 6,
#          ('Inspire', 'Greek'): 6,
#          ('Greek', 'Symbol'): 6,
#          ('Symbol', 'Math'): 9,
#          ('Shirt', 'Zeppelin'): 15,
#          ('Zeppelin', 'Electric'): 15,
#          ('Electric', 'Magic'): 15,
#          ('Magic', 'Shirt'): 12,
#          ('Shirt', 'White'): 216,
#          ('Patricks', 'Irish'): 60,
#          ('Shirt', 'Wednesday'): 6,
#          ('Wednesday', 'Poster'): 3,
#          ('Poster', 'Shirt'): 102,
#          ('Shirt', 'Dibs'): 18,
#          ('Redhead', 'Shirt'): 18,
#          ('Patricks', 'Drinking'): 21,
#          ('Drinking', 'Shirt'): 42,
#          ('Shirt', 'Solemnly'): 3,
#          ('Solemnly', 'Swear'): 3,
#          ('Swear', 'Birthday'): 3,
#          ('Birthday', 'Funny'): 3,
#          ('Nintendo', 'Ocarina'): 45,
#          ('Ocarina', 'Shirt'): 45,
#          ('Medium', 'Charcoal'): 12,
#          ('Heather', 'Yellowstone'): 3,
#          ('Yellowstone', 'Sunburst'): 3,
#          ('Sunburst', 'Logo'): 3,
#          ('Logo', 'Dutton'): 3,
#          ('Dutton', 'Ranch'): 9,
#          ('Ranch', 'Shirt'): 6,
#          ('Patricks', 'Love'): 3,
#          ('Love', 'Drinking'): 6,
#          ('Drinking', 'Funny'): 9,
#          ('Funny', 'Gifts'): 21,
#          ('Gifts', 'Beer'): 3,
#          ('Beer', 'Lover'): 6,
#          ('Lover', 'Shirt'): 129,
#          ('Shirt', 'Thirteen'): 3,
#          ('Thirteen', 'Official'): 3,
#          ('Official', 'Teenager'): 18,
#          ('Teenager', 'Heart'): 3,
#          ('Heart', 'Cute'): 3,
#          ('Cute', 'th'): 3,
#          ('Birthday', 'Girls'): 15,
#          ('Womens', 'Happy'): 3,
#          ('Patrick', 'Birthday'): 9,
#          ('Birthday', 'Gift'): 165,
#          ('Gift', 'Neck'): 12,
#          ('Icon', 'Pink'): 3,
#          ('Pink', 'Hearts'): 3,
#          ('Hearts', 'Valentine'): 6,
#          ('Valentine', 'Shirt'): 15,
#          ('Small', 'Kids'): 6,
#          ('Kids', 'Vintage'): 6,
#          ('Vintage', 'Shamrock'): 15,
#          ('Shamrock', 'Toddler'): 3,
#          ('Toddler', 'Girl'): 3,
#          ('Girl', 'Patricks'): 6,
#          ('Patricks', 'Baby'): 3,
#          ('Baby', 'Shirt'): 15,
#          ('Shirt', 'Teenage'): 15,
#          ('Teenage', 'Mutant'): 15,
#          ('Mutant', 'Ninja'): 15,
#          ('Ninja', 'Turtles'): 15,
#          ('Turtles', 'Multiple'): 3,
#          ('Multiple', 'Panels'): 3,
#          ('Panels', 'Shirt'): 9,
#          ('Shirt', 'Green'): 42,
#          ('Green', 'Beer'): 3,
#          ('Beer', 'Patrick'): 12,
#          ('Patrick', 'Long'): 3,
#          ('Long', 'Sleeve'): 264,
#          ('Shirt', 'Nostalgic'): 3,
#          ('Nostalgic', 'Funny'): 3,
#          ('Shirt', 'Capybaras'): 3,
#          ('Capybaras', 'Moon'): 3,
#          ('Moon', 'Funny'): 3,
#          ('Funny', 'Capybara'): 6,
#          ('Capybara', 'Humor'): 3,
#          ('Humor', 'Parody'): 3,
#          ('Parody', 'Shirt'): 6,
#          ('Disney', 'Pixar'): 105,
#          ('Pixar', 'Story'): 48,
#          ('Story', 'Alien'): 6,
#          ('Alien', 'Face'): 3,
#          ('Face', 'Halloween'): 6,
#          ('Halloween', 'Shirt'): 21,
#          ('WARS', 'March'): 6,
#          ('March', 'Sheet'): 9,
#          ('Sheet', 'Short'): 9,
#          ('Shirt', 'Heather'): 84,
#          ('Medium', 'Jamaican'): 3,
#          ('Jamaican', 'Girl'): 3,
#          ('Girl', 'Jamaica'): 3,
#          ('Jamaica', 'girl'): 3,
#          ('girl', 'Jamaica'): 3,
#          ('Jamaica', 'woman'): 3,
#          ('woman', 'flag'): 6,
#          ('flag', 'Shirt'): 6,
#          ('Shirt', 'Rick'): 12,
#          ('Rick', 'Morty'): 15,
#          ('Morty', 'Dimension'): 3,
#          ('Dimension', 'Portal'): 3,
#          ('Portal', 'Shirt'): 3,
#          ('Vintage', 'th'): 21,
#          ('Birthday', 'Decorations'): 30,
#          ('Decorations', 'Funny'): 3,
#          ('Funny', 'Birthday'): 9,
#          ('Funny', 'Scottish'): 6,
#          ('Scottish', 'Kilts'): 3,
#          ('Kilts', 'Good'): 3,
#          ('Good', 'Girls'): 3,
#          ('Shirt', 'Scotland'): 6,
#          ('Scotland', 'Star'): 3,
#          ('Mandalorian', 'Helmet'): 6,
#          ('Helmet', 'Scene'): 3,
#          ('Scene', 'Fill'): 3,
#          ('Fill', 'Shirt'): 21,
#          ('Icon', 'Filled'): 6,
#          ('Filled', 'Hearts'): 3,
#          ('Hearts', 'Shirt'): 12,
#          ('Friends', 'Mickey'): 21,
#          ('Mickey', 'Floral'): 6,
#          ('Floral', 'Fill'): 3,
#          ('Shirt', 'Irish'): 102,
#          ('Irish', 'Video'): 6,
#          ('Game', 'Controller'): 21,
#          ('Controller', 'Patrick'): 3,
#          ('Patrick', 'Gamer'): 3,
#          ('Shirt', 'Girl'): 48,
#          ('Girl', 'Birthday'): 3,
#          ('Birthday', 'Party'): 90,
#          ('Party', 'Costume'): 6,
#          ('Costume', 'Retro'): 3,
#          ('Retro', 'Vintage'): 84,
#          ('Vintage', 'Gift'): 15,
#          ('Gift', 'Women'): 72,
#          ('Women', 'Shirt'): 219,
#          ('Years', 'Birthday'): 27,
#          ('Birthday', 'Gifts'): 36,
#          ('Gifts', 'Astronaut'): 3,
#          ('Astronaut', 'Birthday'): 3,
#          ('Shirt', 'Chicken'): 15,
#          ('Chicken', 'Whisperer'): 3,
#          ('Whisperer', 'Funny'): 3,
#          ('Funny', 'Chicken'): 6,
#          ('Lover', 'Farming'): 3,
#          ('Farming', 'Shirt'): 3,
#          ('Shirt', 'Singing'): 9,
#          ('Singing', 'Monsters'): 9,
#          ('Monsters', 'Furcorn'): 3,
#          ('Furcorn', 'Icon'): 3,
#          ('Icon', 'shirt'): 9,
#          ('shirt', 'Birthday'): 6,
#          ('Birthday', 'Time'): 6,
#          ('Time', 'Level'): 6,
#          ('Level', 'Video'): 3,
#          ('Game', 'Gift'): 6,
#          ('Gift', 'Boys'): 27,
#          ('Blue', 'Plus'): 75,
#          ('Plus', 'Size'): 81,
#          ('Size', 'Stars'): 3,
#          ('Stars', 'Stripes'): 27,
#          ('Stripes', 'Shirt'): 9,
#          ('Large', 'Costa'): 12,
#          ('Heather', 'Large'): 156,
#          ('Large', 'Patrick'): 9,
#          ('Patrick', 'White'): 3,
#          ('White', 'Smiley'): 3,
#          ('Smiley', 'Face'): 3,
#          ('Face', 'Clover'): 6,
#          ('Clover', 'Trendy'): 12,
#          ('Trendy', 'Shirt'): 24,
#          ('Womens', 'Shenanigans'): 9,
#          ('Shenanigans', 'Begin'): 33,
#          ('Begin', 'Drinking'): 3,
#          ('Drinking', 'Patricks'): 6,
#          ('Shirt', 'Dominican'): 33,
#          ('Dominican', 'Republic'): 48,
#          ('Republic', 'Flag'): 15,
#          ('Flag', 'Shirt'): 87,
#          ('Shirt', 'Baseball'): 33,
#          ('Shirt', 'Sports'): 6,
#          ('Sports', 'Shirt'): 18,
#          ('Shirt', 'Yellowstone'): 21,
#          ('Yellowstone', 'Flag'): 3,
#          ('Mens', 'Vneck'): 21,
#          ('Vneck', 'Shirt'): 21,
#          ('Shirt', 'Pack'): 51,
#          ('Pack', 'Shirt'): 33,
#          ('Shirt', 'Optic'): 12,
#          ('Optic', 'White'): 12,
#          ('Large', 'Cute'): 3,
#          ('Cute', 'Heart'): 3,
#          ('Heart', 'Green'): 3,
#          ('Green', 'Glitter'): 6,
#          ('Glitter', 'Lucky'): 3,
#          ('Lucky', 'Cheetah'): 3,
#          ('Cheetah', 'Patrick'): 3,
#          ('Funny', 'People'): 6,
#          ('People', 'sayings'): 3,
#          ('sayings', 'Know'): 3,
#          ('Know', 'Premium'): 3,
#          ('Shirt', 'Mister'): 3,
#          ('Mister', 'Lucky'): 3,
#          ('Lucky', 'Suspenders'): 3,
#          ('Suspenders', 'Patricks'): 3,
#          ('Patricks', 'Boys'): 42,
#          ('Kids', 'Toddlers'): 3,
#          ('Toddlers', 'Shirt'): 6,
#          ('Shirt', 'Bigfoot'): 9,
#          ('Bigfoot', 'Research'): 3,
#          ('Research', 'Team'): 3,
#          ('Team', 'Retro'): 3,
#          ('Vintage', 'Sasquatch'): 3,
#          ('Sasquatch', 'Women'): 3,
#          ('Gift', 'Idea'): 18,
#          ('Idea', 'Year'): 9,
#          ('Year', 'Awesome'): 9,
#          ('Awesome', 'Shirt'): 15,
#          ('Shirt', 'Fear'): 3,
#          ('Fear', 'Bear'): 3,
#          ('Bear', 'Boston'): 3,
#          ('Boston', 'Hockey'): 3,
#          ('Hockey', 'Shirt'): 9,
#          ('Shirt', 'Magpul'): 6,
#          ('Magpul', 'mens'): 6,
#          ('mens', 'Mapgul'): 3,
#          ('Mapgul', 'Cotton'): 3,
#          ('Cotton', 'Crew'): 21,
#          ('Crew', 'Neck'): 72,
#          ('Neck', 'Short'): 27,
#          ('Shirt', 'Chrome'): 3,
#          ('Chrome', 'Icon'): 3,
#          ('Icon', 'Black'): 3,
#          ('Medium', 'Magpul'): 9,
#          ('Magpul', 'Cotton'): 15,
#          ('Shirt', 'Bang'): 9,
#          ('Bang', 'Navy'): 3,
#          ('Navy', 'Medium'): 21,
#          ('mens', 'Cotton'): 3,
#          ('Shirt', 'Nonstop'): 9,
#          ('Nonstop', 'Polymer'): 9,
#          ('Polymer', 'Action'): 9,
#          ('Action', 'Silver'): 9,
#          ('Silver', 'Large'): 9,
#          ('Large', 'Magpul'): 9,
#          ('Bang', 'Charcoal'): 3,
#          ('Medium', 'Bunny'): 3,
#          ('Bunny', 'Face'): 9,
#          ('Face', 'Sunglasses'): 3,
#          ('Sunglasses', 'Easter'): 3,
#          ('Easter', 'Boys'): 3,
#          ('Irish', 'Italian'): 6,
#          ('Italian', 'Women'): 3,
#          ('Women', 'Patrick'): 3,
#          ('Patrick', 'Gaelic'): 3,
#          ('Gaelic', 'Shirt'): 6,
#          ('Shirt', 'Christian'): 15,
#          ('Christian', 'Things'): 3,
#          ('Things', 'Christ'): 3,
#          ('Christ', 'Lion'): 3,
#          ('Lion', 'Faith'): 3,
#          ('Faith', 'Shirt'): 12,
#          ('Floral', 'Easter'): 3,
#          ('Easter', 'Bunny'): 60,
#          ('Bunny', 'Shirt'): 27,
#          ('Girls', 'Spring'): 3,
#          ('Spring', 'Flowers'): 3,
#          ('Flowers', 'Rabbit'): 3,
#          ('Rabbit', 'Shirt'): 6,
#          ('Shirt', 'Elvis'): 9,
#          ('Elvis', 'Presley'): 6,
#          ('Presley', 'Official'): 6,
#          ('Official', 'Vintage'): 9,
#          ('Vintage', 'Design'): 3,
#          ('Design', 'Shirt'): 48,
#          ('Shirt', 'Mtley'): 9,
#          ...})

# %%
import spacy

# %%
 from spacy import displacy
 nlp = spacy.load('en_core_web_lg')
 doc= nlp(titles)
 displacy.serve(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Mademark Daria Quinn
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fashion Club Shirt Disney Cars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Lightning McQueen Graphic Shirt Charcoal Medium Patricks Shamrock Baseball Saint Paddys Kids Boys Shirt Drop Women Cora Shirt Dress Black Funny Merry
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patrick Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Leprechaun Shirt Amateur Sketch Mobile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Alabama Leprechaun
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patrick Shirt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  16yr BDay Funny Gamer
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16th Year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Birthday Shirt Shenanigans Squad Shirt Saint Patricks Shirt Life Good Women Standard Crusher Graphic Shirt Watercolor Daisy Birds Darkest Blue Large Life Good Women Standard Crusher Graphic Shirt Watercolor Daisy Birds Cloud White Medium Level Unlocked Awesome
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010 13th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Birthday Gaming Shirt
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Hufflepuff Symbol Line Shirt Year Gifts Vintage 1993 Limited Edition
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday Shirt Patricks Shamrock Baseball Saint Paddy Kids Boys Shirt Nintendo Yoshi Shirt Medium Black Liquid Blue unisex adult
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Creedence Clearwater Revival Travelin Band
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  shirt Shirt Grey Medium
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Cute Silly Rabbit Easter Jesus Shirt Calvin Klein Relaxed Logo Crewneck Shirt Black Beauty Brilliant White Medium Life Good Women Crusher Graphic Neck Shirt Floral Jars Darkest Blue Small Life Good Women Crusher Graphic Neck Shirt Floral Jars Darkest Blue Large Alternative Jersey Crew Shirt Warm Gold Large Funny Novelty Shirt Sarcasm Intelligence Test Ness funny joke
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shirt Funny Chess Gift Chess Lover Kids Boys Girls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Cool Player Shirt Capybara Mugshot Wanted Felonies Country Shirt Identify Conspiracy Theorist Pronouns Told Shirt Talk Chickens Shirt Cute Chicken Buffs Gift Shirt Mens Father Gift Uncle Myth Influence Shirt Hello Kitty Friends Sanrio Rainbow Shirt Cricut unisex adult shirt
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BLANK TSHIRT White Large John Cena Champ Shirt Dabbing Banana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  Wearing Sunglasses Dance Girl Mens Kids Shirt Mens Waffle Crewneck Shirt Shirt Bright Aloe Global Large Grey Heather Lucky Simple Blessed Leopard Glitter Patrick
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irish Shirt Womens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Disney
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnie Mouse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Icon
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Green Shamrocks Patrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Neck Shirt Disney Villains Maleficent Shirt Shrek Check Shrek Shirt Naruto Shippuden Heads Shirt Liquid Blue Pink Floyd Dark Paint Short Sleeve Shirt Multi Large Hard Fast Turn Left Funny Baseball Player Shirt Womens Slainte green shamrock clover Patricks Neck Shirt Problem Groovy Retro Shirt birthday Shirt Play Video Games Funny Gamer Boys Teens Shirt Kids Kwazii Cute Funny Pirate Kids Shirt Trump 2024 Vintage Donald Trump
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Shirt Life Good Women Crusher Graphic Neck Shirt Watercolor Daisy Trees Black Small Life Good Women Crusher Graphic Neck Shirt Watercolor Daisy Trees Cloud White Large Disney Peter Skull Rock Vintage Graphic Shirt Shirt Womens Disney Mickey Friends
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnie Mouse Classic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
titles=nt.remove_stopwords(titles)
titles=nt.remove_shortwords(titles,3)

# %%
titles
# Out:
# 'Mademark Daria Quinn Fashion Club Shirt Disney Cars Lightning McQueen Graphic Shirt Charcoal Medium Patricks Shamrock Baseball Saint Paddys Kids Boys Shirt Drop Women Cora Shirt Dress Black Funny Merry Patrick Biden Leprechaun Shirt Amateur Sketch Mobile Alabama Leprechaun Patrick Shirt 16yr BDay Funny Gamer 16th Year Birthday Shirt Shenanigans Squad Shirt Saint Patricks Shirt Life Good Women Standard Crusher Graphic Shirt Watercolor Daisy Birds Darkest Blue Large Life Good Women Standard Crusher Graphic Shirt Watercolor Daisy Birds Cloud White Medium Level Unlocked Awesome 2010 13th Birthday Gaming Shirt Harry Potter Hufflepuff Symbol Line Shirt Year Gifts Vintage 1993 Limited Edition 30th Birthday Shirt Patricks Shamrock Baseball Saint Paddy Kids Boys Shirt Nintendo Yoshi Shirt Medium Black Liquid Blue unisex adult Creedence Clearwater Revival Travelin Band shirt Shirt Grey Medium Christians Cute Silly Rabbit Easter Jesus Shirt Calvin Klein Relaxed Logo Crewneck Shirt Black Beauty Brilliant White Medium Life Good Women Crusher Graphic Neck Shirt Floral Jars Darkest Blue Small Life Good Women Crusher Graphic Neck Shirt Floral Jars Darkest Blue Large Alternative Jersey Crew Shirt Warm Gold Large Funny Novelty Shirt Sarcasm Intelligence Test Ness funny joke Shirt Funny Chess Gift Chess Lover Kids Boys Girls Cool Player Shirt Capybara Mugshot Wanted Felonies Country Shirt Identify Conspiracy Theorist Pronouns Told Shirt Talk Chickens Shirt Cute Chicken Buffs Gift Shirt Mens Father Gift Uncle Myth Influence Shirt Hello Kitty Friends Sanrio Rainbow Shirt Cricut unisex adult shirt BLANK TSHIRT White Large John Cena Champ Shirt Dabbing Banana Wearing Sunglasses Dance Girl Mens Kids Shirt Mens Waffle Crewneck Shirt Shirt Bright Aloe Global Large Grey Heather Lucky Simple Blessed Leopard Glitter Patrick Irish Shirt Womens Disney Minnie Mouse Icon Green Shamrocks Patrick Neck Shirt Disney Villains Maleficent Shirt Shrek Check Shrek Shirt Naruto Shippuden Heads Shirt Liquid Blue Pink Floyd Dark Paint Short Sleeve Shirt Multi Large Hard Fast Turn Left Funny Baseball Player Shirt Womens Slainte green shamrock clover Patricks Neck Shirt Problem Groovy Retro Shirt birthday Shirt Play Video Games Funny Gamer Boys Teens Shirt Kids Kwazii Cute Funny Pirate Kids Shirt Trump 2024 Vintage Donald Trump July Shirt Life Good Women Crusher Graphic Neck Shirt Watercolor Daisy Trees Black Small Life Good Women Crusher Graphic Neck Shirt Watercolor Daisy Trees Cloud White Large Disney Peter Skull Rock Vintage Graphic Shirt Shirt Womens Disney Mickey Friends Minnie Mouse Classic Portrait Neck Shirt Courage Cowardly Girl Courage Logo Shirt Black Small Bruce Retro Style Vintage Distressed Shirt Liquid Blue unisex adult Rock Eruption Short Sleeve shirt Shirt Black Small Lucky Lepricorn Unicorn Patricks Shirt Totally 1980s Vintage Eighties Costume Party shirt Shirt Local Dealer Funny Bleached Chicken Lover Farm Farmer Shirt Taylor Thing understand Shirt Father Papa Grandpa Funny Dada Shirt Shenanigans Coordinator Shirt Teacher Patricks Shirt Sham Rock Funny Patricks Shirt Shamrock Guitar Shirt Kryptek Standard Hyperion Short Sleeve Lightweight Breathable Stealthy Camo Hunting Fishing Shirt Highlander Large Kryptek Standard Hyperion Short Sleeve Lightweight Breathable Stealthy Camo Hunting Fishing Shirt Highlander Large Teacher Life Messy Happy School Teacher Shirt Prince unisex adult Casual Shirt Black Medium Mens Irish Blessing Funny Patricks Shirt Inch Nails Adult Short Sleeve Shirt Charcoal Logo Medium Kanagawa Japanese great wave shirt Disney Caballeros Classic Shirt Patricks Golf Golfing Irish Golfer Beer Humor Shirt Disney Years Wonder Mickey Pals Muted Cute D100 Shirt Lucky Patricks Shamrock Shirt Women Girls Shirt Funny March Birthday Month Birthday Shirt Foxes World Funny Animals Educational Shirt Funny Leprechaun Dibs Redhead Irish Patrick Shirt Disney Minnie Mouse Leopard Print Premium Shirt Nightmare Street Freddy Follow Dreams Shirt Shirt Women ...

# %%
extracted_results=[]

# %%
def extract_products(themes,save=False):
    for theme in themes:
        extracted_results=[]
        for i,prod_title in enumerate(df['Title'].values):
            if theme.lower() in prod_title.lower():
               # print(df.loc[i,'Title'])
               extracted_results.append(i)
        theme_words=nt.remove_stopwords(theme)
        for word in theme_words.split():
            for i,prod_title in enumerate(df['Title'].values):
                if word.lower() in prod_title.lower():
                    extracted_results.append(i)
                   # print(1)
                  # print(df.loc[i,'Title'])
        if save==True:
            df.loc[extracted_results].drop_duplicates().to_csv(f'{theme}.csv')

# %% [markdown]
# # Single Theme

# %%
extract_products(['Saint Patrick'],save=False)  #pass save==True if you want to save the results

# %% [markdown]
# # Multiple Themes

# %%
extract_products(['Saint Patrick','30th Birthday'],save=True) 
#you can add more themes in single quotes separated by comma
#pass save==True if you want to save the results
