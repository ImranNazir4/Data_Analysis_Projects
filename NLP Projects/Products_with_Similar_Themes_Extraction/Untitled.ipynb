# %%
import pandas as pd

# %%
df=pd.read_csv('Amz-Products-Data-2023-03-13-ProductFinder.csv')
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (46,50,51,66,67,68,91,92,93,96,100,101,104,105,106,107,108,109,141,162,166,167,172,173,184,185,242,243,249,267,268,269,271,272,273) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
for i in df.columns:
    print(i)
# Out:
# Locale
# Image
# Title
# Sales Rank: Current
# Sales Rank: 30 days avg.
# Sales Rank: 90 days avg.
# Sales Rank: 180 days avg.
# Sales Rank: 30 days drop %
# Sales Rank: 90 days drop %
# Sales Rank: Lowest
# Sales Rank: Highest
# Sales Rank Drops: Drops last 30 days
# Sales Rank Drops: Drops last 90 days
# Sales Rank Drops: Drops last 180 days
# Sales Rank: Reference
# Sales Rank: Subcategory Sales Ranks
# Rating: Rating
# Review Count: Review Count
# Review Count: Review Count - 30 days avg.
# Review Count: Review Count - 90 days avg.
# Review Count: Review Count - 180 days avg.
# Ratings - Format Specific
# Review Count - Format Specific
# Last Price Change
# Last Update
# Last Offer Update
# Amazon: Current
# Amazon: 30 days avg.
# Amazon: 90 days avg.
# Amazon: 180 days avg.
# Amazon: 30 days drop %
# Amazon: 90 days drop %
# Amazon: Lowest
# Amazon: Highest
# 90 days out of stock percentage (OOS %): 90 days OOS
# Amazon: Availability of the Amazon offer
# MAP restriction
# ...

# %%
for i in df.Title:
    print(i)
# Out:
# Mademark x Daria - Quinn - VP of the Fashion Club T-Shirt
# Disney Men's Cars 3 Lightning McQueen Graphic T-Shirt, Charcoal, Medium
# St Patricks Day Shamrock Baseball Saint Paddys Kids Boys Men T-Shirt
# The Drop Women's Cora T-Shirt Dress, Black, XL
# Funny Merry 4th Of St Patrick's Day Joe Biden Leprechaun Hat T-Shirt
# Amateur Sketch of Mobile Alabama Leprechaun St.Patrick's Day T-Shirt
# 16yr BDay Son Boy Funny Gamer 16th 16 Year Old Birthday T-Shirt
# Shenanigans Squad T-Shirt Saint Patricks Day T-Shirt
# Life is Good Women's Standard Crusher Graphic T-Shirt Watercolor Daisy Birds, Darkest Blue, Large
# Life is Good Women's Standard Crusher Graphic T-Shirt Watercolor Daisy Birds, Cloud White, Medium
# Level 13 Unlocked Awesome Since 2010 13th Birthday Gaming T-Shirt
# Harry Potter Hufflepuff Symbol Line Art T-Shirt
# 30 Year Old Gifts Vintage 1993 Limited Edition 30th Birthday T-Shirt
# St Patricks Day Shamrock Baseball Saint Paddy's Kids Boys T-Shirt
# ...

# %%
df['Sales Rank: Subcategory Sales Ranks']
# Out:
# 0       # 113,514 | Top -% | Private Brands; # 6,058,9...
# 1       # 27,552 | Top 1% | Men's Fashion; # 2,034 | T...
# 2       # 1,246 | Top 1% | Women's Novelty T-Shirts; #...
# 3                                                     NaN
# 4       # 27,489 | Top 1% | Men's Fashion; # 2,047 | T...
#                               ...
# 4995    # 161,889 | Top 1% | Women's Fashion; # 15,125...
# 4996    # 123,838 | Top 1% | Men's Fashion; # 24,840 |...
# 4997    # 4,005 | Top 1% | Women's Novelty T-Shirts; #...
# 4998    # 3,141 | Top 7% | Girls' Novelty Clothing; # ...
# 4999    # 4,595 | Top 1% | Women's Novelty T-Shirts; #...
# Name: Sales Rank: Subcategory Sales Ranks, Length: 5000, dtype: object
