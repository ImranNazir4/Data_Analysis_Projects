# %%
import pandas as pd
import numpy as np

# %%
divorce_df=pd.read_excel('Divocre Rata Analysis.xlsx')

# %%
divorce_df=divorce_df.drop('Woman\'s Job Type',axis=1)

# %%
divorce_df.dropna(inplace=True)

# %%
divorce_df
# Out:
#        Submission Date Man's City Woman's City  Man Age  Woman Age  \
# 0  2023-01-12 12:26:53     Multan       Multan     22.0       18.0
# 1  2023-01-12 12:38:57     Multan       Multan     24.0       24.0
# 5  2023-01-12 19:22:39     Multan     Sargodha     32.0       27.0
# 6  2023-01-12 20:20:57   Kot Addu       Multan     23.0       26.0
# 11 2023-01-14 17:19:09     Lahore       Lahore     23.0       25.0
# 15 2023-01-14 20:48:54     Multan       Multan     25.0       20.0
# 17 2023-01-14 21:25:56     Multan       Multan     27.0       18.0
# 19 2023-01-14 21:36:13     Multan       Multan     32.0       27.0
# 20 2023-01-14 21:44:37     Multan       Multan     30.0       28.0
# 21 2023-01-14 21:50:22     Multan       Multan     40.0       37.0
#
#    Man's Education Woman's Education  Man's Monthly Income  \
# 0          Primary           Primary                 20000
# 1           Metric        Graduation                 90000
# ...
