# %%
import pandas as pd         #python package for data analysis
import neattext as nt       #python package for text cleaning                                                   
import nltk                 #python package for text analysis
nltk.download('punkt')      #nltk dependency for sentence tokenization
import PyPDF2               #python package for extracting data from pdf 
import os                   #importing os to deal with system directories
import re                   #re-> to handle regular expressions
import tabula               #python package for tabular data extraction from pdf
from sklearn.feature_extraction.text import TfidfVectorizer        #sklearn function for TF-IDF
from sklearn.metrics.pairwise import cosine_similarity             #to find similarity among the chunks
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Zee
# [nltk_data]     Tech\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
partitions_similarity=[]           #creating storage for partitions similarity

# %%
def pre_processing(text):
    text=nt.fix_contractions(text)                   #I'm --> I am
    text=nt.remove_special_characters(text)
    text=nt.remove_stopwords(text)
    text=nt.remove_shortwords(text,3)
    text=nt.remove_numbers(text)
    text=nt.remove_urls(text)
    text=nt.remove_non_ascii(text)
    return text


def extract_tables(file_name):
    df = tabula.read_pdf(file_name,pages='all')
    return df


def extract_text(pdf_path):
    text=''
    with open(pdf_path, 'rb') as f:
        pdf_reader = PyPDF2.PdfFileReader(f)
        # Get the number of pages in the PDF file
        num_pages = pdf_reader.getNumPages()
        for page_num in range(num_pages):
            # Get the page object
            page_obj = pdf_reader.getPage(page_num)
            # Extract the text from the page
            text += page_obj.extract_text()
    return text


    def split_into_chunks(pdf_text):
        # Split the input string into sentences
        sentences = nltk.sent_tokenize(pdf_text)
        # Split each sentence into chunks of at most 1600 characters
        chunks = []
        current_chunk = ''
        for sentence in sentences:
            if len(current_chunk) + len(sentence) + 1 <= 1600:
                current_chunk += ' ' + sentence
            else:
                if len(current_chunk) >= 100:
                    chunks.append(current_chunk.strip())
                    current_chunk = sentence
                else:
                    current_chunk += ' ' + sentence
        # Add the last chunk
        if len(current_chunk) >= 100:
            chunks.append(current_chunk.strip())
        return chunks
    
def merge_chunks(chunks, similarity_matrix, most_similar):
    merged_chunks = []
    merged_indices = set()
    
    for i in range(len(chunks)):
        if i not in merged_indices:
            current_chunk = chunks[i]
            merged_indices.add(i)
            j = most_similar[i]
            while j not in merged_indices and similarity_matrix[i][j] > 0.5:
                current_chunk += ' ' + chunks[j]
                merged_indices.add(j)
                j = most_similar[j]
            merged_chunks.append(current_chunk)
    
    return merged_chunks    
    
def get_paritions_similarity(partitions):
    # Use TfidfVectorizer to compute the TF-IDF matrix for the chunks
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(partitions)
    # Compute the cosine similarity matrix for the chunks
    similarity_matrix= cosine_similarity(tfidf_matrix)
    most_similar = similarity_matrix.argsort()[:, -2]
    merged_partitions = merge_chunks(partitions, similarity_matrix, most_similar)


    for i in range(len(partitions)):
        for j in range(len(partitions)):
            if i != j:
                similarity = similarity_matrix[i][j]
                partitions_similarity.append(f"Similarity between chunk {i+1} and chunk {j+1}: {similarity:.2f}")
    
    return partitions_similarity,merged_partitions
    
    
def merge_chunks(chunks, similarity_matrix, most_similar):
    merged_chunks = []
    merged_indices = set()

    for i in range(len(chunks)):
        if i not in merged_indices:
            current_chunk = chunks[i]
            merged_indices.add(i)
            j = most_similar[i]
            while j not in merged_indices and similarity_matrix[i][j] > 0.5:
                current_chunk += ' ' + chunks[j]
                merged_indices.add(j)
                j = most_similar[j]
            merged_chunks.append(current_chunk)

    return merged_chunks   
    
def save_partitions(partitions, file_path):
    file_dir, file_name = os.path.split(file_path)
    file_root, file_ext = os.path.splitext(file_name)
    for i, partition in enumerate(partitions):
        partition_file_name = f"{file_root}_part_{i+1}{file_ext}"
        partition_file_path = os.path.join(file_dir, partition_file_name)
        with open(partition_file_path, 'w', encoding='utf-8') as f:
            f.write(partition)   

    
        
##########################################################################################################
pdf_path ='3404555.3404559.pdf'
text = extract_text(pdf_path)
#######################################################################################################
#tables=extract_tables(pdf_path)
#for i,j in enumerate(tables):
#    j.to_csv(f'tabl{i}.csv')
#########################################################################################################
partitions = partition_text(text)
#########################################################################################################
#un-comment this code if you want to perform preprocessing on each partition
#for index,part in enumerate(partitions):
 #   partitions[index]=pre_processing(part)
#########################################################################################################
partitions_sim,merged_partitions=get_paritions_similarity(partitions)
#########################################################################################################
save_partitions(partitions,pdf_path)
####################################################################################################

# %%
partitions_sim
# Out:
# ['Similarity between chunk 1 and chunk 10: 0.02',
#  'Similarity between chunk 1 and chunk 10: 0.26',
#  'Similarity between chunk 1 and chunk 10: 0.26',
#  'Similarity between chunk 1 and chunk 11: 0.01',
#  'Similarity between chunk 1 and chunk 11: 0.11',
#  'Similarity between chunk 1 and chunk 11: 0.11',
#  'Similarity between chunk 1 and chunk 12: 0.02',
#  'Similarity between chunk 1 and chunk 12: 0.11',
#  'Similarity between chunk 1 and chunk 12: 0.11',
#  'Similarity between chunk 1 and chunk 13: 0.01',
#  'Similarity between chunk 1 and chunk 14: 0.02',
#  'Similarity between chunk 1 and chunk 15: 0.02',
#  'Similarity between chunk 1 and chunk 16: 0.00',
#  'Similarity between chunk 1 and chunk 17: 0.02',
#  'Similarity between chunk 1 and chunk 18: 0.01',
#  'Similarity between chunk 1 and chunk 19: 0.00',
#  'Similarity between chunk 1 and chunk 20: 0.00',
#  'Similarity between chunk 1 and chunk 21: 0.02',
#  'Similarity between chunk 1 and chunk 22: 0.02',
#  'Similarity between chunk 1 and chunk 23: 0.01',
#  'Similarity between chunk 1 and chunk 2: 0.01',
#  'Similarity between chunk 1 and chunk 2: 0.23',
#  'Similarity between chunk 1 and chunk 2: 0.23',
#  'Similarity between chunk 1 and chunk 3: 0.03',
#  'Similarity between chunk 1 and chunk 3: 0.28',
#  'Similarity between chunk 1 and chunk 3: 0.28',
#  'Similarity between chunk 1 and chunk 4: 0.02',
#  'Similarity between chunk 1 and chunk 4: 0.18',
#  'Similarity between chunk 1 and chunk 4: 0.18',
#  'Similarity between chunk 1 and chunk 5: 0.02',
#  'Similarity between chunk 1 and chunk 5: 0.23',
#  'Similarity between chunk 1 and chunk 5: 0.23',
#  'Similarity between chunk 1 and chunk 6: 0.04',
#  'Similarity between chunk 1 and chunk 6: 0.20',
#  'Similarity between chunk 1 and chunk 6: 0.20',
#  'Similarity between chunk 1 and chunk 7: 0.03',
#  'Similarity between chunk 1 and chunk 7: 0.22',
#  'Similarity between chunk 1 and chunk 7: 0.22',
#  'Similarity between chunk 1 and chunk 8: 0.02',
#  'Similarity between chunk 1 and chunk 8: 0.25',
#  'Similarity between chunk 1 and chunk 8: 0.25',
#  'Similarity between chunk 1 and chunk 9: 0.03',
#  'Similarity between chunk 1 and chunk 9: 0.15',
#  'Similarity between chunk 1 and chunk 9: 0.15',
#  'Similarity between chunk 10 and chunk 11: 0.11',
#  'Similarity between chunk 10 and chunk 12: 0.07',
#  'Similarity between chunk 10 and chunk 13: 0.19',
#  'Similarity between chunk 10 and chunk 14: 0.20',
#  'Similarity between chunk 10 and chunk 15: 0.17',
#  'Similarity between chunk 10 and chunk 16: 0.01',
#  'Similarity between chunk 10 and chunk 17: 0.05',
#  'Similarity between chunk 10 and chunk 18: 0.08',
#  'Similarity between chunk 10 and chunk 19: 0.08',
#  'Similarity between chunk 10 and chunk 1: 0.02',
#  'Similarity between chunk 10 and chunk 20: 0.01',
#  'Similarity between chunk 10 and chunk 21: 0.02',
#  'Similarity between chunk 10 and chunk 22: 0.04',
#  'Similarity between chunk 10 and chunk 23: 0.12',
#  'Similarity between chunk 10 and chunk 2: 0.09',
#  'Similarity between chunk 10 and chunk 3: 0.15',
#  'Similarity between chunk 10 and chunk 4: 0.08',
#  'Similarity between chunk 10 and chunk 5: 0.11',
#  'Similarity between chunk 10 and chunk 6: 0.04',
#  'Similarity between chunk 10 and chunk 7: 0.07',
#  'Similarity between chunk 10 and chunk 8: 0.20',
#  'Similarity between chunk 10 and chunk 9: 0.08',
#  'Similarity between chunk 11 and chunk 10: 0.11',
#  'Similarity between chunk 11 and chunk 12: 0.09',
#  'Similarity between chunk 11 and chunk 13: 0.10',
#  'Similarity between chunk 11 and chunk 14: 0.07',
#  'Similarity between chunk 11 and chunk 15: 0.21',
#  'Similarity between chunk 11 and chunk 16: 0.04',
#  'Similarity between chunk 11 and chunk 17: 0.11',
#  'Similarity between chunk 11 and chunk 18: 0.10',
#  'Similarity between chunk 11 and chunk 19: 0.05',
#  'Similarity between chunk 11 and chunk 1: 0.01',
#  'Similarity between chunk 11 and chunk 20: 0.00',
#  'Similarity between chunk 11 and chunk 21: 0.03',
#  'Similarity between chunk 11 and chunk 22: 0.02',
#  'Similarity between chunk 11 and chunk 23: 0.15',
#  'Similarity between chunk 11 and chunk 2: 0.13',
#  'Similarity between chunk 11 and chunk 3: 0.13',
#  'Similarity between chunk 11 and chunk 4: 0.08',
#  'Similarity between chunk 11 and chunk 5: 0.14',
#  'Similarity between chunk 11 and chunk 6: 0.05',
#  'Similarity between chunk 11 and chunk 7: 0.11',
#  'Similarity between chunk 11 and chunk 8: 0.11',
#  'Similarity between chunk 11 and chunk 9: 0.08',
#  'Similarity between chunk 12 and chunk 10: 0.07',
#  'Similarity between chunk 12 and chunk 11: 0.09',
#  'Similarity between chunk 12 and chunk 13: 0.19',
#  'Similarity between chunk 12 and chunk 14: 0.27',
#  'Similarity between chunk 12 and chunk 15: 0.23',
#  'Similarity between chunk 12 and chunk 16: 0.07',
#  'Similarity between chunk 12 and chunk 17: 0.14',
#  'Similarity between chunk 12 and chunk 18: 0.17',
#  'Similarity between chunk 12 and chunk 19: 0.08',
#  'Similarity between chunk 12 and chunk 1: 0.02',
#  'Similarity between chunk 12 and chunk 20: 0.04',
#  'Similarity between chunk 12 and chunk 21: 0.03',
#  'Similarity between chunk 12 and chunk 22: 0.02',
#  'Similarity between chunk 12 and chunk 23: 0.09',
#  'Similarity between chunk 12 and chunk 2: 0.15',
#  'Similarity between chunk 12 and chunk 3: 0.17',
#  'Similarity between chunk 12 and chunk 4: 0.13',
#  'Similarity between chunk 12 and chunk 5: 0.13',
#  'Similarity between chunk 12 and chunk 6: 0.12',
#  'Similarity between chunk 12 and chunk 7: 0.13',
#  'Similarity between chunk 12 and chunk 8: 0.25',
#  'Similarity between chunk 12 and chunk 9: 0.13',
#  'Similarity between chunk 13 and chunk 10: 0.19',
#  'Similarity between chunk 13 and chunk 11: 0.10',
#  'Similarity between chunk 13 and chunk 12: 0.19',
#  'Similarity between chunk 13 and chunk 14: 0.32',
#  'Similarity between chunk 13 and chunk 15: 0.52',
#  'Similarity between chunk 13 and chunk 16: 0.07',
#  'Similarity between chunk 13 and chunk 17: 0.16',
#  'Similarity between chunk 13 and chunk 18: 0.14',
#  'Similarity between chunk 13 and chunk 19: 0.10',
#  'Similarity between chunk 13 and chunk 1: 0.01',
#  'Similarity between chunk 13 and chunk 20: 0.02',
#  'Similarity between chunk 13 and chunk 21: 0.03',
#  'Similarity between chunk 13 and chunk 22: 0.05',
#  'Similarity between chunk 13 and chunk 23: 0.04',
#  'Similarity between chunk 13 and chunk 2: 0.18',
#  'Similarity between chunk 13 and chunk 3: 0.18',
#  'Similarity between chunk 13 and chunk 4: 0.15',
#  'Similarity between chunk 13 and chunk 5: 0.14',
#  'Similarity between chunk 13 and chunk 6: 0.10',
#  'Similarity between chunk 13 and chunk 7: 0.16',
#  'Similarity between chunk 13 and chunk 8: 0.27',
#  'Similarity between chunk 13 and chunk 9: 0.15',
#  'Similarity between chunk 14 and chunk 10: 0.20',
#  'Similarity between chunk 14 and chunk 11: 0.07',
#  'Similarity between chunk 14 and chunk 12: 0.27',
#  'Similarity between chunk 14 and chunk 13: 0.32',
#  'Similarity between chunk 14 and chunk 15: 0.45',
#  'Similarity between chunk 14 and chunk 16: 0.05',
#  'Similarity between chunk 14 and chunk 17: 0.13',
#  'Similarity between chunk 14 and chunk 18: 0.14',
#  'Similarity between chunk 14 and chunk 19: 0.10',
#  'Similarity between chunk 14 and chunk 1: 0.02',
#  'Similarity between chunk 14 and chunk 20: 0.02',
#  'Similarity between chunk 14 and chunk 21: 0.02',
#  'Similarity between chunk 14 and chunk 22: 0.06',
#  'Similarity between chunk 14 and chunk 23: 0.05',
#  'Similarity between chunk 14 and chunk 2: 0.16',
#  'Similarity between chunk 14 and chunk 3: 0.15',
#  'Similarity between chunk 14 and chunk 4: 0.11',
#  'Similarity between chunk 14 and chunk 5: 0.08',
#  'Similarity between chunk 14 and chunk 6: 0.08',
#  'Similarity between chunk 14 and chunk 7: 0.13',
#  'Similarity between chunk 14 and chunk 8: 0.20',
#  'Similarity between chunk 14 and chunk 9: 0.11',
#  'Similarity between chunk 15 and chunk 10: 0.17',
#  'Similarity between chunk 15 and chunk 11: 0.21',
#  'Similarity between chunk 15 and chunk 12: 0.23',
#  'Similarity between chunk 15 and chunk 13: 0.52',
#  'Similarity between chunk 15 and chunk 14: 0.45',
#  'Similarity between chunk 15 and chunk 16: 0.07',
#  'Similarity between chunk 15 and chunk 17: 0.17',
#  'Similarity between chunk 15 and chunk 18: 0.17',
#  'Similarity between chunk 15 and chunk 19: 0.11',
#  'Similarity between chunk 15 and chunk 1: 0.02',
#  'Similarity between chunk 15 and chunk 20: 0.04',
#  'Similarity between chunk 15 and chunk 21: 0.04',
#  'Similarity between chunk 15 and chunk 22: 0.06',
#  'Similarity between chunk 15 and chunk 23: 0.08',
#  'Similarity between chunk 15 and chunk 2: 0.26',
#  'Similarity between chunk 15 and chunk 3: 0.25',
#  'Similarity between chunk 15 and chunk 4: 0.14',
#  'Similarity between chunk 15 and chunk 5: 0.16',
#  'Similarity between chunk 15 and chunk 6: 0.10',
#  'Similarity between chunk 15 and chunk 7: 0.17',
#  'Similarity between chunk 15 and chunk 8: 0.29',
#  'Similarity between chunk 15 and chunk 9: 0.20',
#  'Similarity between chunk 16 and chunk 10: 0.01',
#  'Similarity between chunk 16 and chunk 11: 0.04',
#  'Similarity between chunk 16 and chunk 12: 0.07',
#  'Similarity between chunk 16 and chunk 13: 0.07',
#  'Similarity between chunk 16 and chunk 14: 0.05',
#  'Similarity between chunk 16 and chunk 15: 0.07',
#  'Similarity between chunk 16 and chunk 17: 0.07',
#  'Similarity between chunk 16 and chunk 18: 0.09',
#  'Similarity between chunk 16 and chunk 19: 0.03',
#  'Similarity between chunk 16 and chunk 1: 0.00',
#  'Similarity between chunk 16 and chunk 20: 0.02',
#  'Similarity between chunk 16 and chunk 21: 0.01',
#  'Similarity between chunk 16 and chunk 22: 0.00',
#  'Similarity between chunk 16 and chunk 23: 0.03',
#  'Similarity between chunk 16 and chunk 2: 0.08',
#  'Similarity between chunk 16 and chunk 3: 0.12',
#  'Similarity between chunk 16 and chunk 4: 0.09',
#  'Similarity between chunk 16 and chunk 5: 0.44',
#  'Similarity between chunk 16 and chunk 6: 0.17',
#  'Similarity between chunk 16 and chunk 7: 0.09',
#  'Similarity between chunk 16 and chunk 8: 0.08',
#  'Similarity between chunk 16 and chunk 9: 0.01',
#  'Similarity between chunk 17 and chunk 10: 0.05',
#  'Similarity between chunk 17 and chunk 11: 0.11',
#  'Similarity between chunk 17 and chunk 12: 0.14',
#  'Similarity between chunk 17 and chunk 13: 0.16',
#  'Similarity between chunk 17 and chunk 14: 0.13',
#  'Similarity between chunk 17 and chunk 15: 0.17',
#  'Similarity between chunk 17 and chunk 16: 0.07',
#  'Similarity between chunk 17 and chunk 18: 0.14',
#  'Similarity between chunk 17 and chunk 19: 0.10',
#  'Similarity between chunk 17 and chunk 1: 0.02',
#  'Similarity between chunk 17 and chunk 20: 0.10',
#  'Similarity between chunk 17 and chunk 21: 0.08',
#  'Similarity between chunk 17 and chunk 22: 0.00',
#  'Similarity between chunk 17 and chunk 23: 0.04',
#  'Similarity between chunk 17 and chunk 2: 0.21',
#  'Similarity between chunk 17 and chunk 3: 0.18',
#  'Similarity between chunk 17 and chunk 4: 0.14',
#  'Similarity between chunk 17 and chunk 5: 0.18',
#  'Similarity between chunk 17 and chunk 6: 0.08',
#  'Similarity between chunk 17 and chunk 7: 0.17',
#  'Similarity between chunk 17 and chunk 8: 0.17',
#  'Similarity between chunk 17 and chunk 9: 0.14',
#  'Similarity between chunk 18 and chunk 10: 0.08',
#  'Similarity between chunk 18 and chunk 11: 0.10',
#  'Similarity between chunk 18 and chunk 12: 0.17',
#  'Similarity between chunk 18 and chunk 13: 0.14',
#  'Similarity between chunk 18 and chunk 14: 0.14',
#  'Similarity between chunk 18 and chunk 15: 0.17',
#  'Similarity between chunk 18 and chunk 16: 0.09',
#  'Similarity between chunk 18 and chunk 17: 0.14',
#  'Similarity between chunk 18 and chunk 19: 0.12',
#  'Similarity between chunk 18 and chunk 1: 0.01',
#  'Similarity between chunk 18 and chunk 20: 0.15',
#  'Similarity between chunk 18 and chunk 21: 0.09',
#  'Similarity between chunk 18 and chunk 22: 0.03',
#  'Similarity between chunk 18 and chunk 23: 0.14',
#  'Similarity between chunk 18 and chunk 2: 0.19',
#  'Similarity between chunk 18 and chunk 3: 0.21',
#  'Similarity between chunk 18 and chunk 4: 0.16',
#  'Similarity between chunk 18 and chunk 5: 0.22',
#  'Similarity between chunk 18 and chunk 6: 0.08',
#  'Similarity between chunk 18 and chunk 7: 0.14',
#  'Similarity between chunk 18 and chunk 8: 0.19',
#  'Similarity between chunk 18 and chunk 9: 0.09',
#  'Similarity between chunk 19 and chunk 10: 0.08',
#  'Similarity between chunk 19 and chunk 11: 0.05',
#  'Similarity between chunk 19 and chunk 12: 0.08',
#  'Similarity between chunk 19 and chunk 13: 0.10',
#  'Similarity between chunk 19 and chunk 14: 0.10',
#  'Similarity between chunk 19 and chunk 15: 0.11',
#  'Similarity between chunk 19 and chunk 16: 0.03',
#  'Similarity between chunk 19 and chunk 17: 0.10',
#  'Similarity between chunk 19 and chunk 18: 0.12',
#  'Similarity between chunk 19 and chunk 1: 0.00',
#  'Similarity between chunk 19 and chunk 20: 0.02',
#  'Similarity between chunk 19 and chunk 21: 0.06',
#  'Similarity between chunk 19 and chunk 22: 0.08',
#  'Similarity between chunk 19 and chunk 23: 0.09',
#  'Similarity between chunk 19 and chunk 2: 0.13',
#  'Similarity between chunk 19 and chunk 3: 0.10',
#  'Similarity between chunk 19 and chunk 4: 0.06',
#  'Similarity between chunk 19 and chunk 5: 0.07',
#  'Similarity between chunk 19 and chunk 6: 0.04',
#  'Similarity between chunk 19 and chunk 7: 0.09',
#  'Similarity between chunk 19 and chunk 8: 0.13',
#  'Similarity between chunk 19 and chunk 9: 0.07',
#  'Similarity between chunk 2 and chunk 10: 0.09',
#  'Similarity between chunk 2 and chunk 11: 0.13',
#  'Similarity between chunk 2 and chunk 12: 0.15',
#  'Similarity between chunk 2 and chunk 13: 0.18',
#  'Similarity between chunk 2 and chunk 14: 0.16',
#  'Similarity between chunk 2 and chunk 15: 0.26',
#  'Similarity between chunk 2 and chunk 16: 0.08',
#  'Similarity between chunk 2 and chunk 17: 0.21',
#  'Similarity between chunk 2 and chunk 18: 0.19',
#  'Similarity between chunk 2 and chunk 19: 0.13',
#  'Similarity between chunk 2 and chunk 1: 0.01',
#  'Similarity between chunk 2 and chunk 20: 0.04',
#  'Similarity between chunk 2 and chunk 21: 0.11',
#  'Similarity between chunk 2 and chunk 22: 0.12',
#  'Similarity between chunk 2 and chunk 23: 0.08',
#  'Similarity between chunk 2 and chunk 3: 0.25',
#  'Similarity between chunk 2 and chunk 4: 0.20',
#  'Similarity between chunk 2 and chunk 5: 0.32',
#  'Similarity between chunk 2 and chunk 6: 0.11',
#  'Similarity between chunk 2 and chunk 7: 0.26',
#  'Similarity between chunk 2 and chunk 8: 0.18',
#  'Similarity between chunk 2 and chunk 9: 0.13',
#  'Similarity between chunk 20 and chunk 10: 0.01',
#  'Similarity between chunk 20 and chunk 11: 0.00',
#  'Similarity between chunk 20 and chunk 12: 0.04',
#  'Similarity between chunk 20 and chunk 13: 0.02',
#  'Similarity between chunk 20 and chunk 14: 0.02',
#  'Similarity between chunk 20 and chunk 15: 0.04',
#  'Similarity between chunk 20 and chunk 16: 0.02',
#  'Similarity between chunk 20 and chunk 17: 0.10',
#  'Similarity between chunk 20 and chunk 18: 0.15',
#  'Similarity between chunk 20 and chunk 19: 0.02',
#  'Similarity between chunk 20 and chunk 1: 0.00',
#  'Similarity between chunk 20 and chunk 21: 0.17',
#  'Similarity between chunk 20 and chunk 22: 0.00',
#  'Similarity between chunk 20 and chunk 23: 0.04',
#  'Similarity between chunk 20 and chunk 2: 0.04',
#  'Similarity between chunk 20 and chunk 3: 0.06',
#  'Similarity between chunk 20 and chunk 4: 0.04',
#  'Similarity between chunk 20 and chunk 5: 0.12',
#  'Similarity between chunk 20 and chunk 6: 0.01',
#  'Similarity between chunk 20 and chunk 7: 0.01',
#  'Similarity between chunk 20 and chunk 8: 0.06',
#  'Similarity between chunk 20 and chunk 9: 0.02',
#  'Similarity between chunk 21 and chunk 10: 0.02',
#  'Similarity between chunk 21 and chunk 11: 0.03',
#  'Similarity between chunk 21 and chunk 12: 0.03',
#  'Similarity between chunk 21 and chunk 13: 0.03',
#  'Similarity between chunk 21 and chunk 14: 0.02',
#  'Similarity between chunk 21 and chunk 15: 0.04',
#  'Similarity between chunk 21 and chunk 16: 0.01',
#  'Similarity between chunk 21 and chunk 17: 0.08',
#  'Similarity between chunk 21 and chunk 18: 0.09',
#  'Similarity between chunk 21 and chunk 19: 0.06',
#  'Similarity between chunk 21 and chunk 1: 0.02',
#  'Similarity between chunk 21 and chunk 20: 0.17',
#  'Similarity between chunk 21 and chunk 22: 0.08',
#  'Similarity between chunk 21 and chunk 23: 0.10',
#  'Similarity between chunk 21 and chunk 2: 0.11',
#  'Similarity between chunk 21 and chunk 3: 0.06',
#  'Similarity between chunk 21 and chunk 4: 0.10',
#  'Similarity between chunk 21 and chunk 5: 0.14',
#  'Similarity between chunk 21 and chunk 6: 0.03',
#  'Similarity between chunk 21 and chunk 7: 0.03',
#  'Similarity between chunk 21 and chunk 8: 0.05',
#  'Similarity between chunk 21 and chunk 9: 0.02',
#  'Similarity between chunk 22 and chunk 10: 0.04',
#  'Similarity between chunk 22 and chunk 11: 0.02',
#  'Similarity between chunk 22 and chunk 12: 0.02',
#  'Similarity between chunk 22 and chunk 13: 0.05',
#  'Similarity between chunk 22 and chunk 14: 0.06',
#  'Similarity between chunk 22 and chunk 15: 0.06',
#  'Similarity between chunk 22 and chunk 16: 0.00',
#  'Similarity between chunk 22 and chunk 17: 0.00',
#  'Similarity between chunk 22 and chunk 18: 0.03',
#  'Similarity between chunk 22 and chunk 19: 0.08',
#  'Similarity between chunk 22 and chunk 1: 0.02',
#  'Similarity between chunk 22 and chunk 20: 0.00',
#  'Similarity between chunk 22 and chunk 21: 0.08',
#  'Similarity between chunk 22 and chunk 23: 0.03',
#  'Similarity between chunk 22 and chunk 2: 0.12',
#  'Similarity between chunk 22 and chunk 3: 0.10',
#  'Similarity between chunk 22 and chunk 4: 0.01',
#  'Similarity between chunk 22 and chunk 5: 0.07',
#  'Similarity between chunk 22 and chunk 6: 0.00',
#  'Similarity between chunk 22 and chunk 7: 0.06',
#  'Similarity between chunk 22 and chunk 8: 0.03',
#  'Similarity between chunk 22 and chunk 9: 0.00',
#  'Similarity between chunk 23 and chunk 10: 0.12',
#  'Similarity between chunk 23 and chunk 11: 0.15',
#  'Similarity between chunk 23 and chunk 12: 0.09',
#  'Similarity between chunk 23 and chunk 13: 0.04',
#  'Similarity between chunk 23 and chunk 14: 0.05',
#  'Similarity between chunk 23 and chunk 15: 0.08',
#  'Similarity between chunk 23 and chunk 16: 0.03',
#  'Similarity between chunk 23 and chunk 17: 0.04',
#  'Similarity between chunk 23 and chunk 18: 0.14',
#  'Similarity between chunk 23 and chunk 19: 0.09',
#  'Similarity between chunk 23 and chunk 1: 0.01',
#  'Similarity between chunk 23 and chunk 20: 0.04',
#  'Similarity between chunk 23 and chunk 21: 0.10',
#  'Similarity between chunk 23 and chunk 22: 0.03',
#  'Similarity between chunk 23 and chunk 2: 0.08',
#  'Similarity between chunk 23 and chunk 3: 0.09',
#  'Similarity between chunk 23 and chunk 4: 0.05',
#  'Similarity between chunk 23 and chunk 5: 0.11',
#  'Similarity between chunk 23 and chunk 6: 0.04',
#  'Similarity between chunk 23 and chunk 7: 0.03',
#  'Similarity between chunk 23 and chunk 8: 0.11',
#  'Similarity between chunk 23 and chunk 9: 0.02',
#  'Similarity between chunk 3 and chunk 10: 0.15',
#  'Similarity between chunk 3 and chunk 11: 0.13',
#  'Similarity between chunk 3 and chunk 12: 0.17',
#  'Similarity between chunk 3 and chunk 13: 0.18',
#  'Similarity between chunk 3 and chunk 14: 0.15',
#  'Similarity between chunk 3 and chunk 15: 0.25',
#  'Similarity between chunk 3 and chunk 16: 0.12',
#  'Similarity between chunk 3 and chunk 17: 0.18',
#  'Similarity between chunk 3 and chunk 18: 0.21',
#  'Similarity between chunk 3 and chunk 19: 0.10',
#  'Similarity between chunk 3 and chunk 1: 0.03',
#  'Similarity between chunk 3 and chunk 20: 0.06',
#  'Similarity between chunk 3 and chunk 21: 0.06',
#  'Similarity between chunk 3 and chunk 22: 0.10',
#  'Similarity between chunk 3 and chunk 23: 0.09',
#  'Similarity between chunk 3 and chunk 2: 0.25',
#  'Similarity between chunk 3 and chunk 4: 0.21',
#  'Similarity between chunk 3 and chunk 5: 0.22',
#  'Similarity between chunk 3 and chunk 6: 0.12',
#  'Similarity between chunk 3 and chunk 7: 0.14',
#  'Similarity between chunk 3 and chunk 8: 0.20',
#  'Similarity between chunk 3 and chunk 9: 0.13',
#  'Similarity between chunk 4 and chunk 10: 0.08',
#  'Similarity between chunk 4 and chunk 11: 0.08',
#  'Similarity between chunk 4 and chunk 12: 0.13',
#  'Similarity between chunk 4 and chunk 13: 0.15',
#  'Similarity between chunk 4 and chunk 14: 0.11',
#  'Similarity between chunk 4 and chunk 15: 0.14',
#  'Similarity between chunk 4 and chunk 16: 0.09',
#  'Similarity between chunk 4 and chunk 17: 0.14',
#  'Similarity between chunk 4 and chunk 18: 0.16',
#  'Similarity between chunk 4 and chunk 19: 0.06',
#  'Similarity between chunk 4 and chunk 1: 0.02',
#  'Similarity between chunk 4 and chunk 20: 0.04',
#  'Similarity between chunk 4 and chunk 21: 0.10',
#  'Similarity between chunk 4 and chunk 22: 0.01',
#  'Similarity between chunk 4 and chunk 23: 0.05',
#  'Similarity between chunk 4 and chunk 2: 0.20',
#  'Similarity between chunk 4 and chunk 3: 0.21',
#  'Similarity between chunk 4 and chunk 5: 0.22',
#  'Similarity between chunk 4 and chunk 6: 0.13',
#  'Similarity between chunk 4 and chunk 7: 0.14',
#  'Similarity between chunk 4 and chunk 8: 0.18',
#  'Similarity between chunk 4 and chunk 9: 0.07',
#  'Similarity between chunk 5 and chunk 10: 0.11',
#  'Similarity between chunk 5 and chunk 11: 0.14',
#  'Similarity between chunk 5 and chunk 12: 0.13',
#  'Similarity between chunk 5 and chunk 13: 0.14',
#  'Similarity between chunk 5 and chunk 14: 0.08',
#  'Similarity between chunk 5 and chunk 15: 0.16',
#  'Similarity between chunk 5 and chunk 16: 0.44',
#  'Similarity between chunk 5 and chunk 17: 0.18',
#  'Similarity between chunk 5 and chunk 18: 0.22',
#  'Similarity between chunk 5 and chunk 19: 0.07',
#  'Similarity between chunk 5 and chunk 1: 0.02',
#  'Similarity between chunk 5 and chunk 20: 0.12',
#  'Similarity between chunk 5 and chunk 21: 0.14',
#  'Similarity between chunk 5 and chunk 22: 0.07',
#  'Similarity between chunk 5 and chunk 23: 0.11',
#  'Similarity between chunk 5 and chunk 2: 0.32',
#  'Similarity between chunk 5 and chunk 3: 0.22',
#  'Similarity between chunk 5 and chunk 4: 0.22',
#  'Similarity between chunk 5 and chunk 6: 0.14',
#  'Similarity between chunk 5 and chunk 7: 0.14',
#  'Similarity between chunk 5 and chunk 8: 0.18',
#  'Similarity between chunk 5 and chunk 9: 0.08',
#  'Similarity between chunk 6 and chunk 10: 0.04',
#  'Similarity between chunk 6 and chunk 11: 0.05',
#  'Similarity between chunk 6 and chunk 12: 0.12',
#  'Similarity between chunk 6 and chunk 13: 0.10',
#  'Similarity between chunk 6 and chunk 14: 0.08',
#  'Similarity between chunk 6 and chunk 15: 0.10',
#  'Similarity between chunk 6 and chunk 16: 0.17',
#  'Similarity between chunk 6 and chunk 17: 0.08',
#  'Similarity between chunk 6 and chunk 18: 0.08',
#  'Similarity between chunk 6 and chunk 19: 0.04',
#  'Similarity between chunk 6 and chunk 1: 0.04',
#  'Similarity between chunk 6 and chunk 20: 0.01',
#  'Similarity between chunk 6 and chunk 21: 0.03',
#  'Similarity between chunk 6 and chunk 22: 0.00',
#  'Similarity between chunk 6 and chunk 23: 0.04',
#  'Similarity between chunk 6 and chunk 2: 0.11',
#  'Similarity between chunk 6 and chunk 3: 0.12',
#  'Similarity between chunk 6 and chunk 4: 0.13',
#  'Similarity between chunk 6 and chunk 5: 0.14',
#  'Similarity between chunk 6 and chunk 7: 0.11',
#  'Similarity between chunk 6 and chunk 8: 0.19',
#  'Similarity between chunk 6 and chunk 9: 0.06',
#  'Similarity between chunk 7 and chunk 10: 0.07',
#  'Similarity between chunk 7 and chunk 11: 0.11',
#  'Similarity between chunk 7 and chunk 12: 0.13',
#  'Similarity between chunk 7 and chunk 13: 0.16',
#  'Similarity between chunk 7 and chunk 14: 0.13',
#  'Similarity between chunk 7 and chunk 15: 0.17',
#  'Similarity between chunk 7 and chunk 16: 0.09',
#  'Similarity between chunk 7 and chunk 17: 0.17',
#  'Similarity between chunk 7 and chunk 18: 0.14',
#  'Similarity between chunk 7 and chunk 19: 0.09',
#  'Similarity between chunk 7 and chunk 1: 0.03',
#  'Similarity between chunk 7 and chunk 20: 0.01',
#  'Similarity between chunk 7 and chunk 21: 0.03',
#  'Similarity between chunk 7 and chunk 22: 0.06',
#  'Similarity between chunk 7 and chunk 23: 0.03',
#  'Similarity between chunk 7 and chunk 2: 0.26',
#  'Similarity between chunk 7 and chunk 3: 0.14',
#  'Similarity between chunk 7 and chunk 4: 0.14',
#  'Similarity between chunk 7 and chunk 5: 0.14',
#  'Similarity between chunk 7 and chunk 6: 0.11',
#  'Similarity between chunk 7 and chunk 8: 0.19',
#  'Similarity between chunk 7 and chunk 9: 0.11',
#  'Similarity between chunk 8 and chunk 10: 0.20',
#  'Similarity between chunk 8 and chunk 11: 0.11',
#  'Similarity between chunk 8 and chunk 12: 0.25',
#  'Similarity between chunk 8 and chunk 13: 0.27',
#  'Similarity between chunk 8 and chunk 14: 0.20',
#  'Similarity between chunk 8 and chunk 15: 0.29',
#  'Similarity between chunk 8 and chunk 16: 0.08',
#  'Similarity between chunk 8 and chunk 17: 0.17',
#  'Similarity between chunk 8 and chunk 18: 0.19',
#  'Similarity between chunk 8 and chunk 19: 0.13',
#  'Similarity between chunk 8 and chunk 1: 0.02',
#  'Similarity between chunk 8 and chunk 20: 0.06',
#  'Similarity between chunk 8 and chunk 21: 0.05',
#  'Similarity between chunk 8 and chunk 22: 0.03',
#  'Similarity between chunk 8 and chunk 23: 0.11',
#  'Similarity between chunk 8 and chunk 2: 0.18',
#  'Similarity between chunk 8 and chunk 3: 0.20',
#  'Similarity between chunk 8 and chunk 4: 0.18',
#  'Similarity between chunk 8 and chunk 5: 0.18',
#  'Similarity between chunk 8 and chunk 6: 0.19',
#  'Similarity between chunk 8 and chunk 7: 0.19',
#  'Similarity between chunk 8 and chunk 9: 0.17',
#  'Similarity between chunk 9 and chunk 10: 0.08',
#  'Similarity between chunk 9 and chunk 11: 0.08',
#  'Similarity between chunk 9 and chunk 12: 0.13',
#  'Similarity between chunk 9 and chunk 13: 0.15',
#  'Similarity between chunk 9 and chunk 14: 0.11',
#  'Similarity between chunk 9 and chunk 15: 0.20',
#  'Similarity between chunk 9 and chunk 16: 0.01',
#  'Similarity between chunk 9 and chunk 17: 0.14',
#  'Similarity between chunk 9 and chunk 18: 0.09',
#  'Similarity between chunk 9 and chunk 19: 0.07',
#  'Similarity between chunk 9 and chunk 1: 0.03',
#  'Similarity between chunk 9 and chunk 20: 0.02',
#  'Similarity between chunk 9 and chunk 21: 0.02',
#  'Similarity between chunk 9 and chunk 22: 0.00',
#  'Similarity between chunk 9 and chunk 23: 0.02',
#  'Similarity between chunk 9 and chunk 2: 0.13',
#  'Similarity between chunk 9 and chunk 3: 0.13',
#  'Similarity between chunk 9 and chunk 4: 0.07',
#  'Similarity between chunk 9 and chunk 5: 0.08',
#  'Similarity between chunk 9 and chunk 6: 0.06',
#  'Similarity between chunk 9 and chunk 7: 0.11',
#  'Similarity between chunk 9 and chunk 8: 0.17',
#  'Similarity between chunk 1 and chunk 2: 0.00',
#  'Similarity between chunk 1 and chunk 3: 0.02',
#  'Similarity between chunk 1 and chunk 4: 0.00',
#  'Similarity between chunk 1 and chunk 5: 0.01',
#  'Similarity between chunk 1 and chunk 6: 0.01',
#  'Similarity between chunk 1 and chunk 7: 0.02',
#  'Similarity between chunk 1 and chunk 8: 0.00',
#  'Similarity between chunk 1 and chunk 9: 0.00',
#  'Similarity between chunk 1 and chunk 10: 0.04',
#  'Similarity between chunk 1 and chunk 11: 0.00',
#  'Similarity between chunk 1 and chunk 12: 0.00',
#  'Similarity between chunk 1 and chunk 13: 0.00',
#  'Similarity between chunk 1 and chunk 14: 0.00',
#  'Similarity between chunk 1 and chunk 15: 0.00',
#  'Similarity between chunk 1 and chunk 16: 0.00',
#  'Similarity between chunk 1 and chunk 17: 0.02',
#  'Similarity between chunk 1 and chunk 18: 0.00',
#  'Similarity between chunk 1 and chunk 19: 0.00',
#  'Similarity between chunk 1 and chunk 20: 0.00',
#  'Similarity between chunk 1 and chunk 21: 0.04',
#  'Similarity between chunk 1 and chunk 22: 0.05',
#  'Similarity between chunk 1 and chunk 23: 0.00',
#  'Similarity between chunk 2 and chunk 1: 0.00',
#  'Similarity between chunk 2 and chunk 3: 0.17',
#  'Similarity between chunk 2 and chunk 4: 0.18',
#  'Similarity between chunk 2 and chunk 5: 0.29',
#  'Similarity between chunk 2 and chunk 6: 0.05',
#  'Similarity between chunk 2 and chunk 7: 0.15',
#  'Similarity between chunk 2 and chunk 8: 0.05',
#  'Similarity between chunk 2 and chunk 9: 0.03',
#  'Similarity between chunk 2 and chunk 10: 0.08',
#  'Similarity between chunk 2 and chunk 11: 0.05',
#  'Similarity between chunk 2 and chunk 12: 0.03',
#  'Similarity between chunk 2 and chunk 13: 0.09',
#  'Similarity between chunk 2 and chunk 14: 0.11',
#  'Similarity between chunk 2 and chunk 15: 0.15',
#  'Similarity between chunk 2 and chunk 16: 0.02',
#  'Similarity between chunk 2 and chunk 17: 0.15',
#  'Similarity between chunk 2 and chunk 18: 0.07',
#  'Similarity between chunk 2 and chunk 19: 0.10',
#  'Similarity between chunk 2 and chunk 20: 0.02',
#  'Similarity between chunk 2 and chunk 21: 0.10',
#  'Similarity between chunk 2 and chunk 22: 0.18',
#  'Similarity between chunk 2 and chunk 23: 0.05',
#  'Similarity between chunk 3 and chunk 1: 0.02',
#  'Similarity between chunk 3 and chunk 2: 0.17',
#  'Similarity between chunk 3 and chunk 4: 0.15',
#  'Similarity between chunk 3 and chunk 5: 0.13',
#  'Similarity between chunk 3 and chunk 6: 0.04',
#  'Similarity between chunk 3 and chunk 7: 0.02',
#  'Similarity between chunk 3 and chunk 8: 0.05',
#  'Similarity between chunk 3 and chunk 9: 0.02',
#  'Similarity between chunk 3 and chunk 10: 0.06',
#  'Similarity between chunk 3 and chunk 11: 0.04',
#  'Similarity between chunk 3 and chunk 12: 0.03',
#  'Similarity between chunk 3 and chunk 13: 0.08',
#  'Similarity between chunk 3 and chunk 14: 0.10',
#  'Similarity between chunk 3 and chunk 15: 0.13',
#  'Similarity between chunk 3 and chunk 16: 0.06',
#  'Similarity between chunk 3 and chunk 17: 0.09',
#  'Similarity between chunk 3 and chunk 18: 0.11',
#  'Similarity between chunk 3 and chunk 19: 0.03',
#  'Similarity between chunk 3 and chunk 20: 0.03',
#  'Similarity between chunk 3 and chunk 21: 0.05',
#  'Similarity between chunk 3 and chunk 22: 0.15',
#  'Similarity between chunk 3 and chunk 23: 0.03',
#  'Similarity between chunk 4 and chunk 1: 0.00',
#  'Similarity between chunk 4 and chunk 2: 0.18',
#  'Similarity between chunk 4 and chunk 3: 0.15',
#  'Similarity between chunk 4 and chunk 5: 0.17',
#  'Similarity between chunk 4 and chunk 6: 0.02',
#  'Similarity between chunk 4 and chunk 7: 0.00',
#  'Similarity between chunk 4 and chunk 8: 0.01',
#  'Similarity between chunk 4 and chunk 9: 0.00',
#  'Similarity between chunk 4 and chunk 10: 0.01',
#  'Similarity between chunk 4 and chunk 11: 0.00',
#  'Similarity between chunk 4 and chunk 12: 0.00',
#  'Similarity between chunk 4 and chunk 13: 0.01',
#  'Similarity between chunk 4 and chunk 14: 0.03',
#  'Similarity between chunk 4 and chunk 15: 0.02',
#  'Similarity between chunk 4 and chunk 16: 0.01',
#  'Similarity between chunk 4 and chunk 17: 0.06',
#  'Similarity between chunk 4 and chunk 18: 0.05',
#  'Similarity between chunk 4 and chunk 19: 0.01',
#  'Similarity between chunk 4 and chunk 20: 0.03',
#  'Similarity between chunk 4 and chunk 21: 0.10',
#  'Similarity between chunk 4 and chunk 22: 0.02',
#  'Similarity between chunk 4 and chunk 23: 0.02',
#  'Similarity between chunk 5 and chunk 1: 0.01',
#  'Similarity between chunk 5 and chunk 2: 0.29',
#  'Similarity between chunk 5 and chunk 3: 0.13',
#  'Similarity between chunk 5 and chunk 4: 0.17',
#  'Similarity between chunk 5 and chunk 6: 0.11',
#  'Similarity between chunk 5 and chunk 7: 0.02',
#  'Similarity between chunk 5 and chunk 8: 0.02',
#  'Similarity between chunk 5 and chunk 9: 0.00',
#  'Similarity between chunk 5 and chunk 10: 0.07',
#  'Similarity between chunk 5 and chunk 11: 0.05',
#  'Similarity between chunk 5 and chunk 12: 0.01',
#  'Similarity between chunk 5 and chunk 13: 0.04',
#  'Similarity between chunk 5 and chunk 14: 0.03',
#  'Similarity between chunk 5 and chunk 15: 0.08',
#  'Similarity between chunk 5 and chunk 16: 0.37',
#  'Similarity between chunk 5 and chunk 17: 0.11',
#  'Similarity between chunk 5 and chunk 18: 0.06',
#  'Similarity between chunk 5 and chunk 19: 0.04',
#  'Similarity between chunk 5 and chunk 20: 0.14',
#  'Similarity between chunk 5 and chunk 21: 0.13',
#  'Similarity between chunk 5 and chunk 22: 0.09',
#  'Similarity between chunk 5 and chunk 23: 0.03',
#  'Similarity between chunk 6 and chunk 1: 0.01',
#  'Similarity between chunk 6 and chunk 2: 0.05',
#  'Similarity between chunk 6 and chunk 3: 0.04',
#  'Similarity between chunk 6 and chunk 4: 0.02',
#  'Similarity between chunk 6 and chunk 5: 0.11',
#  'Similarity between chunk 6 and chunk 7: 0.07',
#  'Similarity between chunk 6 and chunk 8: 0.04',
#  'Similarity between chunk 6 and chunk 9: 0.00',
#  'Similarity between chunk 6 and chunk 10: 0.00',
#  'Similarity between chunk 6 and chunk 11: 0.00',
#  'Similarity between chunk 6 and chunk 12: 0.01',
#  'Similarity between chunk 6 and chunk 13: 0.03',
#  'Similarity between chunk 6 and chunk 14: 0.03',
#  'Similarity between chunk 6 and chunk 15: 0.02',
#  'Similarity between chunk 6 and chunk 16: 0.21',
#  'Similarity between chunk 6 and chunk 17: 0.03',
#  'Similarity between chunk 6 and chunk 18: 0.01',
#  'Similarity between chunk 6 and chunk 19: 0.02',
#  'Similarity between chunk 6 and chunk 20: 0.00',
#  'Similarity between chunk 6 and chunk 21: 0.01',
#  'Similarity between chunk 6 and chunk 22: 0.00',
#  'Similarity between chunk 6 and chunk 23: 0.01',
#  'Similarity between chunk 7 and chunk 1: 0.02',
#  'Similarity between chunk 7 and chunk 2: 0.15',
#  'Similarity between chunk 7 and chunk 3: 0.02',
#  'Similarity between chunk 7 and chunk 4: 0.00',
#  'Similarity between chunk 7 and chunk 5: 0.02',
#  'Similarity between chunk 7 and chunk 6: 0.07',
#  'Similarity between chunk 7 and chunk 8: 0.04',
#  'Similarity between chunk 7 and chunk 9: 0.03',
#  'Similarity between chunk 7 and chunk 10: 0.02',
#  'Similarity between chunk 7 and chunk 11: 0.02',
#  'Similarity between chunk 7 and chunk 12: 0.04',
#  'Similarity between chunk 7 and chunk 13: 0.09',
#  'Similarity between chunk 7 and chunk 14: 0.12',
#  'Similarity between chunk 7 and chunk 15: 0.11',
#  'Similarity between chunk 7 and chunk 16: 0.03',
#  'Similarity between chunk 7 and chunk 17: 0.07',
#  'Similarity between chunk 7 and chunk 18: 0.02',
#  'Similarity between chunk 7 and chunk 19: 0.08',
#  'Similarity between chunk 7 and chunk 20: 0.00',
#  'Similarity between chunk 7 and chunk 21: 0.00',
#  'Similarity between chunk 7 and chunk 22: 0.11',
#  'Similarity between chunk 7 and chunk 23: 0.00',
#  'Similarity between chunk 8 and chunk 1: 0.00',
#  'Similarity between chunk 8 and chunk 2: 0.05',
#  'Similarity between chunk 8 and chunk 3: 0.05',
#  'Similarity between chunk 8 and chunk 4: 0.01',
#  'Similarity between chunk 8 and chunk 5: 0.02',
#  'Similarity between chunk 8 and chunk 6: 0.04',
#  'Similarity between chunk 8 and chunk 7: 0.04',
#  'Similarity between chunk 8 and chunk 9: 0.10',
#  'Similarity between chunk 8 and chunk 10: 0.17',
#  'Similarity between chunk 8 and chunk 11: 0.01',
#  'Similarity between chunk 8 and chunk 12: 0.06',
#  'Similarity between chunk 8 and chunk 13: 0.13',
#  'Similarity between chunk 8 and chunk 14: 0.09',
#  'Similarity between chunk 8 and chunk 15: 0.16',
#  'Similarity between chunk 8 and chunk 16: 0.00',
#  'Similarity between chunk 8 and chunk 17: 0.00',
#  'Similarity between chunk 8 and chunk 18: 0.01',
#  'Similarity between chunk 8 and chunk 19: 0.05',
#  'Similarity between chunk 8 and chunk 20: 0.00',
#  'Similarity between chunk 8 and chunk 21: 0.00',
#  'Similarity between chunk 8 and chunk 22: 0.07',
#  'Similarity between chunk 8 and chunk 23: 0.02',
#  'Similarity between chunk 9 and chunk 1: 0.00',
#  'Similarity between chunk 9 and chunk 2: 0.03',
#  'Similarity between chunk 9 and chunk 3: 0.02',
#  'Similarity between chunk 9 and chunk 4: 0.00',
#  'Similarity between chunk 9 and chunk 5: 0.00',
#  'Similarity between chunk 9 and chunk 6: 0.00',
#  'Similarity between chunk 9 and chunk 7: 0.03',
#  'Similarity between chunk 9 and chunk 8: 0.10',
#  'Similarity between chunk 9 and chunk 10: 0.09',
#  'Similarity between chunk 9 and chunk 11: 0.04',
#  'Similarity between chunk 9 and chunk 12: 0.13',
#  'Similarity between chunk 9 and chunk 13: 0.04',
#  'Similarity between chunk 9 and chunk 14: 0.03',
#  'Similarity between chunk 9 and chunk 15: 0.07',
#  'Similarity between chunk 9 and chunk 16: 0.00',
#  'Similarity between chunk 9 and chunk 17: 0.04',
#  'Similarity between chunk 9 and chunk 18: 0.03',
#  'Similarity between chunk 9 and chunk 19: 0.00',
#  'Similarity between chunk 9 and chunk 20: 0.00',
#  'Similarity between chunk 9 and chunk 21: 0.00',
#  'Similarity between chunk 9 and chunk 22: 0.00',
#  'Similarity between chunk 9 and chunk 23: 0.00',
#  'Similarity between chunk 10 and chunk 1: 0.04',
#  'Similarity between chunk 10 and chunk 2: 0.08',
#  'Similarity between chunk 10 and chunk 3: 0.06',
#  'Similarity between chunk 10 and chunk 4: 0.01',
#  'Similarity between chunk 10 and chunk 5: 0.07',
#  'Similarity between chunk 10 and chunk 6: 0.00',
#  'Similarity between chunk 10 and chunk 7: 0.02',
#  'Similarity between chunk 10 and chunk 8: 0.17',
#  'Similarity between chunk 10 and chunk 9: 0.09',
#  'Similarity between chunk 10 and chunk 11: 0.04',
#  'Similarity between chunk 10 and chunk 12: 0.01',
#  'Similarity between chunk 10 and chunk 13: 0.08',
#  'Similarity between chunk 10 and chunk 14: 0.18',
#  'Similarity between chunk 10 and chunk 15: 0.12',
#  'Similarity between chunk 10 and chunk 16: 0.00',
#  'Similarity between chunk 10 and chunk 17: 0.04',
#  'Similarity between chunk 10 and chunk 18: 0.02',
#  'Similarity between chunk 10 and chunk 19: 0.07',
#  'Similarity between chunk 10 and chunk 20: 0.00',
#  'Similarity between chunk 10 and chunk 21: 0.00',
#  'Similarity between chunk 10 and chunk 22: 0.09',
#  'Similarity between chunk 10 and chunk 23: 0.01',
#  'Similarity between chunk 11 and chunk 1: 0.00',
#  'Similarity between chunk 11 and chunk 2: 0.05',
#  'Similarity between chunk 11 and chunk 3: 0.04',
#  'Similarity between chunk 11 and chunk 4: 0.00',
#  'Similarity between chunk 11 and chunk 5: 0.05',
#  'Similarity between chunk 11 and chunk 6: 0.00',
#  'Similarity between chunk 11 and chunk 7: 0.02',
#  'Similarity between chunk 11 and chunk 8: 0.01',
#  'Similarity between chunk 11 and chunk 9: 0.04',
#  'Similarity between chunk 11 and chunk 10: 0.04',
#  'Similarity between chunk 11 and chunk 12: 0.04',
#  'Similarity between chunk 11 and chunk 13: 0.01',
#  'Similarity between chunk 11 and chunk 14: 0.00',
#  'Similarity between chunk 11 and chunk 15: 0.09',
#  'Similarity between chunk 11 and chunk 16: 0.00',
#  'Similarity between chunk 11 and chunk 17: 0.03',
#  'Similarity between chunk 11 and chunk 18: 0.01',
#  'Similarity between chunk 11 and chunk 19: 0.00',
#  'Similarity between chunk 11 and chunk 20: 0.00',
#  'Similarity between chunk 11 and chunk 21: 0.02',
#  'Similarity between chunk 11 and chunk 22: 0.00',
#  'Similarity between chunk 11 and chunk 23: 0.12',
#  'Similarity between chunk 12 and chunk 1: 0.00',
#  'Similarity between chunk 12 and chunk 2: 0.03',
#  'Similarity between chunk 12 and chunk 3: 0.03',
#  'Similarity between chunk 12 and chunk 4: 0.00',
#  'Similarity between chunk 12 and chunk 5: 0.01',
#  'Similarity between chunk 12 and chunk 6: 0.01',
#  'Similarity between chunk 12 and chunk 7: 0.04',
#  'Similarity between chunk 12 and chunk 8: 0.06',
#  'Similarity between chunk 12 and chunk 9: 0.13',
#  'Similarity between chunk 12 and chunk 10: 0.01',
#  'Similarity between chunk 12 and chunk 11: 0.04',
#  'Similarity between chunk 12 and chunk 13: 0.06',
#  'Similarity between chunk 12 and chunk 14: 0.14',
#  'Similarity between chunk 12 and chunk 15: 0.11',
#  'Similarity between chunk 12 and chunk 16: 0.00',
#  'Similarity between chunk 12 and chunk 17: 0.02',
#  'Similarity between chunk 12 and chunk 18: 0.03',
#  'Similarity between chunk 12 and chunk 19: 0.01',
#  'Similarity between chunk 12 and chunk 20: 0.00',
#  'Similarity between chunk 12 and chunk 21: 0.00',
#  'Similarity between chunk 12 and chunk 22: 0.00',
#  'Similarity between chunk 12 and chunk 23: 0.01',
#  'Similarity between chunk 13 and chunk 1: 0.00',
#  'Similarity between chunk 13 and chunk 2: 0.09',
#  'Similarity between chunk 13 and chunk 3: 0.08',
#  'Similarity between chunk 13 and chunk 4: 0.01',
#  'Similarity between chunk 13 and chunk 5: 0.04',
#  'Similarity between chunk 13 and chunk 6: 0.03',
#  'Similarity between chunk 13 and chunk 7: 0.09',
#  'Similarity between chunk 13 and chunk 8: 0.13',
#  'Similarity between chunk 13 and chunk 9: 0.04',
#  'Similarity between chunk 13 and chunk 10: 0.08',
#  'Similarity between chunk 13 and chunk 11: 0.01',
#  'Similarity between chunk 13 and chunk 12: 0.06',
#  'Similarity between chunk 13 and chunk 14: 0.26',
#  'Similarity between chunk 13 and chunk 15: 0.47',
#  'Similarity between chunk 13 and chunk 16: 0.01',
#  'Similarity between chunk 13 and chunk 17: 0.02',
#  'Similarity between chunk 13 and chunk 18: 0.03',
#  'Similarity between chunk 13 and chunk 19: 0.07',
#  'Similarity between chunk 13 and chunk 20: 0.00',
#  'Similarity between chunk 13 and chunk 21: 0.00',
#  'Similarity between chunk 13 and chunk 22: 0.09',
#  'Similarity between chunk 13 and chunk 23: 0.00',
#  'Similarity between chunk 14 and chunk 1: 0.00',
#  'Similarity between chunk 14 and chunk 2: 0.11',
#  'Similarity between chunk 14 and chunk 3: 0.10',
#  'Similarity between chunk 14 and chunk 4: 0.03',
#  'Similarity between chunk 14 and chunk 5: 0.03',
#  'Similarity between chunk 14 and chunk 6: 0.03',
#  'Similarity between chunk 14 and chunk 7: 0.12',
#  'Similarity between chunk 14 and chunk 8: 0.09',
#  'Similarity between chunk 14 and chunk 9: 0.03',
#  'Similarity between chunk 14 and chunk 10: 0.18',
#  'Similarity between chunk 14 and chunk 11: 0.00',
#  'Similarity between chunk 14 and chunk 12: 0.14',
#  'Similarity between chunk 14 and chunk 13: 0.26',
#  'Similarity between chunk 14 and chunk 15: 0.44',
#  'Similarity between chunk 14 and chunk 16: 0.02',
#  'Similarity between chunk 14 and chunk 17: 0.03',
#  'Similarity between chunk 14 and chunk 18: 0.06',
#  'Similarity between chunk 14 and chunk 19: 0.06',
#  'Similarity between chunk 14 and chunk 20: 0.00',
#  'Similarity between chunk 14 and chunk 21: 0.02',
#  'Similarity between chunk 14 and chunk 22: 0.11',
#  'Similarity between chunk 14 and chunk 23: 0.00',
#  'Similarity between chunk 15 and chunk 1: 0.00',
#  'Similarity between chunk 15 and chunk 2: 0.15',
#  'Similarity between chunk 15 and chunk 3: 0.13',
#  'Similarity between chunk 15 and chunk 4: 0.02',
#  'Similarity between chunk 15 and chunk 5: 0.08',
#  'Similarity between chunk 15 and chunk 6: 0.02',
#  'Similarity between chunk 15 and chunk 7: 0.11',
#  'Similarity between chunk 15 and chunk 8: 0.16',
#  'Similarity between chunk 15 and chunk 9: 0.07',
#  'Similarity between chunk 15 and chunk 10: 0.12',
#  'Similarity between chunk 15 and chunk 11: 0.09',
#  'Similarity between chunk 15 and chunk 12: 0.11',
#  'Similarity between chunk 15 and chunk 13: 0.47',
#  'Similarity between chunk 15 and chunk 14: 0.44',
#  'Similarity between chunk 15 and chunk 16: 0.02',
#  'Similarity between chunk 15 and chunk 17: 0.02',
#  'Similarity between chunk 15 and chunk 18: 0.05',
#  'Similarity between chunk 15 and chunk 19: 0.04',
#  'Similarity between chunk 15 and chunk 20: 0.00',
#  'Similarity between chunk 15 and chunk 21: 0.01',
#  'Similarity between chunk 15 and chunk 22: 0.06',
#  'Similarity between chunk 15 and chunk 23: 0.05',
#  'Similarity between chunk 16 and chunk 1: 0.00',
#  'Similarity between chunk 16 and chunk 2: 0.02',
#  'Similarity between chunk 16 and chunk 3: 0.06',
#  'Similarity between chunk 16 and chunk 4: 0.01',
#  'Similarity between chunk 16 and chunk 5: 0.37',
#  'Similarity between chunk 16 and chunk 6: 0.21',
#  'Similarity between chunk 16 and chunk 7: 0.03',
#  'Similarity between chunk 16 and chunk 8: 0.00',
#  'Similarity between chunk 16 and chunk 9: 0.00',
#  'Similarity between chunk 16 and chunk 10: 0.00',
#  'Similarity between chunk 16 and chunk 11: 0.00',
#  'Similarity between chunk 16 and chunk 12: 0.00',
#  'Similarity between chunk 16 and chunk 13: 0.01',
#  'Similarity between chunk 16 and chunk 14: 0.02',
#  'Similarity between chunk 16 and chunk 15: 0.02',
#  'Similarity between chunk 16 and chunk 17: 0.01',
#  'Similarity between chunk 16 and chunk 18: 0.02',
#  'Similarity between chunk 16 and chunk 19: 0.01',
#  'Similarity between chunk 16 and chunk 20: 0.00',
#  'Similarity between chunk 16 and chunk 21: 0.00',
#  'Similarity between chunk 16 and chunk 22: 0.00',
#  'Similarity between chunk 16 and chunk 23: 0.00',
#  'Similarity between chunk 17 and chunk 1: 0.02',
#  'Similarity between chunk 17 and chunk 2: 0.15',
#  'Similarity between chunk 17 and chunk 3: 0.09',
#  'Similarity between chunk 17 and chunk 4: 0.06',
#  'Similarity between chunk 17 and chunk 5: 0.11',
#  'Similarity between chunk 17 and chunk 6: 0.03',
#  'Similarity between chunk 17 and chunk 7: 0.07',
#  'Similarity between chunk 17 and chunk 8: 0.00',
#  'Similarity between chunk 17 and chunk 9: 0.04',
#  'Similarity between chunk 17 and chunk 10: 0.04',
#  'Similarity between chunk 17 and chunk 11: 0.03',
#  'Similarity between chunk 17 and chunk 12: 0.02',
#  'Similarity between chunk 17 and chunk 13: 0.02',
#  'Similarity between chunk 17 and chunk 14: 0.03',
#  'Similarity between chunk 17 and chunk 15: 0.02',
#  'Similarity between chunk 17 and chunk 16: 0.01',
#  'Similarity between chunk 17 and chunk 18: 0.05',
#  'Similarity between chunk 17 and chunk 19: 0.05',
#  'Similarity between chunk 17 and chunk 20: 0.00',
#  'Similarity between chunk 17 and chunk 21: 0.05',
#  'Similarity between chunk 17 and chunk 22: 0.00',
#  'Similarity between chunk 17 and chunk 23: 0.01',
#  'Similarity between chunk 18 and chunk 1: 0.00',
#  'Similarity between chunk 18 and chunk 2: 0.07',
#  'Similarity between chunk 18 and chunk 3: 0.11',
#  'Similarity between chunk 18 and chunk 4: 0.05',
#  'Similarity between chunk 18 and chunk 5: 0.06',
#  'Similarity between chunk 18 and chunk 6: 0.01',
#  'Similarity between chunk 18 and chunk 7: 0.02',
#  'Similarity between chunk 18 and chunk 8: 0.01',
#  'Similarity between chunk 18 and chunk 9: 0.03',
#  'Similarity between chunk 18 and chunk 10: 0.02',
#  'Similarity between chunk 18 and chunk 11: 0.01',
#  'Similarity between chunk 18 and chunk 12: 0.03',
#  'Similarity between chunk 18 and chunk 13: 0.03',
#  'Similarity between chunk 18 and chunk 14: 0.06',
#  'Similarity between chunk 18 and chunk 15: 0.05',
#  'Similarity between chunk 18 and chunk 16: 0.02',
#  'Similarity between chunk 18 and chunk 17: 0.05',
#  'Similarity between chunk 18 and chunk 19: 0.03',
#  'Similarity between chunk 18 and chunk 20: 0.04',
#  'Similarity between chunk 18 and chunk 21: 0.00',
#  'Similarity between chunk 18 and chunk 22: 0.00',
#  'Similarity between chunk 18 and chunk 23: 0.06',
#  'Similarity between chunk 19 and chunk 1: 0.00',
#  'Similarity between chunk 19 and chunk 2: 0.10',
#  'Similarity between chunk 19 and chunk 3: 0.03',
#  'Similarity between chunk 19 and chunk 4: 0.01',
#  'Similarity between chunk 19 and chunk 5: 0.04',
#  'Similarity between chunk 19 and chunk 6: 0.02',
#  'Similarity between chunk 19 and chunk 7: 0.08',
#  'Similarity between chunk 19 and chunk 8: 0.05',
#  'Similarity between chunk 19 and chunk 9: 0.00',
#  'Similarity between chunk 19 and chunk 10: 0.07',
#  'Similarity between chunk 19 and chunk 11: 0.00',
#  'Similarity between chunk 19 and chunk 12: 0.01',
#  'Similarity between chunk 19 and chunk 13: 0.07',
#  'Similarity between chunk 19 and chunk 14: 0.06',
#  'Similarity between chunk 19 and chunk 15: 0.04',
#  'Similarity between chunk 19 and chunk 16: 0.01',
#  'Similarity between chunk 19 and chunk 17: 0.05',
#  'Similarity between chunk 19 and chunk 18: 0.03',
#  'Similarity between chunk 19 and chunk 20: 0.00',
#  'Similarity between chunk 19 and chunk 21: 0.04',
#  'Similarity between chunk 19 and chunk 22: 0.11',
#  'Similarity between chunk 19 and chunk 23: 0.04',
#  'Similarity between chunk 20 and chunk 1: 0.00',
#  'Similarity between chunk 20 and chunk 2: 0.02',
#  'Similarity between chunk 20 and chunk 3: 0.03',
#  'Similarity between chunk 20 and chunk 4: 0.03',
#  'Similarity between chunk 20 and chunk 5: 0.14',
#  'Similarity between chunk 20 and chunk 6: 0.00',
#  'Similarity between chunk 20 and chunk 7: 0.00',
#  'Similarity between chunk 20 and chunk 8: 0.00',
#  'Similarity between chunk 20 and chunk 9: 0.00',
#  'Similarity between chunk 20 and chunk 10: 0.00',
#  'Similarity between chunk 20 and chunk 11: 0.00',
#  'Similarity between chunk 20 and chunk 12: 0.00',
#  'Similarity between chunk 20 and chunk 13: 0.00',
#  'Similarity between chunk 20 and chunk 14: 0.00',
#  'Similarity between chunk 20 and chunk 15: 0.00',
#  'Similarity between chunk 20 and chunk 16: 0.00',
#  'Similarity between chunk 20 and chunk 17: 0.00',
#  'Similarity between chunk 20 and chunk 18: 0.04',
#  'Similarity between chunk 20 and chunk 19: 0.00',
#  'Similarity between chunk 20 and chunk 21: 0.03',
#  'Similarity between chunk 20 and chunk 22: 0.00',
#  'Similarity between chunk 20 and chunk 23: 0.00',
#  'Similarity between chunk 21 and chunk 1: 0.04',
#  'Similarity between chunk 21 and chunk 2: 0.10',
#  'Similarity between chunk 21 and chunk 3: 0.05',
#  'Similarity between chunk 21 and chunk 4: 0.10',
#  'Similarity between chunk 21 and chunk 5: 0.13',
#  'Similarity between chunk 21 and chunk 6: 0.01',
#  'Similarity between chunk 21 and chunk 7: 0.00',
#  'Similarity between chunk 21 and chunk 8: 0.00',
#  'Similarity between chunk 21 and chunk 9: 0.00',
#  'Similarity between chunk 21 and chunk 10: 0.00',
#  'Similarity between chunk 21 and chunk 11: 0.02',
#  'Similarity between chunk 21 and chunk 12: 0.00',
#  'Similarity between chunk 21 and chunk 13: 0.00',
#  'Similarity between chunk 21 and chunk 14: 0.02',
#  'Similarity between chunk 21 and chunk 15: 0.01',
#  'Similarity between chunk 21 and chunk 16: 0.00',
#  'Similarity between chunk 21 and chunk 17: 0.05',
#  'Similarity between chunk 21 and chunk 18: 0.00',
#  'Similarity between chunk 21 and chunk 19: 0.04',
#  'Similarity between chunk 21 and chunk 20: 0.03',
#  'Similarity between chunk 21 and chunk 22: 0.04',
#  'Similarity between chunk 21 and chunk 23: 0.09',
#  'Similarity between chunk 22 and chunk 1: 0.05',
#  'Similarity between chunk 22 and chunk 2: 0.18',
#  'Similarity between chunk 22 and chunk 3: 0.15',
#  'Similarity between chunk 22 and chunk 4: 0.02',
#  'Similarity between chunk 22 and chunk 5: 0.09',
#  'Similarity between chunk 22 and chunk 6: 0.00',
#  'Similarity between chunk 22 and chunk 7: 0.11',
#  'Similarity between chunk 22 and chunk 8: 0.07',
#  'Similarity between chunk 22 and chunk 9: 0.00',
#  'Similarity between chunk 22 and chunk 10: 0.09',
#  ...]

# %%
partitions
# Out:
# ["Is\nYour Marriage R eliable? D ivorce A nalysiswith Machine \nLearningA lgorithm\ns  \nJue Kong\n \nChang'anuniversity \nShangYuanRoad \nXi'an,China, \n710021\n \n+8 618994535561 \n2017901295@chd.edu.cn \n: \nThese aut hors cont ribut ed equal ly to this work. *: cor responding aut hor \nTianruiChai\n*\n \nBeihangUniversity \nXueYuanRoadNo.37 \nBeijing,China,100191 \n+8618914739576 trchai@buaa.edu.cn",
#  "ABSTRA CT\n \nIn \nrece nt y ears, g\nlobal divorc e ra te is still  high\n. What kind of \ncoupl e will divorc e  and what factors lea d to divorc e are  \nim\nporta nt \nproble ms tha\nt \nworth study ing . In this paper , \nwe\n apply  three \nmac hine  lea rning al gorithm\ns \n(Support Vec tor Mac hine  (\nSVM\n)\n, \nRandom fore st (\nRF\n) and Natural Gradient Boosting  (N\nGB\noost )) on \na \ndivorce pre diction data set. The dataset consists of 1 7\n0 \nsample s, eac h of which contains 54 questi ons about the coupl e's \nemotiona l stat us. We\n rega rd the score s of 54 questi ons as the \nfe at ures  of eac h sample  to apply  our mac hine  learning al gorit hms .",
#  'Compar ed with SVM an d RF,  N\nGB\noost has superior  per formance \nas\n NGBoost ca n ac hie ve 0. 9 833 a ccur acy , 0. 9769  pre cision and \n0. 9\n828 F1 score. In addit ion\n, \nwe  also show the most important \nfe at ures  in the model  of RF and N\nGB\noost to find the most \nimportant  factors whic h lea d to divorc e . CCS Concep t s Computing me thodologi es\n\x07á\nMac hine learning\n\x07á\nMachine \nle arning approaches\n\x07á\nClassification and re gression tr ee s. \nKe ywords  \nDivorc e ;  machine learni ng\n; \nrandom fore st\n; \nnat ural gra die nt \nboosting ;  dat a mini ng . 1. INTRODUCTION  \nHusband and wife  are two differe nt sides of a fa mily  and tied  \ntoge ther to live for a better live . But Some couple s divorce d for \nvar ious reasons . Acc ording  to [ 3\n]\n, \nin\n Ameri ca,  40% t o 50% of all \nfirst marr ia ges,  and 60% of sec ond marr ia ges , will end in divorce .',
#  'Although divorce rates have declined in some areas  [2],  the global \ndivorc e rat e is on the  rise as a whole . As eve ryone knows,  h igh \ndivorc e rate sca n lead to soc ial unre st  in many  way s. \nDivorc e do harm to chi ldren , espec ially  for teenage rs. Chil dren \nwith divorce d pare nts are more  li kely  to drink,  take  drugs,  injure \nthe mselve s or do somet hing harmful to others [\n1]. E xcept for thi s\n, \nd ivorc e al so hurts  both husband and wife to some ext ent .  The re fore ,  it  is a very  important and signific ant issue\n to expl ore \nthe  cause s of divorc e and predi ct what kind of couples will',
#  "divorc e. \nOver  the past few y ea rs\n, \nrese archer s have studied this issue from \nvar ious per specti ves\n. A. Jary nowski and P. Ny czka  applied \nDy namic Network  to ana ly ze divorc e \n[6]\n. J. Li , G.  Zha ng, H. Yan  \net al\n. proposed a mark ov l ogic net works b\nase d met hod to p\nredict \ndivorc e [7]\n. Yönte m,  M ,  Adem,  K ,  \n \n, et al. used n\neural \nnet work to predic t divorce and analy ze the importa nt factors  \naff ecting divorce \n[8]\n.  In thi s paper\n, \nwe apply  three mac hine learning al gorit hms ,  \nSupport Vec tor Mac hine  (SVM) \n[9]\n, \nRandom fore st  (RF) \n[10]\n and \nNatur al Gradie nt Boosting \n(N\nGB\noost)\n \n[11]\n to ident ify  potent ial \ndivorc ing couples. Based on these  al gorit hms, we coul d al so \ndet ermine importa nt fact ors associate d with divorc e.  In Section\n 2\n, \nwe introduce d our mat eria ls and  three al gorithms we used  to \ndet ect  divorcing couples. In Secti on 3 and 4\n, we put forward  our \nexpe rimental re sult and our conclusion. 2. MATERI ALS AND M ETHO DS  \n2.1\n \nDataset \nTable  1\n. Some sample questions i n the questionnair e  \nNo.\n \nQuestions\n \n1  If one of usapologize s when our discussion \ndet eriora tes, thediscussion ends. 1\n1\n \nI thi nk that one day  in the future,  when I look \nbac k, I see tha tmy  spouse and Ihave  bee n in \nhar mony  with each other. 1\n7\n \nWe share the same vie ws about bei ng happy in \nour li fe with my spouse\n \n2\n0\n \nMy  spouse and I have \nsimil ar values in trust. 2\n6\n \nI know my  spouse' s basic anxieties. 3\n1\n \nI fe el aggre ssivewhen I argue with my  spouse.",
#  "3\n3\n \nI ca n use negative state ment sabout my  spouse' s \nper sonality  during our discussions. 3\n8\n \nI hate my  spouse' s way of open a subje ct. 4\n0\n \nWe' re just starting a discussion before  I know \nwhat' s going on. 4\n9\n \nI have not hing to do with what I' ve been accused \nof. Per miss io n  to mak e di\ng ital or  hard  co p ies o f  allo rp a rto f  this  work  f o r \np erso n al o r class ro o m u se is  g ranted  with o u t f ee p rov ided  th at co p ies  \nare n o t mad e o r  d istrib u ted  f o r p rofit o r co mme r cial ad v an tag e an d \nth at co p ies b ear th is n o tice an d  the f u ll citatio n  on th e f irst p a\ng e. \nCo p yrigh ts f o r comp o n en ts o f th is wo rk o wn ed  b y o th ers th an  ACM  \nmu st b e h o n o red. Ab stractin g  with  credit is p er mitt ed . To co p y  \no th erwise, o r  repu b lish , to  p o st o n  serv ers o r  to  redis t ribu te to  lists , \nrequ ires p rior  sp e cif ic p er miss io n  a n d /o r a f ee. Req\nu est p er miss io n s \nf ro m \nPer miss io n s@ac m.org\n. ICCAI' 2 0\n,Ap ril  23\n2 6 ,2 02 0 ,Tianjin ,Ch in a\n \n©\n \n2 0 2 0  Asso ciation  f o rCo mp u tin g  Machi n er y.\n \nACM I SBN 9 7 8\n-\n1\n-\n4503\n-\n7 70 8\n-\n9 /2 0 /04\n–$ 1 5 .00\n \nDOI: \nht tp s://d oi .o rg /10.1 145/34 0455 5.34045 59\n \nOu\nr dat ase t was obta ined  \nfrom\n [8\n]. The re  are  1\n70 sample s in the \ndat aset\n. Of the sample s, 84 (49%) were divorced and 86 (51%) \nwere  marrie d couple s . Acc ording to [8],  couples were invit ed to \nfini sh a questi onnai re  with 5 4 questi ons about thei r marr iage .",
#  'T hey  score d themsel ves  on a five -point  sca le ac cor ding to the \ndegr ee of conf ormity  with the questi ons . We liste d some  sample \nquesti ons in Table  \n1. In thi s pape r,  we rega rd the  scor e s of 54 \nquesti ons a s 54 fea tures . 2.2\n \nMachine Learning Algori thm  \n2. 2. 1 Su pport Vector Mach in e  (S\nVM\n) \nSVM is a effect ive  machi ne lea rning met hod with suffici ent \nthe oreti cal explana tion , and it is mai nly  used for cl assifica tion',
#  're cognition and re gression model ing  [2\n],  [9\n]\n. It calc ula te s a \ndec ision boundary  \nto\n maxi mizes the dista nc e of the nea rest points \nof any  cla ss to the deci sion  boundary\n. Given N point s \n\x12<\n\x07:\n\x0bÜ\n\x01á \x07;\n\x0bÜ\n\x12=\n\x0bÜ \x0b@ \x0b5\n\x0bÇ\n \nwhere  \n\x07:\n\x0bÜ\n\x05Ð \x074\n\x0bá\n is the\n i\n-\nth\n input  and \n\x07;\n\x0bÜ\n is the \ni\n-th \n \n labe l.  In \nthi s pape r,  \n\x07J \rL\n\x03w\x03v\n and \n\x07;\n\x0bÜ\n \x05Ð \x12<\x03r\x01á \x03s\x12=\n. SVM ai ms to cre ate a  cl assifier \nin the form of : \n   \n\x07B\n\x12:\n\x07T\n\x12;\n\rL \x07O\x07E\x07C\x07J \x12:\n\x03Ã\n\x07U\n\x0bÜ\n\x07=\n\x0bÜ\n\x07ð\n\x12:\n\x07T \x01á \x07T\n\x0bÜ\n\x12;\n\rE \x07>\n\x0bá\n\x0bÜ \x0b@ \x0b5\n\x12;\n           (1)  \nwher e \n\x07=\n\x0bÜ\n are positive re al constant s and b is a real constant . \x07ð\n\x12:\n\x03® \x01á \x03®\n\x12;\n \nis\n a  kern el funct ion  [12]. 2. 2. 2 Ra nd om Fo rest \n(RF)\n \nRandom fore st is an ense mble of d\neci sion \ntr\nee s tra ined with the \nbaggi ng met hod used for Classificat ion, Regression and other \nta sks [4\n],  [10]. Tre es in fore st are  tra ined  on random sample s of \ntra ini ng data  and the  split  of each node on a tree  is base d on a',
#  'ra ndom subset  of fe at ures . T\nhe\n fina l result  of RF \nis\n det ermined  \nac cor ding to ensemble of the all classifi cation results of deci sion',
#  'tre es by  average voti ng . Random fore st has a bet ter abi lity  to \ncont rol the over fit ti ng compare dwith single deci sion tree. Fig\nure 1\n. Ill ustration of Random for est. 2. 2. 3 Nat ura l Gra dient  Bo osti ng(N\nGB\noo st)  \nThe NGBoost al gorit hm is a supervise d learning  met hod for',
#  'proba bil istic forec asting  proposed by  Tony  Duan ,  Anand Avati ,  \nDaisy  Yi Ding,  et  al . in 2019 . It is a gra die nt boosting appr oac h  \nwhich uses nat ural gra dient s to solve the problem of simult aneous \nboosting of multi ple para meters from  the base le arners  [11]. In \nthi s paper, \nwe\n use the py thon',
#  'crea ted by  \nstanfor dmlgroup   and choose decision tree sas the base leane r\ns.\n \n2.3\n \nEvaluati on  \nIn orde r to e valuat e algorithms on the dataset objec tive ly , we used \n10\n-fold cro ss-vali dation\n. On 10 -fold cro ss-validati on, the data  set \nwas divi ded into te n subset s, and 9 of the m were ta ken as tra ining \nset and 1 subset was used as validati on set. Thi s proc ess re peate d \n10 ti mes, with every  subset used as vali dat ion set exact ly once\n. In this\n pape r, Acc ura cy , Pre cision  and F1 score  are uti liz ed to \neva luat e per formanc e . The de finitions of them a re : \n          \n \rL\n\x0bX\x0bT\n\x0b>\n\x0bX\x0bR\n\x0bX\x0bT\n\x0b>\n\x0bX\x0bR\n\x0b>\n\x0bJ\x0bT\n\x0b>\n\x0bJ\x0bR\n           \n  \n(2) \x072\x07N\x07A\x07?\x07E\x07O\x07E \x07K\x07J \rL\n\x0bÍ\x0bÉ\n\x0bÍ\x0bÉ\n\x0b>\n\x0b¿\x0bÉ\n                (3) \n \n\x07( \x03s\n\x07O\x07?\x07K\x07N\x07A \rL \x03t \x05Û\n\x0bã\x0bå\x0bØ \x0bÖ \x0bÜ\x0bæ\x0bÜ\x0bâ\x0bá \x05Û\x0bå\x0bØ \x0bÖ \x0bÔ\x0bß\x0bß\n\x0bã\x0bå\x0bØ \x0bÖ \x0bÜ\x0bæ\x0bÜ\x0bâ\x0bá \x0b> \x0bå\x0bØ \x0bÖ \x0bÔ\x0bß\x0bß\n \n  \n   \n(4)\n \nwher e TP, TN, FP,  FN mea ns True  Positi ve ,  True  Negative\n, \nFalse \nPositi ve\n, \nFalse Nega tive and \n              \n\x07N\x07A\x07?\x07= \x07H\x07H \rL\n\x0bÍ\x0bÉ\n\x0bÍ\x0bÉ\n\x0b>\n\x0b¿\x0bÇ\n  \n                (5) \n3. RESULTS  \n3.1\n \nSVM \nIn this pape r,  w\ne \nchoose the Radia l Basis Function  as the ker nel \nfunc ti on  and set key  para meters\n C = 1. 0, Gamma = 0. 03. The \nper formanc e of \nSVM\n is sho wn in Ta ble  2. All result s are \nca lcul ate d as the ave rage of 10\n-fold cro ss-validation . Table  2. Per formance  of SVM  \nEvaluation M etri cs\n \nEvaluation\n \nS\nc\nore\ns\n \nAcc ura cy\n \n0. 9715\n \nPrec ision\n \n0. 9769\n \nF1 score\n \n0. 9710',
#  'A\ns \nshown in Table  2, SVM has ac hieve d very  good per formance  \nas alle val uat ionscor es  are higher tha n 97% . 3.2\n \nRandom Fo res t \nT he key  paramete rs of Random fore st  set in this pape r  are shown \nin Tabl e 3 . Table  3. Key  param eters of  Random for est  \nPar ame ter s\n \nDescr iption\n \nOptimal  \nValue\n \nn_esti mat ors\n \nThe  number oftree s in the \nfore st.\n \n2\n0\n00\n \nmax_f ea ture s\n \nThe  number of \nfea tures to \nconside r when looking for the \nbest split\n. 1\n5\n \nmax_de pth\n \nThe  maxi mum dept h of the \ntre e\n. n\not li mited\n \nmin_samples_\nsplit\n \nThe  mini mum number  of \nsample s re quired to split an \nint ernal  node. 2\n \nmin_samples_\nleaf\n \nThe  mini mum number  of \nsample s in newly  \ncreated \nle aves. 1\n \nmin_wei ght_f\nra ction_leaf\n \nThe  mini mum weighted \nfra ction of the i nput sample s \nre quire d to be ata lea f node. 0\n \nbootstra p Whet her  bootstrap sample s \nare  used when buil ding trees. T\nrue\n \n \nThe  performance of ra ndom forest is shown in Ta ble 4. Random \nfore st has bet ter per formance and\n all three e val uat ion score s are \nbet ter than tha t',
#  '. Table  4\n. Per formance  of Random F orest  \nEvaluation M etri cs\n \nEvaluation\n \nS\nc\nore s\n \nAcc ura cy\n \n0. 97\n78\n \nPrec ision\n \n0. 9\n824\n \nF1 score\n \n0. 97\n72\n \n \nThe  top 10 important feat ure s of ra ndom fore st  are shown in \nFigure  2. As shown in Figure 2, questi on 18 is the most important \nquesti onana ly zed by  ra n d\nom fores t .  Fig\nure 2. Top 10 importance feature s  of Random for est. 3.3\n \nNatural G radient  Boosti ng \nThe  key  paramete rs of Random fore st set in this pape r are shown',
#  'in Tabl e 5\n. Table  5\n. Key  param eters of  Natural Gradie ntBoosting \nPar ame ter s\n \nDescr iption\n \nOptimal  \nValue\n \nbase  lea ner\n \nThe  base le aner of \nnat ural \ngra die nt boosting mac hine\n \nd\nec ision \ntre e\n \nn_esti mat ors\n \nThe  number oftree s in the \ngra die nt \nboosting \nmac hine\n. 2\n000\n \nmax_de pth\n \nThe  maxi mum dept h of the tree\n. 3\n \nmin_samples\n_split\n \nThe  mini mum number  of \nsample s re quired to split an \nint ernal  node\n \nofthe  base  \ndec ision tree\n. 2\n \nmin_samples\n_le af\n \nThe  \nmini mum number  of \nsample s in newly created lea ves\n \nof the ba se deci sion tree\n. 1\n \nmin_wei ght_f\nra ction_leaf\n \nThe  mini mum weighted frac tion \nof the i nput sample s re quire d to \nbe at a lea f node\n \nof the ba se \ndec ision tree\n. 0\n \nmini bat ch_f ra\nc\n \nFrac ti on of \nminibatc h\n \nselected \nra ndomly  without re sampli ng\n. 0. 9\n \nDist\n \nD\nistri buti on\n \ncon\nfig\nur\ned in\n \n \nNGBoost\n \nBernoul li\n \nS\ncor e\n \nS\ncor ing rule\n \nMLE\n \n \nThe  per formance of Natural  Gradie nt Boosting is shown in Ta ble \n6\n. It outperforms SVM and ra ndom fore st on all three  eval uat ion \nscore s.  \nThe  top 10 important feat ure s of ra ndom fore st  are shown in \nFigure  3. As shown in Figure  3,  questi on 18 is stil l the most \nimportant feat ure and is re lat ively  more important than that of \nra ndom fore st. Table  6. Per formance  of Natural  Gradie nt Boosting  \nEvaluation M etri cs\n \nEvaluation\n \nS\nc\nore s\n \nAcc ura cy\n \n0. 9\n833\n \nPrec ision\n \n0. 9\n8\n75\n \nF1 score\n \n0. 9\n828\n \n \n \nFig\nure 3. Top 10 importance feature s  of Natural Gradie nt \nBoosting.',
#  "Table  7. Top 10 important features ofeac h algori thm  \nR\nF\n \nNGBoost\n \nNo.\n \nQ\nuesti on\n \nNo.\n \nQ\nuesti on\n \n1\n8\n \nMy  spouse and I have \nsimil ar idea sabout how \nmarr ia ge shouldbe\n. 18\n \nMy  spouse and I have \nsimil ar idea sabout how \nmarr ia ge shouldbe\n. 40\n \nWe' re just starting a \ndiscussion bef ore I \nknow what' s going on. 4\n0\n \nWe' re just starting a \ndiscussion bef ore I know \nwhat'\ns going on. 1\n1\n \nI thi nk that one day  in \nthe  future, whenI look \nbac k, I see tha tmy  \nspouse and I have been \nin har mony  with each \nothe r.\n \n1\n1\n \nI thi nk that one day  in \nthe  future, whenI look \nbac k, I see tha tmy  \nspouse and I have been \nin har mony  with each \nothe r.\n \n2\n6\n \nI know my  spouse' s \nbasic anxi eties. 1\n9\n \nMy  spouse and I have \nsimil ar idea sabout how \nrole s should be in \nmarr ia ge\n. 1\n9\n \nMy  spouse and I have \nsimil ar idea sabout how \nrole s should be in \nmarr ia ge\n. 1\n7\n \nWe share the same vie ws \nabout  bei ng happy  in our \nli fe \nwith my  spouse\n. 1\n7\n \nWe share the same \nvie ws about being \nhappy  in our life with \nmy  spouse\n. 2\n0\n \nMy  spouse and I have \nsimil ar value sin trust. 2\n0\n \nMy  spouse and I have \nsimil ar value sin trust. 9\n \nI enj oy trave ling with \nmy  wife. 9\n \nI enj oy trave ling with \nmy  \nwife. 2\n6\n \nI know my  spouse' s \nbasic anxi eties. 1\n6\n \nWe' re compatible with \nmy  spouse about what \nlove  should be. 1\n6\n \nWe' re compatible with \nmy  spouse about what \nlove  should be. 3\n6\n \nI ca n be humil iating \nwhen we discussions. 2\n5\n \nI have knowle dge of my  \nspouse' s inner\n \nworld.",
#  '3.4\n \nI mport antFeature s  \nIn orde r to eff ecti vely  solve  the proble m of high divorc e ra te,  we \noutput  the importa nce of each fea ture. The te n most important \nfe at ures of RFand  \nNGB\noost areshown in Ta ble7. 4. CONCL USIO N AND DISCUSSI ON In thi s work,  thre e machi ne learning algori thms are applied to',
#  'pre dict pote nti al divorce. SVM, RF and NGBoost all have good \nper formanc e. NGBoost h a s \na \nslight  adva ntage than SVM and RF \nin pre dicting. In addition,  we find out the most important  fa ctors \nle ad to divorce calculate d by  RF and NGBoost. As shown in \nTa ble 7,  the re is only  one diffe rence  in the top ten  questi ons. This \nshows tha t the  rese arc h is very  convi ncing . In the future, we will \ncol lec t more  data and add some personal informati on to analy ze. 5. REF\nE REN CES  \n[1]\n \nA. P. Panat agama,  G.  P. Pratama and D. Y. Wibawa,  \n"Soci oEmpathy : A Soci al -Sensitivity  Applicationto Reduce \nStress a nd Depression of Divorce or Domesti c Viole nce \nVict ims, " 2018 6th Intern ational Confer ence on Informat ion \nand Communic ati onTe chnolog y (ICoICT) , Bandung,  2018,  \npp. 92 - 97. [2]\n \nZha ng, C., Zhou,  Y.,  Guo, J. et al. Researc h onclassifi cation \nmet hod of high -dimensional cl ass-imbala nce d datase ts base d \non SVM. Int. J. Mac h. Lea rn.  & Cy ber. 10, 1765\n1778 (2019)  \n[3]\n \nCel la, Annabe lle, Ford Marti n, and M ari ell e Cohen. "Deve lopmenta lPsy chol ogy at Vande rbilt . " [4]\n \nLa kshmana pra bu,  S.K.,  Shankar, K., Il ay araja, M.  et al.',
#  'Random fore st for big data cla ssific ati onin the inte rnet of \nthi ngs using optimal  fe ature s. Int. J. Mach. L earn .& Cy ber. 10,  2609\n2618 (2019)  \n[5]\n \n S. Sohail, S. Aziz , F. Tahir, S. Haqqui and A. Hussai n,  \n"Imple ment at ion of mac hine learning algori thm on fa ctors',
#  'eff ecting divorce ra te, " \n2018 International  Confere nce on \nEngi neering and Eme rging Technologi es (ICEE T)\n,  La hore,  \n2018,  pp. 1 -\n5. [6]\n \nA. Jary nowski  and P. Ny czka, "Dy namic Network Approac h',
#  'to Marriage /Divorc es Problem,"2014 European Net work \nInte lligence Confe re nce, Wrocl aw, 2014, pp. 122 -125. [7]\n \nJ. Li, G.  Zhang,H. Yan, L.  Yuand T. Meng, "AMarkov \nLogi c NetworksBased Method to Predict Judici al Decisi ons \nof Divorc e Cases," 2018 IEEE Inte rnati onal Confere nce on \nSmart  Cloud (Smart Cloud),  New York,  NY,  2018,  pp. 129 -\n132. [8]\n \n \nDivorc e Prediction Using Corre lat ion Based Feature \nSele cti onand Arti ficial N eural  Net works-273 . [9]\n \nCorte s, Corinna, and Vladi mir Vapni k. "Support -vec tor',
#  'net works. " Machine le arning 20.3 (1995): 273 -297. [10]\n \nBrei man, L eo.  "Random fore sts." Mac hine lea rning 45. 1',
#  '(2001): 5 -32. [11]\n \nDuan,  Tony ,et al. "NGBoost:  Natura l Gradient  Boosting for \nProbabil istic Predic ti on. "arXiv  pre print a rXiv:1910. 03225 (2019). [12]\n \nHaiqi ng Yu, Yanli ngLi , ShujunZha ng, and Chuny an Lia ng.  \n2019. Popularity Predi cti onfor Arti sts Base d onUser Songs \nData set. In Procee dings of the 2019 5th Inte rnat ional  \nConfer ence on Computi ng and Arti fici al Intelligence  (ICCAI \n\' 19). ACM,  New York, NY, USA, 17 -24.']

# %%
merged_partitions
# Out:
# ["Is\nYour Marriage R eliable? D ivorce A nalysiswith Machine \nLearningA lgorithm\ns  \nJue Kong\n \nChang'anuniversity \nShangYuanRoad \nXi'an,China, \n710021\n \n+8 618994535561 \n2017901295@chd.edu.cn \n: \nThese aut hors cont ribut ed equal ly to this work. *: cor responding aut hor \nTianruiChai\n*\n \nBeihangUniversity \nXueYuanRoadNo.37 \nBeijing,China,100191 \n+8618914739576 trchai@buaa.edu.cn",
#  "ABSTRA CT\n \nIn \nrece nt y ears, g\nlobal divorc e ra te is still  high\n. What kind of \ncoupl e will divorc e  and what factors lea d to divorc e are  \nim\nporta nt \nproble ms tha\nt \nworth study ing . In this paper , \nwe\n apply  three \nmac hine  lea rning al gorithm\ns \n(Support Vec tor Mac hine  (\nSVM\n)\n, \nRandom fore st (\nRF\n) and Natural Gradient Boosting  (N\nGB\noost )) on \na \ndivorce pre diction data set. The dataset consists of 1 7\n0 \nsample s, eac h of which contains 54 questi ons about the coupl e's \nemotiona l stat us. We\n rega rd the score s of 54 questi ons as the \nfe at ures  of eac h sample  to apply  our mac hine  learning al gorit hms .",
#  'Compar ed with SVM an d RF,  N\nGB\noost has superior  per formance \nas\n NGBoost ca n ac hie ve 0. 9 833 a ccur acy , 0. 9769  pre cision and \n0. 9\n828 F1 score. In addit ion\n, \nwe  also show the most important \nfe at ures  in the model  of RF and N\nGB\noost to find the most \nimportant  factors whic h lea d to divorc e . CCS Concep t s Computing me thodologi es\n\x07á\nMac hine learning\n\x07á\nMachine \nle arning approaches\n\x07á\nClassification and re gression tr ee s. \nKe ywords  \nDivorc e ;  machine learni ng\n; \nrandom fore st\n; \nnat ural gra die nt \nboosting ;  dat a mini ng . 1. INTRODUCTION  \nHusband and wife  are two differe nt sides of a fa mily  and tied  \ntoge ther to live for a better live . But Some couple s divorce d for \nvar ious reasons . Acc ording  to [ 3\n]\n, \nin\n Ameri ca,  40% t o 50% of all \nfirst marr ia ges,  and 60% of sec ond marr ia ges , will end in divorce .',
#  'Although divorce rates have declined in some areas  [2],  the global \ndivorc e rat e is on the  rise as a whole . As eve ryone knows,  h igh \ndivorc e rate sca n lead to soc ial unre st  in many  way s. \nDivorc e do harm to chi ldren , espec ially  for teenage rs. Chil dren \nwith divorce d pare nts are more  li kely  to drink,  take  drugs,  injure \nthe mselve s or do somet hing harmful to others [\n1]. E xcept for thi s\n, \nd ivorc e al so hurts  both husband and wife to some ext ent .  The re fore ,  it  is a very  important and signific ant issue\n to expl ore \nthe  cause s of divorc e and predi ct what kind of couples will',
#  "divorc e. \nOver  the past few y ea rs\n, \nrese archer s have studied this issue from \nvar ious per specti ves\n. A. Jary nowski and P. Ny czka  applied \nDy namic Network  to ana ly ze divorc e \n[6]\n. J. Li , G.  Zha ng, H. Yan  \net al\n. proposed a mark ov l ogic net works b\nase d met hod to p\nredict \ndivorc e [7]\n. Yönte m,  M ,  Adem,  K ,  \n \n, et al. used n\neural \nnet work to predic t divorce and analy ze the importa nt factors  \naff ecting divorce \n[8]\n.  In thi s paper\n, \nwe apply  three mac hine learning al gorit hms ,  \nSupport Vec tor Mac hine  (SVM) \n[9]\n, \nRandom fore st  (RF) \n[10]\n and \nNatur al Gradie nt Boosting \n(N\nGB\noost)\n \n[11]\n to ident ify  potent ial \ndivorc ing couples. Based on these  al gorit hms, we coul d al so \ndet ermine importa nt fact ors associate d with divorc e.  In Section\n 2\n, \nwe introduce d our mat eria ls and  three al gorithms we used  to \ndet ect  divorcing couples. In Secti on 3 and 4\n, we put forward  our \nexpe rimental re sult and our conclusion. 2. MATERI ALS AND M ETHO DS  \n2.1\n \nDataset \nTable  1\n. Some sample questions i n the questionnair e  \nNo.\n \nQuestions\n \n1  If one of usapologize s when our discussion \ndet eriora tes, thediscussion ends. 1\n1\n \nI thi nk that one day  in the future,  when I look \nbac k, I see tha tmy  spouse and Ihave  bee n in \nhar mony  with each other. 1\n7\n \nWe share the same vie ws about bei ng happy in \nour li fe with my spouse\n \n2\n0\n \nMy  spouse and I have \nsimil ar values in trust. 2\n6\n \nI know my  spouse' s basic anxieties. 3\n1\n \nI fe el aggre ssivewhen I argue with my  spouse.",
#  "3\n3\n \nI ca n use negative state ment sabout my  spouse' s \nper sonality  during our discussions. 3\n8\n \nI hate my  spouse' s way of open a subje ct. 4\n0\n \nWe' re just starting a discussion before  I know \nwhat' s going on. 4\n9\n \nI have not hing to do with what I' ve been accused \nof. Per miss io n  to mak e di\ng ital or  hard  co p ies o f  allo rp a rto f  this  work  f o r \np erso n al o r class ro o m u se is  g ranted  with o u t f ee p rov ided  th at co p ies  \nare n o t mad e o r  d istrib u ted  f o r p rofit o r co mme r cial ad v an tag e an d \nth at co p ies b ear th is n o tice an d  the f u ll citatio n  on th e f irst p a\ng e. \nCo p yrigh ts f o r comp o n en ts o f th is wo rk o wn ed  b y o th ers th an  ACM  \nmu st b e h o n o red. Ab stractin g  with  credit is p er mitt ed . To co p y  \no th erwise, o r  repu b lish , to  p o st o n  serv ers o r  to  redis t ribu te to  lists , \nrequ ires p rior  sp e cif ic p er miss io n  a n d /o r a f ee. Req\nu est p er miss io n s \nf ro m \nPer miss io n s@ac m.org\n. ICCAI' 2 0\n,Ap ril  23\n2 6 ,2 02 0 ,Tianjin ,Ch in a\n \n©\n \n2 0 2 0  Asso ciation  f o rCo mp u tin g  Machi n er y.\n \nACM I SBN 9 7 8\n-\n1\n-\n4503\n-\n7 70 8\n-\n9 /2 0 /04\n–$ 1 5 .00\n \nDOI: \nht tp s://d oi .o rg /10.1 145/34 0455 5.34045 59\n \nOu\nr dat ase t was obta ined  \nfrom\n [8\n]. The re  are  1\n70 sample s in the \ndat aset\n. Of the sample s, 84 (49%) were divorced and 86 (51%) \nwere  marrie d couple s . Acc ording to [8],  couples were invit ed to \nfini sh a questi onnai re  with 5 4 questi ons about thei r marr iage .",
#  'T hey  score d themsel ves  on a five -point  sca le ac cor ding to the \ndegr ee of conf ormity  with the questi ons . We liste d some  sample \nquesti ons in Table  \n1. In thi s pape r,  we rega rd the  scor e s of 54 \nquesti ons a s 54 fea tures . 2.2\n \nMachine Learning Algori thm  \n2. 2. 1 Su pport Vector Mach in e  (S\nVM\n) \nSVM is a effect ive  machi ne lea rning met hod with suffici ent \nthe oreti cal explana tion , and it is mai nly  used for cl assifica tion',
#  're cognition and re gression model ing  [2\n],  [9\n]\n. It calc ula te s a \ndec ision boundary  \nto\n maxi mizes the dista nc e of the nea rest points \nof any  cla ss to the deci sion  boundary\n. Given N point s \n\x12<\n\x07:\n\x0bÜ\n\x01á \x07;\n\x0bÜ\n\x12=\n\x0bÜ \x0b@ \x0b5\n\x0bÇ\n \nwhere  \n\x07:\n\x0bÜ\n\x05Ð \x074\n\x0bá\n is the\n i\n-\nth\n input  and \n\x07;\n\x0bÜ\n is the \ni\n-th \n \n labe l.  In \nthi s pape r,  \n\x07J \rL\n\x03w\x03v\n and \n\x07;\n\x0bÜ\n \x05Ð \x12<\x03r\x01á \x03s\x12=\n. SVM ai ms to cre ate a  cl assifier \nin the form of : \n   \n\x07B\n\x12:\n\x07T\n\x12;\n\rL \x07O\x07E\x07C\x07J \x12:\n\x03Ã\n\x07U\n\x0bÜ\n\x07=\n\x0bÜ\n\x07ð\n\x12:\n\x07T \x01á \x07T\n\x0bÜ\n\x12;\n\rE \x07>\n\x0bá\n\x0bÜ \x0b@ \x0b5\n\x12;\n           (1)  \nwher e \n\x07=\n\x0bÜ\n are positive re al constant s and b is a real constant . \x07ð\n\x12:\n\x03® \x01á \x03®\n\x12;\n \nis\n a  kern el funct ion  [12]. 2. 2. 2 Ra nd om Fo rest \n(RF)\n \nRandom fore st is an ense mble of d\neci sion \ntr\nee s tra ined with the \nbaggi ng met hod used for Classificat ion, Regression and other \nta sks [4\n],  [10]. Tre es in fore st are  tra ined  on random sample s of \ntra ini ng data  and the  split  of each node on a tree  is base d on a',
#  'ra ndom subset  of fe at ures . T\nhe\n fina l result  of RF \nis\n det ermined  \nac cor ding to ensemble of the all classifi cation results of deci sion',
#  'tre es by  average voti ng . Random fore st has a bet ter abi lity  to \ncont rol the over fit ti ng compare dwith single deci sion tree. Fig\nure 1\n. Ill ustration of Random for est. 2. 2. 3 Nat ura l Gra dient  Bo osti ng(N\nGB\noo st)  \nThe NGBoost al gorit hm is a supervise d learning  met hod for',
#  'proba bil istic forec asting  proposed by  Tony  Duan ,  Anand Avati ,  \nDaisy  Yi Ding,  et  al . in 2019 . It is a gra die nt boosting appr oac h  \nwhich uses nat ural gra dient s to solve the problem of simult aneous \nboosting of multi ple para meters from  the base le arners  [11]. In \nthi s paper, \nwe\n use the py thon',
#  'crea ted by  \nstanfor dmlgroup   and choose decision tree sas the base leane r\ns.\n \n2.3\n \nEvaluati on  \nIn orde r to e valuat e algorithms on the dataset objec tive ly , we used \n10\n-fold cro ss-vali dation\n. On 10 -fold cro ss-validati on, the data  set \nwas divi ded into te n subset s, and 9 of the m were ta ken as tra ining \nset and 1 subset was used as validati on set. Thi s proc ess re peate d \n10 ti mes, with every  subset used as vali dat ion set exact ly once\n. In this\n pape r, Acc ura cy , Pre cision  and F1 score  are uti liz ed to \neva luat e per formanc e . The de finitions of them a re : \n          \n \rL\n\x0bX\x0bT\n\x0b>\n\x0bX\x0bR\n\x0bX\x0bT\n\x0b>\n\x0bX\x0bR\n\x0b>\n\x0bJ\x0bT\n\x0b>\n\x0bJ\x0bR\n           \n  \n(2) \x072\x07N\x07A\x07?\x07E\x07O\x07E \x07K\x07J \rL\n\x0bÍ\x0bÉ\n\x0bÍ\x0bÉ\n\x0b>\n\x0b¿\x0bÉ\n                (3) \n \n\x07( \x03s\n\x07O\x07?\x07K\x07N\x07A \rL \x03t \x05Û\n\x0bã\x0bå\x0bØ \x0bÖ \x0bÜ\x0bæ\x0bÜ\x0bâ\x0bá \x05Û\x0bå\x0bØ \x0bÖ \x0bÔ\x0bß\x0bß\n\x0bã\x0bå\x0bØ \x0bÖ \x0bÜ\x0bæ\x0bÜ\x0bâ\x0bá \x0b> \x0bå\x0bØ \x0bÖ \x0bÔ\x0bß\x0bß\n \n  \n   \n(4)\n \nwher e TP, TN, FP,  FN mea ns True  Positi ve ,  True  Negative\n, \nFalse \nPositi ve\n, \nFalse Nega tive and \n              \n\x07N\x07A\x07?\x07= \x07H\x07H \rL\n\x0bÍ\x0bÉ\n\x0bÍ\x0bÉ\n\x0b>\n\x0b¿\x0bÇ\n  \n                (5) \n3. RESULTS  \n3.1\n \nSVM \nIn this pape r,  w\ne \nchoose the Radia l Basis Function  as the ker nel \nfunc ti on  and set key  para meters\n C = 1. 0, Gamma = 0. 03. The \nper formanc e of \nSVM\n is sho wn in Ta ble  2. All result s are \nca lcul ate d as the ave rage of 10\n-fold cro ss-validation . Table  2. Per formance  of SVM  \nEvaluation M etri cs\n \nEvaluation\n \nS\nc\nore\ns\n \nAcc ura cy\n \n0. 9715\n \nPrec ision\n \n0. 9769\n \nF1 score\n \n0. 9710',
#  'A\ns \nshown in Table  2, SVM has ac hieve d very  good per formance  \nas alle val uat ionscor es  are higher tha n 97% . 3.2\n \nRandom Fo res t \nT he key  paramete rs of Random fore st  set in this pape r  are shown \nin Tabl e 3 . Table  3. Key  param eters of  Random for est  \nPar ame ter s\n \nDescr iption\n \nOptimal  \nValue\n \nn_esti mat ors\n \nThe  number oftree s in the \nfore st.\n \n2\n0\n00\n \nmax_f ea ture s\n \nThe  number of \nfea tures to \nconside r when looking for the \nbest split\n. 1\n5\n \nmax_de pth\n \nThe  maxi mum dept h of the \ntre e\n. n\not li mited\n \nmin_samples_\nsplit\n \nThe  mini mum number  of \nsample s re quired to split an \nint ernal  node. 2\n \nmin_samples_\nleaf\n \nThe  mini mum number  of \nsample s in newly  \ncreated \nle aves. 1\n \nmin_wei ght_f\nra ction_leaf\n \nThe  mini mum weighted \nfra ction of the i nput sample s \nre quire d to be ata lea f node. 0\n \nbootstra p Whet her  bootstrap sample s \nare  used when buil ding trees. T\nrue\n \n \nThe  performance of ra ndom forest is shown in Ta ble 4. Random \nfore st has bet ter per formance and\n all three e val uat ion score s are \nbet ter than tha t in Tabl e 5\n. Table  5\n. Key  param eters of  Natural Gradie ntBoosting \nPar ame ter s\n \nDescr iption\n \nOptimal  \nValue\n \nbase  lea ner\n \nThe  base le aner of \nnat ural \ngra die nt boosting mac hine\n \nd\nec ision \ntre e\n \nn_esti mat ors\n \nThe  number oftree s in the \ngra die nt \nboosting \nmac hine\n. 2\n000\n \nmax_de pth\n \nThe  maxi mum dept h of the tree\n. 3\n \nmin_samples\n_split\n \nThe  mini mum number  of \nsample s re quired to split an \nint ernal  node\n \nofthe  base  \ndec ision tree\n. 2\n \nmin_samples\n_le af\n \nThe  \nmini mum number  of \nsample s in newly created lea ves\n \nof the ba se deci sion tree\n. 1\n \nmin_wei ght_f\nra ction_leaf\n \nThe  mini mum weighted frac tion \nof the i nput sample s re quire d to \nbe at a lea f node\n \nof the ba se \ndec ision tree\n. 0\n \nmini bat ch_f ra\nc\n \nFrac ti on of \nminibatc h\n \nselected \nra ndomly  without re sampli ng\n. 0. 9\n \nDist\n \nD\nistri buti on\n \ncon\nfig\nur\ned in\n \n \nNGBoost\n \nBernoul li\n \nS\ncor e\n \nS\ncor ing rule\n \nMLE\n \n \nThe  per formance of Natural  Gradie nt Boosting is shown in Ta ble \n6\n. It outperforms SVM and ra ndom fore st on all three  eval uat ion \nscore s.  \nThe  top 10 important feat ure s of ra ndom fore st  are shown in \nFigure  3. As shown in Figure  3,  questi on 18 is stil l the most \nimportant feat ure and is re lat ively  more important than that of \nra ndom fore st. Table  6. Per formance  of Natural  Gradie nt Boosting  \nEvaluation M etri cs\n \nEvaluation\n \nS\nc\nore s\n \nAcc ura cy\n \n0. 9\n833\n \nPrec ision\n \n0. 9\n8\n75\n \nF1 score\n \n0. 9\n828\n \n \n \nFig\nure 3. Top 10 importance feature s  of Natural Gradie nt \nBoosting.',
#  '. Table  4\n. Per formance  of Random F orest  \nEvaluation M etri cs\n \nEvaluation\n \nS\nc\nore s\n \nAcc ura cy\n \n0. 97\n78\n \nPrec ision\n \n0. 9\n824\n \nF1 score\n \n0. 97\n72\n \n \nThe  top 10 important feat ure s of ra ndom fore st  are shown in \nFigure  2. As shown in Figure 2, questi on 18 is the most important \nquesti onana ly zed by  ra n d\nom fores t .  Fig\nure 2. Top 10 importance feature s  of Random for est. 3.3\n \nNatural G radient  Boosti ng \nThe  key  paramete rs of Random fore st set in this pape r are shown',
#  "Table  7. Top 10 important features ofeac h algori thm  \nR\nF\n \nNGBoost\n \nNo.\n \nQ\nuesti on\n \nNo.\n \nQ\nuesti on\n \n1\n8\n \nMy  spouse and I have \nsimil ar idea sabout how \nmarr ia ge shouldbe\n. 18\n \nMy  spouse and I have \nsimil ar idea sabout how \nmarr ia ge shouldbe\n. 40\n \nWe' re just starting a \ndiscussion bef ore I \nknow what' s going on. 4\n0\n \nWe' re just starting a \ndiscussion bef ore I know \nwhat'\ns going on. 1\n1\n \nI thi nk that one day  in \nthe  future, whenI look \nbac k, I see tha tmy  \nspouse and I have been \nin har mony  with each \nothe r.\n \n1\n1\n \nI thi nk that one day  in \nthe  future, whenI look \nbac k, I see tha tmy  \nspouse and I have been \nin har mony  with each \nothe r.\n \n2\n6\n \nI know my  spouse' s \nbasic anxi eties. 1\n9\n \nMy  spouse and I have \nsimil ar idea sabout how \nrole s should be in \nmarr ia ge\n. 1\n9\n \nMy  spouse and I have \nsimil ar idea sabout how \nrole s should be in \nmarr ia ge\n. 1\n7\n \nWe share the same vie ws \nabout  bei ng happy  in our \nli fe \nwith my  spouse\n. 1\n7\n \nWe share the same \nvie ws about being \nhappy  in our life with \nmy  spouse\n. 2\n0\n \nMy  spouse and I have \nsimil ar value sin trust. 2\n0\n \nMy  spouse and I have \nsimil ar value sin trust. 9\n \nI enj oy trave ling with \nmy  wife. 9\n \nI enj oy trave ling with \nmy  \nwife. 2\n6\n \nI know my  spouse' s \nbasic anxi eties. 1\n6\n \nWe' re compatible with \nmy  spouse about what \nlove  should be. 1\n6\n \nWe' re compatible with \nmy  spouse about what \nlove  should be. 3\n6\n \nI ca n be humil iating \nwhen we discussions. 2\n5\n \nI have knowle dge of my  \nspouse' s inner\n \nworld.",
#  '3.4\n \nI mport antFeature s  \nIn orde r to eff ecti vely  solve  the proble m of high divorc e ra te,  we \noutput  the importa nce of each fea ture. The te n most important \nfe at ures of RFand  \nNGB\noost areshown in Ta ble7. 4. CONCL USIO N AND DISCUSSI ON In thi s work,  thre e machi ne learning algori thms are applied to',
#  'pre dict pote nti al divorce. SVM, RF and NGBoost all have good \nper formanc e. NGBoost h a s \na \nslight  adva ntage than SVM and RF \nin pre dicting. In addition,  we find out the most important  fa ctors \nle ad to divorce calculate d by  RF and NGBoost. As shown in \nTa ble 7,  the re is only  one diffe rence  in the top ten  questi ons. This \nshows tha t the  rese arc h is very  convi ncing . In the future, we will \ncol lec t more  data and add some personal informati on to analy ze. 5. REF\nE REN CES  \n[1]\n \nA. P. Panat agama,  G.  P. Pratama and D. Y. Wibawa,  \n"Soci oEmpathy : A Soci al -Sensitivity  Applicationto Reduce \nStress a nd Depression of Divorce or Domesti c Viole nce \nVict ims, " 2018 6th Intern ational Confer ence on Informat ion \nand Communic ati onTe chnolog y (ICoICT) , Bandung,  2018,  \npp. 92 - 97. [2]\n \nZha ng, C., Zhou,  Y.,  Guo, J. et al. Researc h onclassifi cation \nmet hod of high -dimensional cl ass-imbala nce d datase ts base d \non SVM. Int. J. Mac h. Lea rn.  & Cy ber. 10, 1765\n1778 (2019)  \n[3]\n \nCel la, Annabe lle, Ford Marti n, and M ari ell e Cohen. "Deve lopmenta lPsy chol ogy at Vande rbilt . " [4]\n \nLa kshmana pra bu,  S.K.,  Shankar, K., Il ay araja, M.  et al.',
#  'Random fore st for big data cla ssific ati onin the inte rnet of \nthi ngs using optimal  fe ature s. Int. J. Mach. L earn .& Cy ber. 10,  2609\n2618 (2019)  \n[5]\n \n S. Sohail, S. Aziz , F. Tahir, S. Haqqui and A. Hussai n,  \n"Imple ment at ion of mac hine learning algori thm on fa ctors',
#  'eff ecting divorce ra te, " \n2018 International  Confere nce on \nEngi neering and Eme rging Technologi es (ICEE T)\n,  La hore,  \n2018,  pp. 1 -\n5. [6]\n \nA. Jary nowski  and P. Ny czka, "Dy namic Network Approac h',
#  'to Marriage /Divorc es Problem,"2014 European Net work \nInte lligence Confe re nce, Wrocl aw, 2014, pp. 122 -125. [7]\n \nJ. Li, G.  Zhang,H. Yan, L.  Yuand T. Meng, "AMarkov \nLogi c NetworksBased Method to Predict Judici al Decisi ons \nof Divorc e Cases," 2018 IEEE Inte rnati onal Confere nce on \nSmart  Cloud (Smart Cloud),  New York,  NY,  2018,  pp. 129 -\n132. [8]\n \n \nDivorc e Prediction Using Corre lat ion Based Feature \nSele cti onand Arti ficial N eural  Net works-273 . [9]\n \nCorte s, Corinna, and Vladi mir Vapni k. "Support -vec tor',
#  'net works. " Machine le arning 20.3 (1995): 273 -297. [10]\n \nBrei man, L eo.  "Random fore sts." Mac hine lea rning 45. 1',
#  '(2001): 5 -32. [11]\n \nDuan,  Tony ,et al. "NGBoost:  Natura l Gradient  Boosting for \nProbabil istic Predic ti on. "arXiv  pre print a rXiv:1910. 03225 (2019). [12]\n \nHaiqi ng Yu, Yanli ngLi , ShujunZha ng, and Chuny an Lia ng.  \n2019. Popularity Predi cti onfor Arti sts Base d onUser Songs \nData set. In Procee dings of the 2019 5th Inte rnat ional  \nConfer ence on Computi ng and Arti fici al Intelligence  (ICCAI \n\' 19). ACM,  New York, NY, USA, 17 -24.']

# %%
pdf_path ='3404555.3404559.pdf'

# %%
tables = camelot.read_pdf(pdf_path)

# %%
def split_into_chunks(input_str):
    # Split the input string into sentences
    sentences = nltk.sent_tokenize(input_str)
    
    # Split each sentence into chunks of at most 1600 characters
    chunks = []
    current_chunk = ''
    for sentence in sentences:
        if len(current_chunk) + len(sentence) + 1 <= 1600:
            current_chunk += ' ' + sentence
        else:
            if len(current_chunk) >= 100:
                chunks.append(current_chunk.strip())
                current_chunk = sentence
            else:
                current_chunk += ' ' + sentence

    # Add the last chunk
    if len(current_chunk) >= 100:
        chunks.append(current_chunk.strip())
    
    return chunks

# %%
chunks=split_into_chunks(text)

# %%
len(chunks[0])
# Out:
# 1367

# %%
for i in chunks:
    print(len(i))
# Out:
# 1367
# 1551
# 1506
# 1571
# 1520
# 1508
# 1568
# 1544
# 1548
# 1389
# 1590
# 764

# %%
def get_similarity():
    for i in partitions:
# Out:
#   File "<ipython-input-68-d8f36e87ba3d>", line 2
#     for i in partitions:
#                         ^
# IndentationError: expected an indented block

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def compute_similarity_matrix(chunks):
    # Use TfidfVectorizer to compute the TF-IDF matrix for the chunks
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(chunks)
    # Compute the cosine similarity matrix for the chunks
    similarity_matrix = cosine_similarity(tfidf_matrix)
    return similarity_matrix

# %%
compute_similarity_matrix(partitions)
# Out:
# array([[1.        , 0.01167023, 0.03180888, 0.01730063, 0.02363675,
#         0.04050599, 0.02797332, 0.0235127 , 0.02942829, 0.02479206,
#         0.00680429, 0.02452421, 0.01271764, 0.01867512, 0.02100826,
#         0.        , 0.01740823, 0.01022291, 0.        , 0.        ,
#         0.02384696, 0.02008367, 0.00624024],
#        [0.01167023, 1.        , 0.25043874, 0.20297419, 0.32358406,
#         0.10951833, 0.26281601, 0.18185891, 0.1339797 , 0.09313846,
#         0.13057086, 0.14768684, 0.18364704, 0.1603797 , 0.26330232,
#         0.0796284 , 0.21198651, 0.18584334, 0.12826052, 0.04132894,
#         0.10508626, 0.12184493, 0.07695128],
#        [0.03180888, 0.25043874, 1.        , 0.20863631, 0.22250012,
#         0.12264005, 0.13575169, 0.20442386, 0.12674145, 0.14926954,
#         0.12925914, 0.17413693, 0.18026368, 0.15443224, 0.24604258,
#         0.11905894, 0.18375341, 0.20553221, 0.10402972, 0.05521893,
#         0.06050145, 0.09639244, 0.08706499],
#        [0.01730063, 0.20297419, 0.20863631, 1.        , 0.22186555,
#         0.12532985, 0.13799976, 0.17933369, 0.06809823, 0.0807073 ,
#         0.08169396, 0.12776126, 0.14783618, 0.11481304, 0.13888784,
#         0.0861669 , 0.14356719, 0.15658689, 0.0560262 , 0.03926308,
#         0.09860965, 0.00666946, 0.05371022],
#        [0.02363675, 0.32358406, 0.22250012, 0.22186555, 1.        ,
#         0.14399516, 0.14376277, 0.17713741, 0.07760589, 0.10617231,
#         0.13941819, 0.13272497, 0.14077252, 0.08298418, 0.16351489,
#         0.4396345 , 0.17739108, 0.22326042, 0.07262502, 0.12069262,
#         0.14090498, 0.06900538, 0.10719813],
#        [0.04050599, 0.10951833, 0.12264005, 0.12532985, 0.14399516,
#         1.        , 0.11078482, 0.19413001, 0.06150326, 0.04181123,
#         0.0530645 , 0.12095058, 0.10337904, 0.0759149 , 0.10261885,
#         0.17480538, 0.08328648, 0.07908031, 0.035984  , 0.01086606,
#         0.02924449, 0.0037195 , 0.04153104],
#        [0.02797332, 0.26281601, 0.13575169, 0.13799976, 0.14376277,
#         0.11078482, 1.        , 0.19148233, 0.10584975, 0.07295174,
#         0.10699355, 0.12830062, 0.16392447, 0.13187093, 0.17026277,
#         0.08505915, 0.16607886, 0.14487737, 0.09483309, 0.01114644,
#         0.0313501 , 0.06494809, 0.03132321],
#        [0.0235127 , 0.18185891, 0.20442386, 0.17933369, 0.17713741,
#         0.19413001, 0.19148233, 1.        , 0.16616283, 0.19777295,
#         0.11243199, 0.24589872, 0.26879066, 0.19760449, 0.29290197,
#         0.08114849, 0.17123357, 0.19280982, 0.12848623, 0.0615202 ,
#         0.04930032, 0.03218359, 0.10989531],
#        [0.02942829, 0.1339797 , 0.12674145, 0.06809823, 0.07760589,
#         0.06150326, 0.10584975, 0.16616283, 1.        , 0.08281922,
#         0.07897928, 0.13036862, 0.15355551, 0.10846454, 0.20346251,
#         0.01123959, 0.14375111, 0.09171942, 0.07420335, 0.01652656,
#         0.01941927, 0.        , 0.01649723],
#        [0.02479206, 0.09313846, 0.14926954, 0.0807073 , 0.10617231,
#         0.04181123, 0.07295174, 0.19777295, 0.08281922, 1.        ,
#         0.11077619, 0.06775478, 0.18582265, 0.19698442, 0.17469146,
#         0.01371905, 0.04531511, 0.0825374 , 0.07938302, 0.01384518,
#         0.0193215 , 0.03541424, 0.1186057 ],
#        [0.00680429, 0.13057086, 0.12925914, 0.08169396, 0.13941819,
#         0.0530645 , 0.10699355, 0.11243199, 0.07897928, 0.11077619,
#         1.        , 0.09138011, 0.09841039, 0.06875055, 0.20644147,
#         0.03629592, 0.10986253, 0.10499614, 0.04549573, 0.        ,
#         0.02684963, 0.01505824, 0.15007657],
#        [0.02452421, 0.14768684, 0.17413693, 0.12776126, 0.13272497,
#         0.12095058, 0.12830062, 0.24589872, 0.13036862, 0.06775478,
#         0.09138011, 1.        , 0.1887718 , 0.26550755, 0.23380248,
#         0.07128541, 0.13777343, 0.17126504, 0.08268053, 0.04055588,
#         0.02692926, 0.01851831, 0.08511518],
#        [0.01271764, 0.18364704, 0.18026368, 0.14783618, 0.14077252,
#         0.10337904, 0.16392447, 0.26879066, 0.15355551, 0.18582265,
#         0.09841039, 0.1887718 , 1.        , 0.31744483, 0.52439333,
#         0.06518418, 0.16419239, 0.14189   , 0.10173688, 0.01979859,
#         0.02775165, 0.04968187, 0.04184353],
#        [0.01867512, 0.1603797 , 0.15443224, 0.11481304, 0.08298418,
#         0.0759149 , 0.13187093, 0.19760449, 0.10846454, 0.19698442,
#         0.06875055, 0.26550755, 0.31744483, 1.        , 0.4526709 ,
#         0.04954569, 0.13410518, 0.14297379, 0.10411368, 0.02119907,
#         0.01764691, 0.06392994, 0.05479341],
#        [0.02100826, 0.26330232, 0.24604258, 0.13888784, 0.16351489,
#         0.10261885, 0.17026277, 0.29290197, 0.20346251, 0.17469146,
#         0.20644147, 0.23380248, 0.52439333, 0.4526709 , 1.        ,
#         0.07396604, 0.17193003, 0.16659246, 0.11364312, 0.0354068 ,
#         0.03758026, 0.06252997, 0.08008732],
#        [0.        , 0.0796284 , 0.11905894, 0.0861669 , 0.4396345 ,
#         0.17480538, 0.08505915, 0.08114849, 0.01123959, 0.01371905,
#         0.03629592, 0.07128541, 0.06518418, 0.04954569, 0.07396604,
#         1.        , 0.07229342, 0.09290258, 0.03156667, 0.02098996,
#         0.01295949, 0.00253567, 0.03031583],
#        [0.01740823, 0.21198651, 0.18375341, 0.14356719, 0.17739108,
#         0.08328648, 0.16607886, 0.17123357, 0.14375111, 0.04531511,
#         0.10986253, 0.13777343, 0.16419239, 0.13410518, 0.17193003,
#         0.07229342, 1.        , 0.13548125, 0.09694198, 0.10108634,
#         0.07505752, 0.        , 0.03521778],
#        [0.01022291, 0.18584334, 0.20553221, 0.15658689, 0.22326042,
#         0.07908031, 0.14487737, 0.19280982, 0.09171942, 0.0825374 ,
#         0.10499614, 0.17126504, 0.14189   , 0.14297379, 0.16659246,
#         0.09290258, 0.13548125, 1.        , 0.12154704, 0.15123112,
#         0.0895247 , 0.02779616, 0.14243829],
#        [0.        , 0.12826052, 0.10402972, 0.0560262 , 0.07262502,
#         0.035984  , 0.09483309, 0.12848623, 0.07420335, 0.07938302,
#         0.04549573, 0.08268053, 0.10173688, 0.10411368, 0.11364312,
#         0.03156667, 0.09694198, 0.12154704, 1.        , 0.01591333,
#         0.0593091 , 0.07569657, 0.08741448],
#        [0.        , 0.04132894, 0.05521893, 0.03926308, 0.12069262,
#         0.01086606, 0.01114644, 0.0615202 , 0.01652656, 0.01384518,
#         0.        , 0.04055588, 0.01979859, 0.02119907, 0.0354068 ,
#         0.02098996, 0.10108634, 0.15123112, 0.01591333, 1.        ,
#         0.16561926, 0.        , 0.03559017],
#        [0.02384696, 0.10508626, 0.06050145, 0.09860965, 0.14090498,
#         0.02924449, 0.0313501 , 0.04930032, 0.01941927, 0.0193215 ,
#         0.02684963, 0.02692926, 0.02775165, 0.01764691, 0.03758026,
#         0.01295949, 0.07505752, 0.0895247 , 0.0593091 , 0.16561926,
#         1.        , 0.08132459, 0.09693316],
#        [0.02008367, 0.12184493, 0.09639244, 0.00666946, 0.06900538,
#         0.0037195 , 0.06494809, 0.03218359, 0.        , 0.03541424,
#         0.01505824, 0.01851831, 0.04968187, 0.06392994, 0.06252997,
#         0.00253567, 0.        , 0.02779616, 0.07569657, 0.        ,
#         0.08132459, 1.        , 0.02578464],
#        [0.00624024, 0.07695128, 0.08706499, 0.05371022, 0.10719813,
#         0.04153104, 0.03132321, 0.10989531, 0.01649723, 0.1186057 ,
#         0.15007657, 0.08511518, 0.04184353, 0.05479341, 0.08008732,
#         0.03031583, 0.03521778, 0.14243829, 0.08741448, 0.03559017,
#         0.09693316, 0.02578464, 1.        ]])

# %%
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def plot_similarity_matrix(chunks, similarity_matrix):
    # Create a DataFrame from the similarity matrix
    df = pd.DataFrame(similarity_matrix, columns=chunks)
    
    # Create a heatmap from the DataFrame
    sns.heatmap(df, cmap='coolwarm', annot=True, fmt='.2f', vmin=0, vmax=1)
    plt.title('Chunk Similarity')
    plt.xlabel('Chunk')
    plt.ylabel('Chunk')
    plt.show()


similarity_matrix = compute_similarity_matrix(partitions)
plot_similarity_matrix(chunks, similarity_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1674                 blocks = [
# -> 1675                     make_block(
#    1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2750
# -> 2751     return klass(values, ndim=ndim, placement=placement)
#    2752
#
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 23, placement implies 12
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-aab4ad67bd4e> in <module>
#      12
#      13 similarity_matrix = compute_similarity_matrix(partitions)
# ---> 14 plot_similarity_matrix(chunks, similarity_matrix)
#
# <ipython-input-78-aab4ad67bd4e> in plot_similarity_matrix(chunks, similarity_matrix)
#       1 def plot_similarity_matrix(chunks, similarity_matrix):
#       2     # Create a DataFrame from the similarity matrix
# ----> 3     df = pd.DataFrame(similarity_matrix, columns=chunks)
#       4
#       5     # Create a heatmap from the DataFrame
#
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# ValueError: Shape of passed values is (23, 23), indices imply (23, 12)

# %%
for i in range(len(partitions)):
    for j in range(len(partitions)):
        if i != j:
            similarity = similarity_matrix[i][j]
            print(f"Similarity between chunk {i+1} and chunk {j+1}: {similarity:.2f}")
# Out:
# Similarity between chunk 1 and chunk 2: 0.01
# Similarity between chunk 1 and chunk 3: 0.03
# Similarity between chunk 1 and chunk 4: 0.02
# Similarity between chunk 1 and chunk 5: 0.02
# Similarity between chunk 1 and chunk 6: 0.04
# Similarity between chunk 1 and chunk 7: 0.03
# Similarity between chunk 1 and chunk 8: 0.02
# Similarity between chunk 1 and chunk 9: 0.03
# Similarity between chunk 1 and chunk 10: 0.02
# Similarity between chunk 1 and chunk 11: 0.01
# Similarity between chunk 1 and chunk 12: 0.02
# Similarity between chunk 1 and chunk 13: 0.01
# Similarity between chunk 1 and chunk 14: 0.02
# Similarity between chunk 1 and chunk 15: 0.02
# Similarity between chunk 1 and chunk 16: 0.00
# Similarity between chunk 1 and chunk 17: 0.02
# Similarity between chunk 1 and chunk 18: 0.01
# Similarity between chunk 1 and chunk 19: 0.00
# Similarity between chunk 1 and chunk 20: 0.00
# Similarity between chunk 1 and chunk 21: 0.02
# Similarity between chunk 1 and chunk 22: 0.02
# Similarity between chunk 1 and chunk 23: 0.01
# Similarity between chunk 2 and chunk 1: 0.01
# Similarity between chunk 2 and chunk 3: 0.25
# Similarity between chunk 2 and chunk 4: 0.20
# Similarity between chunk 2 and chunk 5: 0.32
# Similarity between chunk 2 and chunk 6: 0.11
# Similarity between chunk 2 and chunk 7: 0.26
# Similarity between chunk 2 and chunk 8: 0.18
# Similarity between chunk 2 and chunk 9: 0.13
# Similarity between chunk 2 and chunk 10: 0.09
# Similarity between chunk 2 and chunk 11: 0.13
# Similarity between chunk 2 and chunk 12: 0.15
# Similarity between chunk 2 and chunk 13: 0.18
# Similarity between chunk 2 and chunk 14: 0.16
# Similarity between chunk 2 and chunk 15: 0.26
# Similarity between chunk 2 and chunk 16: 0.08
# Similarity between chunk 2 and chunk 17: 0.21
# Similarity between chunk 2 and chunk 18: 0.19
# Similarity between chunk 2 and chunk 19: 0.13
# Similarity between chunk 2 and chunk 20: 0.04
# Similarity between chunk 2 and chunk 21: 0.11
# Similarity between chunk 2 and chunk 22: 0.12
# Similarity between chunk 2 and chunk 23: 0.08
# Similarity between chunk 3 and chunk 1: 0.03
# Similarity between chunk 3 and chunk 2: 0.25
# Similarity between chunk 3 and chunk 4: 0.21
# Similarity between chunk 3 and chunk 5: 0.22
# Similarity between chunk 3 and chunk 6: 0.12
# Similarity between chunk 3 and chunk 7: 0.14
# Similarity between chunk 3 and chunk 8: 0.20
# Similarity between chunk 3 and chunk 9: 0.13
# Similarity between chunk 3 and chunk 10: 0.15
# Similarity between chunk 3 and chunk 11: 0.13
# Similarity between chunk 3 and chunk 12: 0.17
# Similarity between chunk 3 and chunk 13: 0.18
# Similarity between chunk 3 and chunk 14: 0.15
# Similarity between chunk 3 and chunk 15: 0.25
# Similarity between chunk 3 and chunk 16: 0.12
# Similarity between chunk 3 and chunk 17: 0.18
# Similarity between chunk 3 and chunk 18: 0.21
# Similarity between chunk 3 and chunk 19: 0.10
# Similarity between chunk 3 and chunk 20: 0.06
# Similarity between chunk 3 and chunk 21: 0.06
# Similarity between chunk 3 and chunk 22: 0.10
# Similarity between chunk 3 and chunk 23: 0.09
# Similarity between chunk 4 and chunk 1: 0.02
# Similarity between chunk 4 and chunk 2: 0.20
# Similarity between chunk 4 and chunk 3: 0.21
# Similarity between chunk 4 and chunk 5: 0.22
# Similarity between chunk 4 and chunk 6: 0.13
# Similarity between chunk 4 and chunk 7: 0.14
# Similarity between chunk 4 and chunk 8: 0.18
# Similarity between chunk 4 and chunk 9: 0.07
# Similarity between chunk 4 and chunk 10: 0.08
# Similarity between chunk 4 and chunk 11: 0.08
# Similarity between chunk 4 and chunk 12: 0.13
# Similarity between chunk 4 and chunk 13: 0.15
# Similarity between chunk 4 and chunk 14: 0.11
# Similarity between chunk 4 and chunk 15: 0.14
# Similarity between chunk 4 and chunk 16: 0.09
# Similarity between chunk 4 and chunk 17: 0.14
# Similarity between chunk 4 and chunk 18: 0.16
# Similarity between chunk 4 and chunk 19: 0.06
# Similarity between chunk 4 and chunk 20: 0.04
# Similarity between chunk 4 and chunk 21: 0.10
# Similarity between chunk 4 and chunk 22: 0.01
# Similarity between chunk 4 and chunk 23: 0.05
# Similarity between chunk 5 and chunk 1: 0.02
# Similarity between chunk 5 and chunk 2: 0.32
# Similarity between chunk 5 and chunk 3: 0.22
# Similarity between chunk 5 and chunk 4: 0.22
# Similarity between chunk 5 and chunk 6: 0.14
# Similarity between chunk 5 and chunk 7: 0.14
# Similarity between chunk 5 and chunk 8: 0.18
# Similarity between chunk 5 and chunk 9: 0.08
# Similarity between chunk 5 and chunk 10: 0.11
# Similarity between chunk 5 and chunk 11: 0.14
# Similarity between chunk 5 and chunk 12: 0.13
# Similarity between chunk 5 and chunk 13: 0.14
# Similarity between chunk 5 and chunk 14: 0.08
# Similarity between chunk 5 and chunk 15: 0.16
# Similarity between chunk 5 and chunk 16: 0.44
# Similarity between chunk 5 and chunk 17: 0.18
# Similarity between chunk 5 and chunk 18: 0.22
# Similarity between chunk 5 and chunk 19: 0.07
# Similarity between chunk 5 and chunk 20: 0.12
# Similarity between chunk 5 and chunk 21: 0.14
# Similarity between chunk 5 and chunk 22: 0.07
# Similarity between chunk 5 and chunk 23: 0.11
# Similarity between chunk 6 and chunk 1: 0.04
# Similarity between chunk 6 and chunk 2: 0.11
# Similarity between chunk 6 and chunk 3: 0.12
# Similarity between chunk 6 and chunk 4: 0.13
# Similarity between chunk 6 and chunk 5: 0.14
# Similarity between chunk 6 and chunk 7: 0.11
# Similarity between chunk 6 and chunk 8: 0.19
# Similarity between chunk 6 and chunk 9: 0.06
# Similarity between chunk 6 and chunk 10: 0.04
# Similarity between chunk 6 and chunk 11: 0.05
# Similarity between chunk 6 and chunk 12: 0.12
# Similarity between chunk 6 and chunk 13: 0.10
# Similarity between chunk 6 and chunk 14: 0.08
# Similarity between chunk 6 and chunk 15: 0.10
# Similarity between chunk 6 and chunk 16: 0.17
# Similarity between chunk 6 and chunk 17: 0.08
# Similarity between chunk 6 and chunk 18: 0.08
# Similarity between chunk 6 and chunk 19: 0.04
# Similarity between chunk 6 and chunk 20: 0.01
# Similarity between chunk 6 and chunk 21: 0.03
# Similarity between chunk 6 and chunk 22: 0.00
# Similarity between chunk 6 and chunk 23: 0.04
# Similarity between chunk 7 and chunk 1: 0.03
# Similarity between chunk 7 and chunk 2: 0.26
# Similarity between chunk 7 and chunk 3: 0.14
# Similarity between chunk 7 and chunk 4: 0.14
# Similarity between chunk 7 and chunk 5: 0.14
# Similarity between chunk 7 and chunk 6: 0.11
# Similarity between chunk 7 and chunk 8: 0.19
# Similarity between chunk 7 and chunk 9: 0.11
# Similarity between chunk 7 and chunk 10: 0.07
# Similarity between chunk 7 and chunk 11: 0.11
# Similarity between chunk 7 and chunk 12: 0.13
# Similarity between chunk 7 and chunk 13: 0.16
# Similarity between chunk 7 and chunk 14: 0.13
# Similarity between chunk 7 and chunk 15: 0.17
# Similarity between chunk 7 and chunk 16: 0.09
# Similarity between chunk 7 and chunk 17: 0.17
# Similarity between chunk 7 and chunk 18: 0.14
# Similarity between chunk 7 and chunk 19: 0.09
# Similarity between chunk 7 and chunk 20: 0.01
# Similarity between chunk 7 and chunk 21: 0.03
# Similarity between chunk 7 and chunk 22: 0.06
# Similarity between chunk 7 and chunk 23: 0.03
# Similarity between chunk 8 and chunk 1: 0.02
# Similarity between chunk 8 and chunk 2: 0.18
# Similarity between chunk 8 and chunk 3: 0.20
# Similarity between chunk 8 and chunk 4: 0.18
# Similarity between chunk 8 and chunk 5: 0.18
# Similarity between chunk 8 and chunk 6: 0.19
# Similarity between chunk 8 and chunk 7: 0.19
# Similarity between chunk 8 and chunk 9: 0.17
# Similarity between chunk 8 and chunk 10: 0.20
# Similarity between chunk 8 and chunk 11: 0.11
# Similarity between chunk 8 and chunk 12: 0.25
# Similarity between chunk 8 and chunk 13: 0.27
# Similarity between chunk 8 and chunk 14: 0.20
# Similarity between chunk 8 and chunk 15: 0.29
# Similarity between chunk 8 and chunk 16: 0.08
# Similarity between chunk 8 and chunk 17: 0.17
# Similarity between chunk 8 and chunk 18: 0.19
# Similarity between chunk 8 and chunk 19: 0.13
# Similarity between chunk 8 and chunk 20: 0.06
# Similarity between chunk 8 and chunk 21: 0.05
# Similarity between chunk 8 and chunk 22: 0.03
# Similarity between chunk 8 and chunk 23: 0.11
# Similarity between chunk 9 and chunk 1: 0.03
# Similarity between chunk 9 and chunk 2: 0.13
# Similarity between chunk 9 and chunk 3: 0.13
# Similarity between chunk 9 and chunk 4: 0.07
# Similarity between chunk 9 and chunk 5: 0.08
# Similarity between chunk 9 and chunk 6: 0.06
# Similarity between chunk 9 and chunk 7: 0.11
# Similarity between chunk 9 and chunk 8: 0.17
# Similarity between chunk 9 and chunk 10: 0.08
# Similarity between chunk 9 and chunk 11: 0.08
# Similarity between chunk 9 and chunk 12: 0.13
# Similarity between chunk 9 and chunk 13: 0.15
# Similarity between chunk 9 and chunk 14: 0.11
# Similarity between chunk 9 and chunk 15: 0.20
# Similarity between chunk 9 and chunk 16: 0.01
# Similarity between chunk 9 and chunk 17: 0.14
# Similarity between chunk 9 and chunk 18: 0.09
# Similarity between chunk 9 and chunk 19: 0.07
# Similarity between chunk 9 and chunk 20: 0.02
# Similarity between chunk 9 and chunk 21: 0.02
# Similarity between chunk 9 and chunk 22: 0.00
# Similarity between chunk 9 and chunk 23: 0.02
# Similarity between chunk 10 and chunk 1: 0.02
# Similarity between chunk 10 and chunk 2: 0.09
# Similarity between chunk 10 and chunk 3: 0.15
# Similarity between chunk 10 and chunk 4: 0.08
# Similarity between chunk 10 and chunk 5: 0.11
# Similarity between chunk 10 and chunk 6: 0.04
# Similarity between chunk 10 and chunk 7: 0.07
# Similarity between chunk 10 and chunk 8: 0.20
# Similarity between chunk 10 and chunk 9: 0.08
# Similarity between chunk 10 and chunk 11: 0.11
# Similarity between chunk 10 and chunk 12: 0.07
# Similarity between chunk 10 and chunk 13: 0.19
# Similarity between chunk 10 and chunk 14: 0.20
# Similarity between chunk 10 and chunk 15: 0.17
# Similarity between chunk 10 and chunk 16: 0.01
# Similarity between chunk 10 and chunk 17: 0.05
# Similarity between chunk 10 and chunk 18: 0.08
# Similarity between chunk 10 and chunk 19: 0.08
# Similarity between chunk 10 and chunk 20: 0.01
# Similarity between chunk 10 and chunk 21: 0.02
# Similarity between chunk 10 and chunk 22: 0.04
# Similarity between chunk 10 and chunk 23: 0.12
# Similarity between chunk 11 and chunk 1: 0.01
# Similarity between chunk 11 and chunk 2: 0.13
# Similarity between chunk 11 and chunk 3: 0.13
# Similarity between chunk 11 and chunk 4: 0.08
# Similarity between chunk 11 and chunk 5: 0.14
# Similarity between chunk 11 and chunk 6: 0.05
# Similarity between chunk 11 and chunk 7: 0.11
# Similarity between chunk 11 and chunk 8: 0.11
# Similarity between chunk 11 and chunk 9: 0.08
# Similarity between chunk 11 and chunk 10: 0.11
# Similarity between chunk 11 and chunk 12: 0.09
# Similarity between chunk 11 and chunk 13: 0.10
# Similarity between chunk 11 and chunk 14: 0.07
# Similarity between chunk 11 and chunk 15: 0.21
# Similarity between chunk 11 and chunk 16: 0.04
# Similarity between chunk 11 and chunk 17: 0.11
# Similarity between chunk 11 and chunk 18: 0.10
# Similarity between chunk 11 and chunk 19: 0.05
# Similarity between chunk 11 and chunk 20: 0.00
# Similarity between chunk 11 and chunk 21: 0.03
# Similarity between chunk 11 and chunk 22: 0.02
# Similarity between chunk 11 and chunk 23: 0.15
# Similarity between chunk 12 and chunk 1: 0.02
# Similarity between chunk 12 and chunk 2: 0.15
# Similarity between chunk 12 and chunk 3: 0.17
# Similarity between chunk 12 and chunk 4: 0.13
# Similarity between chunk 12 and chunk 5: 0.13
# Similarity between chunk 12 and chunk 6: 0.12
# Similarity between chunk 12 and chunk 7: 0.13
# Similarity between chunk 12 and chunk 8: 0.25
# Similarity between chunk 12 and chunk 9: 0.13
# Similarity between chunk 12 and chunk 10: 0.07
# Similarity between chunk 12 and chunk 11: 0.09
# Similarity between chunk 12 and chunk 13: 0.19
# Similarity between chunk 12 and chunk 14: 0.27
# Similarity between chunk 12 and chunk 15: 0.23
# Similarity between chunk 12 and chunk 16: 0.07
# Similarity between chunk 12 and chunk 17: 0.14
# Similarity between chunk 12 and chunk 18: 0.17
# Similarity between chunk 12 and chunk 19: 0.08
# Similarity between chunk 12 and chunk 20: 0.04
# Similarity between chunk 12 and chunk 21: 0.03
# Similarity between chunk 12 and chunk 22: 0.02
# Similarity between chunk 12 and chunk 23: 0.09
# Similarity between chunk 13 and chunk 1: 0.01
# Similarity between chunk 13 and chunk 2: 0.18
# Similarity between chunk 13 and chunk 3: 0.18
# Similarity between chunk 13 and chunk 4: 0.15
# Similarity between chunk 13 and chunk 5: 0.14
# Similarity between chunk 13 and chunk 6: 0.10
# Similarity between chunk 13 and chunk 7: 0.16
# Similarity between chunk 13 and chunk 8: 0.27
# Similarity between chunk 13 and chunk 9: 0.15
# Similarity between chunk 13 and chunk 10: 0.19
# Similarity between chunk 13 and chunk 11: 0.10
# Similarity between chunk 13 and chunk 12: 0.19
# Similarity between chunk 13 and chunk 14: 0.32
# Similarity between chunk 13 and chunk 15: 0.52
# Similarity between chunk 13 and chunk 16: 0.07
# Similarity between chunk 13 and chunk 17: 0.16
# Similarity between chunk 13 and chunk 18: 0.14
# Similarity between chunk 13 and chunk 19: 0.10
# Similarity between chunk 13 and chunk 20: 0.02
# Similarity between chunk 13 and chunk 21: 0.03
# Similarity between chunk 13 and chunk 22: 0.05
# Similarity between chunk 13 and chunk 23: 0.04
# Similarity between chunk 14 and chunk 1: 0.02
# Similarity between chunk 14 and chunk 2: 0.16
# Similarity between chunk 14 and chunk 3: 0.15
# Similarity between chunk 14 and chunk 4: 0.11
# Similarity between chunk 14 and chunk 5: 0.08
# Similarity between chunk 14 and chunk 6: 0.08
# Similarity between chunk 14 and chunk 7: 0.13
# Similarity between chunk 14 and chunk 8: 0.20
# Similarity between chunk 14 and chunk 9: 0.11
# Similarity between chunk 14 and chunk 10: 0.20
# Similarity between chunk 14 and chunk 11: 0.07
# Similarity between chunk 14 and chunk 12: 0.27
# Similarity between chunk 14 and chunk 13: 0.32
# Similarity between chunk 14 and chunk 15: 0.45
# Similarity between chunk 14 and chunk 16: 0.05
# Similarity between chunk 14 and chunk 17: 0.13
# Similarity between chunk 14 and chunk 18: 0.14
# Similarity between chunk 14 and chunk 19: 0.10
# Similarity between chunk 14 and chunk 20: 0.02
# Similarity between chunk 14 and chunk 21: 0.02
# Similarity between chunk 14 and chunk 22: 0.06
# Similarity between chunk 14 and chunk 23: 0.05
# Similarity between chunk 15 and chunk 1: 0.02
# Similarity between chunk 15 and chunk 2: 0.26
# Similarity between chunk 15 and chunk 3: 0.25
# Similarity between chunk 15 and chunk 4: 0.14
# Similarity between chunk 15 and chunk 5: 0.16
# Similarity between chunk 15 and chunk 6: 0.10
# Similarity between chunk 15 and chunk 7: 0.17
# Similarity between chunk 15 and chunk 8: 0.29
# Similarity between chunk 15 and chunk 9: 0.20
# Similarity between chunk 15 and chunk 10: 0.17
# Similarity between chunk 15 and chunk 11: 0.21
# Similarity between chunk 15 and chunk 12: 0.23
# Similarity between chunk 15 and chunk 13: 0.52
# Similarity between chunk 15 and chunk 14: 0.45
# Similarity between chunk 15 and chunk 16: 0.07
# Similarity between chunk 15 and chunk 17: 0.17
# Similarity between chunk 15 and chunk 18: 0.17
# Similarity between chunk 15 and chunk 19: 0.11
# Similarity between chunk 15 and chunk 20: 0.04
# Similarity between chunk 15 and chunk 21: 0.04
# Similarity between chunk 15 and chunk 22: 0.06
# Similarity between chunk 15 and chunk 23: 0.08
# Similarity between chunk 16 and chunk 1: 0.00
# Similarity between chunk 16 and chunk 2: 0.08
# Similarity between chunk 16 and chunk 3: 0.12
# Similarity between chunk 16 and chunk 4: 0.09
# Similarity between chunk 16 and chunk 5: 0.44
# Similarity between chunk 16 and chunk 6: 0.17
# Similarity between chunk 16 and chunk 7: 0.09
# Similarity between chunk 16 and chunk 8: 0.08
# Similarity between chunk 16 and chunk 9: 0.01
# Similarity between chunk 16 and chunk 10: 0.01
# Similarity between chunk 16 and chunk 11: 0.04
# Similarity between chunk 16 and chunk 12: 0.07
# Similarity between chunk 16 and chunk 13: 0.07
# Similarity between chunk 16 and chunk 14: 0.05
# Similarity between chunk 16 and chunk 15: 0.07
# Similarity between chunk 16 and chunk 17: 0.07
# Similarity between chunk 16 and chunk 18: 0.09
# Similarity between chunk 16 and chunk 19: 0.03
# Similarity between chunk 16 and chunk 20: 0.02
# Similarity between chunk 16 and chunk 21: 0.01
# Similarity between chunk 16 and chunk 22: 0.00
# Similarity between chunk 16 and chunk 23: 0.03
# Similarity between chunk 17 and chunk 1: 0.02
# Similarity between chunk 17 and chunk 2: 0.21
# Similarity between chunk 17 and chunk 3: 0.18
# Similarity between chunk 17 and chunk 4: 0.14
# Similarity between chunk 17 and chunk 5: 0.18
# Similarity between chunk 17 and chunk 6: 0.08
# Similarity between chunk 17 and chunk 7: 0.17
# Similarity between chunk 17 and chunk 8: 0.17
# Similarity between chunk 17 and chunk 9: 0.14
# Similarity between chunk 17 and chunk 10: 0.05
# Similarity between chunk 17 and chunk 11: 0.11
# Similarity between chunk 17 and chunk 12: 0.14
# Similarity between chunk 17 and chunk 13: 0.16
# Similarity between chunk 17 and chunk 14: 0.13
# Similarity between chunk 17 and chunk 15: 0.17
# Similarity between chunk 17 and chunk 16: 0.07
# Similarity between chunk 17 and chunk 18: 0.14
# Similarity between chunk 17 and chunk 19: 0.10
# Similarity between chunk 17 and chunk 20: 0.10
# Similarity between chunk 17 and chunk 21: 0.08
# Similarity between chunk 17 and chunk 22: 0.00
# Similarity between chunk 17 and chunk 23: 0.04
# Similarity between chunk 18 and chunk 1: 0.01
# Similarity between chunk 18 and chunk 2: 0.19
# Similarity between chunk 18 and chunk 3: 0.21
# Similarity between chunk 18 and chunk 4: 0.16
# Similarity between chunk 18 and chunk 5: 0.22
# Similarity between chunk 18 and chunk 6: 0.08
# Similarity between chunk 18 and chunk 7: 0.14
# Similarity between chunk 18 and chunk 8: 0.19
# Similarity between chunk 18 and chunk 9: 0.09
# Similarity between chunk 18 and chunk 10: 0.08
# Similarity between chunk 18 and chunk 11: 0.10
# Similarity between chunk 18 and chunk 12: 0.17
# Similarity between chunk 18 and chunk 13: 0.14
# Similarity between chunk 18 and chunk 14: 0.14
# Similarity between chunk 18 and chunk 15: 0.17
# Similarity between chunk 18 and chunk 16: 0.09
# Similarity between chunk 18 and chunk 17: 0.14
# Similarity between chunk 18 and chunk 19: 0.12
# Similarity between chunk 18 and chunk 20: 0.15
# Similarity between chunk 18 and chunk 21: 0.09
# Similarity between chunk 18 and chunk 22: 0.03
# Similarity between chunk 18 and chunk 23: 0.14
# Similarity between chunk 19 and chunk 1: 0.00
# Similarity between chunk 19 and chunk 2: 0.13
# Similarity between chunk 19 and chunk 3: 0.10
# Similarity between chunk 19 and chunk 4: 0.06
# Similarity between chunk 19 and chunk 5: 0.07
# Similarity between chunk 19 and chunk 6: 0.04
# Similarity between chunk 19 and chunk 7: 0.09
# Similarity between chunk 19 and chunk 8: 0.13
# Similarity between chunk 19 and chunk 9: 0.07
# Similarity between chunk 19 and chunk 10: 0.08
# Similarity between chunk 19 and chunk 11: 0.05
# Similarity between chunk 19 and chunk 12: 0.08
# Similarity between chunk 19 and chunk 13: 0.10
# Similarity between chunk 19 and chunk 14: 0.10
# Similarity between chunk 19 and chunk 15: 0.11
# Similarity between chunk 19 and chunk 16: 0.03
# Similarity between chunk 19 and chunk 17: 0.10
# Similarity between chunk 19 and chunk 18: 0.12
# Similarity between chunk 19 and chunk 20: 0.02
# Similarity between chunk 19 and chunk 21: 0.06
# Similarity between chunk 19 and chunk 22: 0.08
# Similarity between chunk 19 and chunk 23: 0.09
# Similarity between chunk 20 and chunk 1: 0.00
# Similarity between chunk 20 and chunk 2: 0.04
# Similarity between chunk 20 and chunk 3: 0.06
# Similarity between chunk 20 and chunk 4: 0.04
# Similarity between chunk 20 and chunk 5: 0.12
# Similarity between chunk 20 and chunk 6: 0.01
# Similarity between chunk 20 and chunk 7: 0.01
# Similarity between chunk 20 and chunk 8: 0.06
# Similarity between chunk 20 and chunk 9: 0.02
# Similarity between chunk 20 and chunk 10: 0.01
# Similarity between chunk 20 and chunk 11: 0.00
# Similarity between chunk 20 and chunk 12: 0.04
# Similarity between chunk 20 and chunk 13: 0.02
# Similarity between chunk 20 and chunk 14: 0.02
# Similarity between chunk 20 and chunk 15: 0.04
# Similarity between chunk 20 and chunk 16: 0.02
# Similarity between chunk 20 and chunk 17: 0.10
# Similarity between chunk 20 and chunk 18: 0.15
# Similarity between chunk 20 and chunk 19: 0.02
# Similarity between chunk 20 and chunk 21: 0.17
# Similarity between chunk 20 and chunk 22: 0.00
# Similarity between chunk 20 and chunk 23: 0.04
# Similarity between chunk 21 and chunk 1: 0.02
# Similarity between chunk 21 and chunk 2: 0.11
# Similarity between chunk 21 and chunk 3: 0.06
# Similarity between chunk 21 and chunk 4: 0.10
# Similarity between chunk 21 and chunk 5: 0.14
# Similarity between chunk 21 and chunk 6: 0.03
# Similarity between chunk 21 and chunk 7: 0.03
# Similarity between chunk 21 and chunk 8: 0.05
# Similarity between chunk 21 and chunk 9: 0.02
# Similarity between chunk 21 and chunk 10: 0.02
# Similarity between chunk 21 and chunk 11: 0.03
# Similarity between chunk 21 and chunk 12: 0.03
# Similarity between chunk 21 and chunk 13: 0.03
# Similarity between chunk 21 and chunk 14: 0.02
# Similarity between chunk 21 and chunk 15: 0.04
# Similarity between chunk 21 and chunk 16: 0.01
# Similarity between chunk 21 and chunk 17: 0.08
# Similarity between chunk 21 and chunk 18: 0.09
# Similarity between chunk 21 and chunk 19: 0.06
# Similarity between chunk 21 and chunk 20: 0.17
# Similarity between chunk 21 and chunk 22: 0.08
# Similarity between chunk 21 and chunk 23: 0.10
# Similarity between chunk 22 and chunk 1: 0.02
# Similarity between chunk 22 and chunk 2: 0.12
# Similarity between chunk 22 and chunk 3: 0.10
# Similarity between chunk 22 and chunk 4: 0.01
# Similarity between chunk 22 and chunk 5: 0.07
# Similarity between chunk 22 and chunk 6: 0.00
# Similarity between chunk 22 and chunk 7: 0.06
# Similarity between chunk 22 and chunk 8: 0.03
# Similarity between chunk 22 and chunk 9: 0.00
# Similarity between chunk 22 and chunk 10: 0.04
# Similarity between chunk 22 and chunk 11: 0.02
# Similarity between chunk 22 and chunk 12: 0.02
# Similarity between chunk 22 and chunk 13: 0.05
# Similarity between chunk 22 and chunk 14: 0.06
# Similarity between chunk 22 and chunk 15: 0.06
# Similarity between chunk 22 and chunk 16: 0.00
# Similarity between chunk 22 and chunk 17: 0.00
# Similarity between chunk 22 and chunk 18: 0.03
# Similarity between chunk 22 and chunk 19: 0.08
# Similarity between chunk 22 and chunk 20: 0.00
# Similarity between chunk 22 and chunk 21: 0.08
# Similarity between chunk 22 and chunk 23: 0.03
# Similarity between chunk 23 and chunk 1: 0.01
# Similarity between chunk 23 and chunk 2: 0.08
# Similarity between chunk 23 and chunk 3: 0.09
# Similarity between chunk 23 and chunk 4: 0.05
# Similarity between chunk 23 and chunk 5: 0.11
# Similarity between chunk 23 and chunk 6: 0.04
# Similarity between chunk 23 and chunk 7: 0.03
# Similarity between chunk 23 and chunk 8: 0.11
# Similarity between chunk 23 and chunk 9: 0.02
# Similarity between chunk 23 and chunk 10: 0.12
# Similarity between chunk 23 and chunk 11: 0.15
# Similarity between chunk 23 and chunk 12: 0.09
# Similarity between chunk 23 and chunk 13: 0.04
# Similarity between chunk 23 and chunk 14: 0.05
# Similarity between chunk 23 and chunk 15: 0.08
# Similarity between chunk 23 and chunk 16: 0.03
# Similarity between chunk 23 and chunk 17: 0.04
# Similarity between chunk 23 and chunk 18: 0.14
# Similarity between chunk 23 and chunk 19: 0.09
# Similarity between chunk 23 and chunk 20: 0.04
# Similarity between chunk 23 and chunk 21: 0.10
# Similarity between chunk 23 and chunk 22: 0.03
