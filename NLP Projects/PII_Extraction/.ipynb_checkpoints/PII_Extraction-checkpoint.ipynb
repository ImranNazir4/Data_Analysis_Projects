# %%
import pandas as pd
import numpy as np
import re
import neattext as nt
import spacy
nlp=spacy.load('en_core_web_lg')
#import scispacy
#sci_nlp=spacy.load(("en_ner_bc5cdr_md")
# Out:
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\spacy\util.py:877: UserWarning: [W095] Model 'en_core_web_lg' (3.2.0) was trained with spaCy v3.2 and may not be 100% compatible with the current version (3.4.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
dir(nt)
# Out:
# ['AUTOMATED_READ_INDEX',
#  'BTC_ADDRESS_REGEX',
#  'CONTRACTIONS_DICT',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Callable',
#  'Counter',
#  'CreditCard_REGEX',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'FUNCTORS_WORDLIST',
#  'HASTAG_REGEX',
#  'HTML_TAGS_REGEX',
#  'List',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PUNCT_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextCleaner',
#  'TextExtractor',
#  'TextFrame',
#  'TextMetrics',
#  'TextPipeline',
#  'Tuple',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  'ZIP_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
# ...

# %%
nt.CreditCard_REGEX
# Out:
# re.compile(r'(?:(?:(?:\d{4}[- ]?){3}\d{4}|\d{15,16}))', re.UNICODE)

# %%
ip_regex = r'^((25[0-5]|2[0-4]\d|[01]?\d{1,2})\.){3}(25[0-5]|2[0-4]\d|[01]?\d{1,2})$'
mac_regex = r'^([0-9A-Fa-f]{2}[:-]){5}([0-9A-Fa-f]{2})$|^([0-9A-Fa-f]{12})$'
ssn_regex = r'^\d{3}-\d{2}-\d{4}$'
china_national_id_regex = r'^[A-Z]\d{17}$'
india_national_id_regex = r'^\d{12}$'
japan_national_id_regex = r'^\d{12}$'
pakistan_national_id_regex = r'^\d{13}$'
philippines_national_id_regex = r'^\d{12}$'
ifsc_regex="^[A-Z]{4}0[A-Z0-9]{6}$"

# %%
emails=[]
phone_no=[]
persons=[]
orgs=[]
gpe=[]
location=[]
ssn=[]
urls=[]
zip_codes=[]
ip_addresses=[]
mac_addresses=[]
master_visa_cards=[]
drugs=[]
dieases=[]
ifsc=[]

# %%
# pre-cautions python 3.6 and spacy version 2.3.x

# %%
def sensitive_PII(data):
    doc=sci_nlp(data)
    entities = []
    for ent in doc.ents:
        entities.append((ent.text, ent.label_))
        df = pd.DataFrame(entities, columns=['Entity', 'Type'])

# %%
def critical_PII(df):
    all_data=df.values
    for value in all_data:
        data=' '.join(value)
        #emails.extend(re.findall(re.compile(r'[\w\.-]+@[\w\.-]+', re.UNICODE),data))
        #phone_no.extend(re.findall(re.compile(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]', re.UNICODE),data))
        #ssn.extend((re,findall(ssn_regex,data))
        #ip_addresses.extend(re.findall(ip_regex,data))
        #mac_addresses.extend(re.findall(mac_regex,data))
        #urls.extend(nt.extract_urls(data))
        #master_visa_cards.extend(re.findall(re.compile(r'(?:(?:(?:\d{4}[- ]?){3}\d{4}|\d{15,16}))', re.UNICODE),data))
        #master_visa_cards.extend(re.findall(re.compile(r'5[1-5]\d{2}[\s-]?\d{4}[\s-]?\d{4}[\s-]?\d{4}', re.UNICODE),data))
        #ifsc.extend(re.findall(ifsc_regex,data))
        #doc=nlp(data)
        #for ent in doc.ents:
         #   if ent.label_=='PERSON':
          #      persons.append(ent.text)
           # if ent.label_=='ORG':
            #    orgs.append(ent.text)
            #if ent.label_=='GPE':
            #    gpe.append(ent.text)
            #if ent.label_=='LOC':
             #   location.append(ent.text)

# %%
critical_PII(df[0:10])

# %%
ip_addresses,mac_addresses
# Out:
# ([], [])

# %%
import pandas as pd
from faker import Faker

# create Faker object
fake = Faker('en_US')

# generate 100 rows of data for each of the columns
emails = [fake.email() for _ in range(100)]
names = [fake.name() for _ in range(100)]
phone_numbers = [fake.phone_number() for _ in range(100)]
urls = [fake.url() for _ in range(100)]
ssns = [fake.ssn() for _ in range(100)]
locations = [fake.city() for _ in range(100)]
gpes = [fake.country() for _ in range(100)]
organizations = [fake.company() for _ in range(100)]
zip_codes = [fake.zipcode() for _ in range(100)]
mac_addresses = [fake.mac_address() for _ in range(100)]
ip_addresses = [fake.ipv4_public() for _ in range(100)]
credit_card_numbers = [fake.credit_card_number() for _ in range(100)]
master_card_numbers = [fake.credit_card_number(card_type='mastercard') for _ in range(100)]
#passport_numbers = [fake.passport_number() for _ in range(100)]
twitter_handles = [fake.user_name() for _ in range(100)]
instagram_handles = [fake.user_name() for _ in range(100)]
nation_id_card_numbers = [fake.numerify(text='############') for _ in range(100)]

# create a Pandas dataframe with the generated data
data = {
    'Email': emails,
    'Name': names,
    'Phone': phone_numbers,
    'URL': urls,
    'SSN': ssns,
    'Location': locations,
    'GPE': gpes,
    'Organization': organizations,
    'Zip Code': zip_codes,
    'MAC Address': mac_addresses,
    'IP Address': ip_addresses,
    'Credit Card Number': credit_card_numbers,
    'Mastercard Number': master_card_numbers,
    'Twitter Handle': twitter_handles,
    'Instagram Handle': instagram_handles,
    'National ID Card Number': nation_id_card_numbers
}

df = pd.DataFrame(data)

# display the dataframe
#print(df)

# %%
df
# Out:
#                           Email              Name                 Phone  \
# 0      patelkathryn@example.com  Joseph Castaneda            1874189303
# 1           gharris@example.net      Kevin Oliver            3157261146
# 2   carolynmcdaniel@example.org   Alexandra Smith  +1-334-631-2775x8840
# 3      raymondbrown@example.net   Whitney Sanders     (025)306-9956x735
# 4     crystalpierce@example.org    Jennifer Brown      731.396.3401x892
# ..                          ...               ...                   ...
# 95      knightbrent@example.org   Jonathan Palmer          124.649.7780
# 96          andre16@example.org     Johnny Barker      033-736-8343x856
# 97           vfrost@example.org    Michael Thomas   (409)452-6356x97270
# 98          edwin06@example.net       Shelley Lee    912.502.3387x80900
# 99         samuel01@example.org       Jacob Davis   +1-090-701-1552x074
#
#                                URL          SSN          Location  \
# ...

# %%
ifsc_list = [
    "ABHY0065001", "ALLA0212614", "ANDB0001476", "UTIB0000302", "BARB0VJLALW", "BKID0008541", "CBIN0284702",
    "CIUB0000035", "CNRB0003025", "CORP0000897", "CTRB0000019", "DBSS0IN0817", "DCBL0000113", "DLXB0000240",
    "FDRL0001909", "HDFC0000101", "HSBC0560002", "ICIC0000104", "IDIB000N048", "INDB0000729", "IOBA0001496",
    "ISIN0000001", "JAKA0MIRZP2", "KARB0000009", "KLGB0040231", "KKBK0000958", "KOEX0000001", "KTKM0000214",
    "LAVB0000665", "MAHB0000434", "NKGS0000025", "ORBC0100303", "PUNB0069300", "RATN0000101", "SBIN0000642",
    "SIBL0000543", "SVCB0000055", "SYNB0000551", "TMBL0000314", "UBIN0541276", "UCBA0000019", "UTBI0VIC680",
    "VIJB0007401", "YESB0000001", "BKDN0630476", "CSBK0000127", "BKID0008584", "HDFC0000478", "ABNA0100312",
    "BARB0BAWANG", "IBKL0000142", "CNRB0000843", "BKID0008500", "BMBL0000061", "ALLA0212599", "UTIB0000988",
    "CNRB0002675", "ANDB0001091", "BARB0DAHGAM", "BKID0004451", "CITI0000003", "CNRB0002957", "CRBT0000002",
    "DLXB0000177", "HSBC0490003", "HDFC0000593", "IBKL0000211", "ICIC0000069", "IDIB000S006", "IDFB0020101",
    "INDB0000023", "IOBA0000135", "JAKA0PALAK1", "KLGB0040401", "KARB0000641", "KKBK0000957", "KNSB0015001",
    "LAVB0000660", "MAHB0000622", "MHCB0000301", "NKGS0000063", "ORBC0100043", "PUNB0602600", "RATN0000081",
    "SBIN0000904", "SIBL0000084", "SVCB0000161", "SYNB0002203", "TMBL0000279", "UCBA0002066", "UNIN0780131",
    "UTIB0000468"]

# %%
for i in ifsc_list:
    if re.findall("^[A-Z]{4}0[A-Z0-9]{6}$",i):
        print("yes_it")
# Out:
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
# yes_it
