# %%
import pandas as pd
import numpy as np
import re
import neattext as nt
import spacy
nlp=spacy.load('en_core_web_lg')

# %%
dir(nt)
# Out:
# ['AUTOMATED_READ_INDEX',
#  'BTC_ADDRESS_REGEX',
#  'CONTRACTIONS_DICT',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Callable',
#  'Counter',
#  'CreditCard_REGEX',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'FUNCTORS_WORDLIST',
#  'HASTAG_REGEX',
#  'HTML_TAGS_REGEX',
#  'List',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PUNCT_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextCleaner',
#  'TextExtractor',
#  'TextFrame',
#  'TextMetrics',
#  'TextPipeline',
#  'Tuple',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  'ZIP_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
# ...

# %%
nt.PHONE_REGEX
# Out:
# re.compile(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]', re.UNICODE)

# %%
emails=[]
phone_no=[]
persons=[]
orgs=[]
gpe=[]
location=[]
ssn=[]

# %%
def critical_PII(df):
    all_data=df.values
    for value in all_data:
        data=' '.join(value)
        #emails.extend(re.findall(re.compile(r'[\w\.-]+@[\w\.-]+', re.UNICODE),data))
        #phone_no.extend(re.findall(re.compile(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]', re.UNICODE),data))
        #ssn.extend(ssn_regex = r'^\d{3}-\d{2}-\d{4}$')
        doc=nlp(data)
        for ent in doc.ents:
            if ent.label_=='PERSON':
                persons.append(ent.text)
            if ent.label_=='ORG':
                orgs.append(ent.text)
            if ent.label_=='GPE':
                gpe.append(ent.text)
            if ent.label_=='LOC':
                location.append(ent.text)

# %%
critical_PII(df[0:10])
# Out:
# vmassey@example.net +1-177-442- PERSON
# Angela Elliott PERSON
# Eric Bypass Suite PERSON
# 954 CARDINAL
# West Amandatown ORG
# Michael Kent PERSON
# 862 CARDINAL
# North Emily PERSON
# 26258 CARDINAL
# Victoria Scott PERSON
# 5586 Box 8238
#  DATE
# AP ORG
# 30297 DATE
# 235)789-8976 DATE
# Gregory Cochran PERSON
# Allen Glens PERSON
# 092 CARDINAL
# North Kimberlyfurt GPE
# 51587 DATE
# Richard Mclean PERSON
# 4756 CARDINAL
# Johnny Route Apt PERSON
# 236 CARDINAL
# Port Zacharyfurt PERSON
# 25969 DATE
# 332 CARDINAL
# Jeremy Cooper PERSON
# 299 CARDINAL
# Gregory Mountains PERSON
# RI ORG
# Debra Chapman USNV PERSON
# Mccall
# FPO AE 96680 ORG
# 324.214.5658x07280 CARDINAL
# Patrick Phillips PERSON
# White Route
#  GPE
# 05298 CARDINAL
# Elizabeth Clay 815 PERSON
# 46497 CARDINAL
# Brian Martinez PERSON
# 034 CARDINAL
# TN ORG
# 26925 DATE

# %%
extract_btc_address',
 'extract_currencies',
 'extract_currency_symbols',
 'extract_dates',
 'extract_emails',
 'extract_emojis',
 'extract_hashtags',
 'extract_html_tags',
 'extract_mastercard_addr',
 'extract_md5sha',
 'extract_numbers',
 'extract_pattern',
 'extract_phone_numbers',
 'extract_postoffice_box',
 'extract_shortwords',
 'extract_special_characters',
 'extract_stopwords',
 'extract_street_address',
 'extract_terms_in_bracket',
 'extract_urls',
 'extract_userhandles',
 'extract_visacard_addr
# Out:
#   File "<ipython-input-2-bf5022af4e02>", line 1
#     extract_btc_address',
#                          ^
# SyntaxError: EOL while scanning string literal

# %%
def pii_extraction(text):

# %%
import pandas as pd
from faker import Faker

fake = Faker()

# Generate 100 rows of fake data
data = []
for i in range(100):
    data.append([fake.email(), fake.phone_number(), fake.first_name(), fake.last_name(), fake.address()])

# Create a Pandas DataFrame from the fake data
df = pd.DataFrame(data, columns=['Email', 'Phone', 'First Name', 'Last Name', 'Address'])

# Print the first five rows of the DataFrame
print(df.head())
# Out:
#                       Email                  Phone First Name Last Name  \
# 0       vmassey@example.net  +1-177-442-7180x88897     Angela   Elliott
# 1       ujensen@example.com     110.737.0241x18592    Michael      Kent
# 2  billyproctor@example.net  +1-580-969-5813x20331   Victoria     Scott
# 3      ronnie12@example.com          (235)789-8976    Gregory   Cochran
# 4  hunterashley@example.net       377.363.9914x377    Richard    Mclean
#
#                                              Address
# 0  53538 Eric Bypass Suite 954\nWest Amandatown, ...
# 1                862 Jose Key\nNorth Emily, TX 26258
# 2                   Unit 5586 Box 8238\nDPO AP 30297
# 3  13241 Allen Glens Suite 092\nNorth Kimberlyfur...
# 4  4756 Johnny Route Apt. 236\nPort Zacharyfurt, ...

# %%
df.values
# Out:
# array([['vmassey@example.net', '+1-177-442-7180x88897', 'Angela',
#         'Elliott',
#         '53538 Eric Bypass Suite 954\nWest Amandatown, FM 59314'],
#        ['ujensen@example.com', '110.737.0241x18592', 'Michael', 'Kent',
#         '862 Jose Key\nNorth Emily, TX 26258'],
#        ['billyproctor@example.net', '+1-580-969-5813x20331', 'Victoria',
#         'Scott', 'Unit 5586 Box 8238\nDPO AP 30297'],
#        ['ronnie12@example.com', '(235)789-8976', 'Gregory', 'Cochran',
#         '13241 Allen Glens Suite 092\nNorth Kimberlyfurt, AR 51587'],
#        ['hunterashley@example.net', '377.363.9914x377', 'Richard',
#         'Mclean',
#         '4756 Johnny Route Apt. 236\nPort Zacharyfurt, PA 25969'],
#        ['martinezcourtney@example.org', '332-733-1830x7914', 'Jeremy',
#         'Cooper',
#         '299 Gregory Mountains\nNorth Stephanieville, RI 70262'],
#        ['ymason@example.net', '777-540-9806', 'Debra', 'Chapman',
#         'USNV Mccall\nFPO AE 96680'],
# ...

# %%
# create Faker object
fake = Faker()

# generate 100 SSN numbers using Faker and store in a list
ssn_list = [fake.ssn() for _ in range(100)]

# create pandas series from the list
ssn_series = pd.Series(ssn_list)

# %%
ssn_series
# Out:
# 0     337-62-0762
# 1     849-71-9144
# 2     879-91-3835
# 3     221-21-6318
# 4     272-13-3722
#          ...
# 95    389-35-2783
# 96    789-51-2078
# 97    550-34-9616
# 98    681-76-0835
# 99    513-66-0467
# Length: 100, dtype: object

# %%
def validate_ssn(x):
    if re.findall(ssn_regex,x):
        print('it works')

# %%
ssn_series.apply(lambda x:validate_ssn(x))
# Out:
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# it works
# ...
