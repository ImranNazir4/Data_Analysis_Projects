# %% [markdown]
# ---
# # **Installing Necessary Dependencies**
# ---

# %%
# !pip install -q neattext
# nltk.download('wordnet')

# %% [markdown]
# ---
# # **Importing Dependencies**
# ---

# %%
import pandas as pd         #python pcakage for data analysis
import os                   #python package to deal with local system files and directories
import re                   #python package for deal with regular expression
import neattext as nt       #python package to do text cleaning
import numpy as np          #package for handling arrays
import matplotlib.pyplot as plt  #for data visualizaitons
import seaborn as sns             #python package for data visualizations
from wordcloud import WordCloud #to draw word clouds
import nltk                 #package for text analysis
from nltk.stem import WordNetLemmatizer #importing lemmatizer for word lemmatization
# Create a lemmatizer object
lemmatizer = WordNetLemmatizer()
from sklearn.feature_extraction.text import TfidfVectorizer    #importing tf-idf vectorizer
# Create a TF-IDF vectorizer object
vectorizer = TfidfVectorizer()

# %% [markdown]
# ---
# # **Data Preparation**
# ---

# %% [markdown]
# ### Data Source:  https://www.kaggle.com/datasets/shivamkushwaha/bbc-full-text-document-classification

# %% [markdown]
# ### Data Description:
# This data comprised 5 directories: business, tech, sports, entertainment, and politics. Each directory contains a sufficient number of text files. In each file, the text is present related to the directory which owns that file.

# %%
data_directories=os.listdir()   #list of files and directories present in current directory

# %%
data_directories
# Out:
# ['.ipynb_checkpoints',
#  'business',
#  'entertainment',
#  'politics',
#  'README.TXT',
#  'sport',
#  'tech',
#  'text_classification_p1.ipynb',
#  'text_classification_p2.ipynb']

# %% [markdown]
# # Data Selection:
# We random selected three categories of our choice and performed text classification on that data

# %%
data_directories=['entertainment','sport','tech']  #our selected data directories

# %%
files_dict={}  #files_dictonary to store files with their category name

# %%
 '''
    This loop iterate each directoy in present in the list of selected directories, then goes through each
    file in that directoy, read its text and save it in the dictionary with follwing format:
    {file_Category:file_text}
'''
for dir in data_directories:
    for file in os.listdir(dir):
        f=open('./'+dir+'/'+file)
        f=f.read()
        files_dict[dir+'/'+file]=f

# %%
df=pd.DataFrame(files_dict,index=[1]).T  #converting files_dict to pandas dataframe for analysis

# %%
df.reset_index(inplace=True)

# %%
df.columns=['label','text']  #changing columns names to desired names

# %%
df['label']=df['label'].apply(lambda x:str(x).split('/')[0])

# %%
df
# Out:
#               label                                               text
# 0     entertainment  Gallery unveils interactive tree\n\nA Christma...
# 1     entertainment  Jarre joins fairytale celebration\n\nFrench mu...
# 2     entertainment  Musical treatment for Capra film\n\nThe classi...
# 3     entertainment  Richard and Judy choose top books\n\nThe 10 au...
# 4     entertainment  Poppins musical gets flying start\n\nThe stage...
# ...             ...                                                ...
# 1293           tech  BT program to beat dialler scams\n\nBT is intr...
# 1294           tech  Spam e-mails tempt net shoppers\n\nComputer us...
# 1295           tech  Be careful how you code\n\nA new European dire...
# 1296           tech  US cyber security chief resigns\n\nThe man mak...
# 1297           tech  Losing yourself in online gaming\n\nOnline rol...
#
# [1298 rows x 2 columns]

# %% [markdown]
# ---
# # **Text Preprocessing**
# ---

# %% [markdown]
# ### **Text Cleaning**

# %%
def text_cleaning(text):
    '''
    This function gets text of each file one by and apply text cleaning techniques on given text
    '''
    text=nt.fix_contractions(text)                # I'm --> I am
    text=nt.remove_special_characters(text)       #removes special characters
    text=nt.remove_stopwords(text)                #removes stopwords
    text=nt.remove_multiple_spaces(text)          #removes multiple spaces
    text=nt.remove_shortwords(text,4)             #remove short words of lenght 4
    text=nt.remove_numbers(text)                  #remove numbers
    return text

# %%
df['cleaned text']=df['text'].apply(lambda x:text_cleaning(x))

# %% [markdown]
# ### **Lemmatization**

# %%
def lemmatization(text):
    lemmas=[]
    tokens = nltk.word_tokenize(text)
    for token in tokens:
        lemma = lemmatizer.lemmatize(token)
        lemmas.append(lemma)
    return ' '.join(lemmas)

# %%
df['cleaned text']=df['cleaned text'].apply(lambda x:lemmatization(x))

# %% [markdown]
# ###  **Data Visualizations**

# %%
around_color = "#f6f5f5"
inside_color= "#f6f5f5"
colors = sns.color_palette("ch:s=-.2,r=.6")
fig = plt.figure(figsize=(10,6))
colors = colors

# %%
for label in range(0,3):
    values = sorted(df["label"].unique())
    specific_value= values[label]
    dataset = df[df["label"]==specific_value]
    list_ = dataset["cleaned text"].tolist()
    sentence = "".join(list_)
    plt.figure(figsize=(40,20))
    plt.subplot(1,5,1+label)
    plt.imshow(WordCloud().generate(sentence))
    plt.title("Words used in " + str(specific_value), fontsize=30)
    fig.patch.set_facecolor(inside_color)

# %% [markdown]
# ### **Text Vectorization**

# %%
X=vectorizer.fit_transform(df['cleaned text'])

# %%
y=df['label']

# %% [markdown]
# ---
# # **Model Development**
# ---

# %%
from sklearn.model_selection import train_test_split  #for train test plit

# %% [markdown]
# ### Data Splitting into Training and Testing

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=34)
#test data size=20% and training data size=80%

# %% [markdown]
# ### **Model Selection:**
# We selected all the famous classification algorithms and check their performance on our data.

# %%
# Importing Models
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm
# Importing Evaluation matrces
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report, plot_confusion_matrix

# check the performance on diffrent regressor
models = []
models.append(('Support Vector Classifier', svm.SVC()))
models.append(('LogisitcRegression', LogisticRegression()))
models.append(('KNeighborsClassifier', KNeighborsClassifier()))
models.append(('RandomForestClassifier', RandomForestClassifier()))
models.append(('DecisionTreeClassifier', DecisionTreeClassifier()))
models.append(('NaiveBayesClassifier', MultinomialNB()))


# prepare the cross-validation procedure
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# metrices to store performance
acc = []
pre = []
f1 = []
con = []
rec = []


import time
i = 0
for name,model in models:
    i = i+1
    start_time = time.time()
    
    # Fitting model to the Training set
    clf = model
    clf.fit(X_train, y_train)
    
    # predict values
    y_pred = clf.predict(X_test)
    
    # Accuracy
    accuracy = accuracy_score(y_test, y_pred)
    acc.append(accuracy)
    # Precision
    precision = precision_score(y_test, y_pred, average=None)
    pre.append(precision)
    # Recall
    recall = recall_score(y_test, y_pred, average=None)
    rec.append(recall)
    # F1 Score
    f1_sco = f1_score(y_test, y_pred, average=None)
    f1.append(f1_sco)
    # Confusion Matrix
    confusion_mat = confusion_matrix(y_test, y_pred)
    con.append(confusion_mat)
    # Report
    report = classification_report(y_test, y_pred)
    
    # evaluate model
    scores = cross_val_score(clf, X, y, cv=cv, n_jobs=-1)



    print("+","="*100,"+")
    print('\033[1m' + f"\t\t\t{i}-For {name} The Performance result is: " + '\033[0m')
    print("+","="*100,"+")
    print('Accuracy : ', accuracy)   
    print("-"*50)
    print('F1 : ', f1_sco)
    print("-"*50)
    print('Reacll : ', recall)
    print("-"*50)
    print('Precision : ', precision)
    print("-"*50)
    print('cross validation accuracy : ', np.mean(scores))
    print("-"*50)
    print('Confusion Matrix....\n', confusion_mat)
    print("-"*50)
    print('Classification Report....\n', report)
    print("-"*50)
    print('Plotting Confusion Matrix...\n')
    plot_confusion_matrix(clf, X_test, y_test)
    plt.show()


    
    print("\t\t\t\t\t\t\t-----------------------------------------------------------")
    print(f"\t\t\t\t\t\t\t Time for detection ({name}) : {round((time.time() - start_time), 3)} seconds...")
    print("\t\t\t\t\t\t\t-----------------------------------------------------------")
    print()
    
pd.DataFrame({"Model": dict(models).keys(), "Accuracy": acc, "Precision": pre, "Recall": rec, "F1_Score": f1, "Confusion Matrix": con})
# Out:
# + ==================================================================================================== +
# 			1-For Support Vector Classifier The Performance result is:
# + ==================================================================================================== +
# Accuracy :  0.9884615384615385
# --------------------------------------------------
# F1 :  [0.98684211 0.99516908 0.98136646]
# --------------------------------------------------
# Reacll :  [0.97402597 1.         0.9875    ]
# --------------------------------------------------
# Precision :  [1.         0.99038462 0.97530864]
# --------------------------------------------------
# cross validation accuracy :  0.9892159192159193
# --------------------------------------------------
# Confusion Matrix....
#  [[ 75   0   2]
#  [  0 103   0]
#  [  0   1  79]]
# --------------------------------------------------
# Classification Report....
#                 precision    recall  f1-score   support
#
# entertainment       1.00      0.97      0.99        77
#         sport       0.99      1.00      1.00       103
#          tech       0.98      0.99      0.98        80
#
#      accuracy                           0.99       260
#     macro avg       0.99      0.99      0.99       260
#  weighted avg       0.99      0.99      0.99       260
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 							-----------------------------------------------------------
# 							 Time for detection (Support Vector Classifier) : 6.109 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			2-For LogisitcRegression The Performance result is:
# + ==================================================================================================== +
# Accuracy :  0.9846153846153847
# --------------------------------------------------
# F1 :  [0.98684211 0.98564593 0.98113208]
# --------------------------------------------------
# Reacll :  [0.97402597 1.         0.975     ]
# --------------------------------------------------
# Precision :  [1.         0.97169811 0.98734177]
# --------------------------------------------------
# cross validation accuracy :  0.9884466884466885
# --------------------------------------------------
# Confusion Matrix....
#  [[ 75   1   1]
#  [  0 103   0]
#  [  0   2  78]]
# --------------------------------------------------
# Classification Report....
#                 precision    recall  f1-score   support
#
# entertainment       1.00      0.97      0.99        77
#         sport       0.97      1.00      0.99       103
#          tech       0.99      0.97      0.98        80
#
#      accuracy                           0.98       260
#     macro avg       0.99      0.98      0.98       260
#  weighted avg       0.98      0.98      0.98       260
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 							-----------------------------------------------------------
# 							 Time for detection (LogisitcRegression) : 3.164 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			3-For KNeighborsClassifier The Performance result is:
# + ==================================================================================================== +
# Accuracy :  0.9615384615384616
# --------------------------------------------------
# F1 :  [0.93877551 0.98095238 0.95705521]
# --------------------------------------------------
# Reacll :  [0.8961039 1.        0.975    ]
# --------------------------------------------------
# Precision :  [0.98571429 0.96261682 0.93975904]
# --------------------------------------------------
# cross validation accuracy :  0.9653370953370952
# --------------------------------------------------
# Confusion Matrix....
#  [[ 69   3   5]
#  [  0 103   0]
#  [  1   1  78]]
# --------------------------------------------------
# Classification Report....
#                 precision    recall  f1-score   support
#
# entertainment       0.99      0.90      0.94        77
#         sport       0.96      1.00      0.98       103
#          tech       0.94      0.97      0.96        80
#
#      accuracy                           0.96       260
#     macro avg       0.96      0.96      0.96       260
#  weighted avg       0.96      0.96      0.96       260
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 							-----------------------------------------------------------
# 							 Time for detection (KNeighborsClassifier) : 0.642 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			4-For RandomForestClassifier The Performance result is:
# + ==================================================================================================== +
# Accuracy :  0.9692307692307692
# --------------------------------------------------
# F1 :  [0.96       0.98095238 0.9625    ]
# --------------------------------------------------
# Reacll :  [0.93506494 1.         0.9625    ]
# --------------------------------------------------
# Precision :  [0.98630137 0.96261682 0.9625    ]
# --------------------------------------------------
# cross validation accuracy :  0.9861300861300861
# --------------------------------------------------
# Confusion Matrix....
#  [[ 72   2   3]
#  [  0 103   0]
#  [  1   2  77]]
# --------------------------------------------------
# Classification Report....
#                 precision    recall  f1-score   support
#
# entertainment       0.99      0.94      0.96        77
#         sport       0.96      1.00      0.98       103
#          tech       0.96      0.96      0.96        80
#
#      accuracy                           0.97       260
#     macro avg       0.97      0.97      0.97       260
#  weighted avg       0.97      0.97      0.97       260
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 							-----------------------------------------------------------
# 							 Time for detection (RandomForestClassifier) : 12.164 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			5-For DecisionTreeClassifier The Performance result is:
# + ==================================================================================================== +
# Accuracy :  0.8807692307692307
# --------------------------------------------------
# F1 :  [0.82119205 0.90047393 0.91139241]
# --------------------------------------------------
# Reacll :  [0.80519481 0.9223301  0.9       ]
# --------------------------------------------------
# Precision :  [0.83783784 0.87962963 0.92307692]
# --------------------------------------------------
# cross validation accuracy :  0.906008316008316
# --------------------------------------------------
# Confusion Matrix....
#  [[62  9  6]
#  [ 8 95  0]
#  [ 4  4 72]]
# --------------------------------------------------
# Classification Report....
#                 precision    recall  f1-score   support
#
# entertainment       0.84      0.81      0.82        77
#         sport       0.88      0.92      0.90       103
#          tech       0.92      0.90      0.91        80
#
#      accuracy                           0.88       260
#     macro avg       0.88      0.88      0.88       260
#  weighted avg       0.88      0.88      0.88       260
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 							-----------------------------------------------------------
# 							 Time for detection (DecisionTreeClassifier) : 2.604 seconds...
# 							-----------------------------------------------------------
#
# + ==================================================================================================== +
# 			6-For NaiveBayesClassifier The Performance result is:
# + ==================================================================================================== +
# Accuracy :  0.9769230769230769
# --------------------------------------------------
# F1 :  [0.96644295 0.98564593 0.97530864]
# --------------------------------------------------
# Reacll :  [0.93506494 1.         0.9875    ]
# --------------------------------------------------
# Precision :  [1.         0.97169811 0.96341463]
# --------------------------------------------------
# cross validation accuracy :  0.9784348084348086
# --------------------------------------------------
# Confusion Matrix....
#  [[ 72   2   3]
#  [  0 103   0]
#  [  0   1  79]]
# --------------------------------------------------
# Classification Report....
#                 precision    recall  f1-score   support
#
# entertainment       1.00      0.94      0.97        77
#         sport       0.97      1.00      0.99       103
#          tech       0.96      0.99      0.98        80
#
#      accuracy                           0.98       260
#     macro avg       0.98      0.97      0.98       260
#  weighted avg       0.98      0.98      0.98       260
#
# --------------------------------------------------
# Plotting Confusion Matrix...
# c:\users\zee tech\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# 							-----------------------------------------------------------
# 							 Time for detection (NaiveBayesClassifier) : 0.41 seconds...
# 							-----------------------------------------------------------
#                        Model  Accuracy  \
# 0  Support Vector Classifier  0.988462
# 1         LogisitcRegression  0.984615
# 2       KNeighborsClassifier  0.961538
# 3     RandomForestClassifier  0.969231
# 4     DecisionTreeClassifier  0.880769
# 5       NaiveBayesClassifier  0.976923
#
#                                            Precision  \
# 0      [1.0, 0.9903846153846154, 0.9753086419753086]
# 1      [1.0, 0.9716981132075472, 0.9873417721518988]
# 2  [0.9857142857142858, 0.9626168224299065, 0.939...
# 3   [0.9863013698630136, 0.9626168224299065, 0.9625]
# 4  [0.8378378378378378, 0.8796296296296297, 0.923...
# 5      [1.0, 0.9716981132075472, 0.9634146341463414]
#
#                                           Recall  \
# 0               [0.974025974025974, 1.0, 0.9875]
# 1                [0.974025974025974, 1.0, 0.975]
# 2               [0.8961038961038961, 1.0, 0.975]
# 3               [0.935064935064935, 1.0, 0.9625]
# 4  [0.8051948051948052, 0.9223300970873787, 0.9]
# 5               [0.935064935064935, 1.0, 0.9875]
#
#                                             F1_Score  \
# 0  [0.9868421052631579, 0.9951690821256038, 0.981...
# 1  [0.9868421052631579, 0.985645933014354, 0.9811...
# 2  [0.9387755102040817, 0.9809523809523809, 0.957...
# 3  [0.9600000000000001, 0.9809523809523809, 0.962...
# 4  [0.8211920529801325, 0.9004739336492891, 0.911...
# 5  [0.9664429530201343, 0.985645933014354, 0.9753...
#
#                         Confusion Matrix
# 0  [[75, 0, 2], [0, 103, 0], [0, 1, 79]]
# 1  [[75, 1, 1], [0, 103, 0], [0, 2, 78]]
# 2  [[69, 3, 5], [0, 103, 0], [1, 1, 78]]
# 3  [[72, 2, 3], [0, 103, 0], [1, 2, 77]]
# 4   [[62, 9, 6], [8, 95, 0], [4, 4, 72]]
# 5  [[72, 2, 3], [0, 103, 0], [0, 1, 79]]

# %% [markdown]
# ### **Model Evaluation**

# %% [markdown]
# SVM is best performer on our data with good accuracy and F1-score. The logistic regression in on 2nd position in these metrics.
